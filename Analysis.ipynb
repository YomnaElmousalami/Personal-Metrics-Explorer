# %% [markdown]
# <a href="https://colab.research.google.com/github/YomnaElmousalami/Predictive-Wellness-Analytics/blob/main/Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import os
from bs4 import BeautifulSoup
import dask.dataframe as dd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #Analyze the content in this folder

# %%
folder = "/content/drive/MyDrive/apple_health_export"
directory_files = os.listdir(folder)
for i in directory_files:
  print(i)
# Out:
# export.xml
# electrocardiograms
# export_cda.xml
# workout-routes

# %% [markdown]
# #Work on the first file

# %%
file_1 = "/content/drive/MyDrive/apple_health_export/export.xml"

# %%
tree = ET.parse(file_1)
root = tree.getroot()

# %%
# Function to extract attributes as DataFrame
def extract_data(tag):
    data = []
    for elem in root.findall(tag):
        data.append(elem.attrib)
    return pd.DataFrame(data)

# Extract tables
export_date_df = extract_data("ExportDate")
me_df = extract_data("Me")
records_df = extract_data("Record")
workouts_df = extract_data("Workout")
activity_summary_df = extract_data("ActivitySummary")

# %% [markdown]
# Make sure every table is displayed

# %%
records_df
# Out:
#                                                     type  \
# 0                         HKQuantityTypeIdentifierHeight
# 1                         HKQuantityTypeIdentifierHeight
# 2                       HKQuantityTypeIdentifierBodyMass
# 3                       HKQuantityTypeIdentifierBodyMass
# 4                       HKQuantityTypeIdentifierBodyMass
# ...                                                  ...
# 911267  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911268  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911269  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911270  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911271  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
#
#                   sourceName sourceVersion unit               creationDate  \
# 0                 iPhone (2)        16.6.1   ft  2023-09-17 10:41:20 -0500
# 1       Jannah’s Apple Watch           9.3   ft  2023-09-17 16:11:26 -0500
# 2                     Health        11.2.6   lb  2018-04-01 13:08:42 -0500
# 3                     Health        11.2.6   lb  2018-04-03 19:11:31 -0500
# 4                     Health        11.2.6   lb  2018-04-05 21:03:57 -0500
# ...                      ...           ...  ...                        ...
# 911267  Jannah’s Apple Watch          11.0   ms  2025-02-25 21:29:58 -0500
# 911268  Jannah’s Apple Watch          11.0   ms  2025-02-26 06:45:04 -0500
# 911269  Jannah’s Apple Watch          11.0   ms  2025-02-26 07:57:41 -0500
# 911270  Jannah’s Apple Watch          11.0   ms  2025-02-26 13:43:06 -0500
# 911271  Jannah’s Apple Watch          11.0   ms  2025-02-26 15:09:12 -0500
#
#                         startDate                    endDate    value  \
# 0       2023-09-17 10:41:20 -0500  2023-09-17 10:41:20 -0500     5.25
# 1       2023-09-17 16:11:26 -0500  2023-09-17 16:11:26 -0500     5.25
# 2       2018-04-01 13:08:00 -0500  2018-04-01 13:08:00 -0500      120
# 3       2018-04-03 19:11:00 -0500  2018-04-03 19:11:00 -0500      120
# 4       2018-04-05 21:03:00 -0500  2018-04-05 21:03:00 -0500      120
# ...                           ...                        ...      ...
# 911267  2025-02-25 21:28:57 -0500  2025-02-25 21:29:54 -0500  144.231
# 911268  2025-02-26 06:44:03 -0500  2025-02-26 06:45:03 -0500  120.072
# 911269  2025-02-26 07:56:40 -0500  2025-02-26 07:57:39 -0500  38.8269
# 911270  2025-02-26 13:42:05 -0500  2025-02-26 13:43:04 -0500  39.7098
# 911271  2025-02-26 15:08:11 -0500  2025-02-26 15:09:11 -0500  27.7803
#
#                                                    device
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 911267  <<HKDevice: 0x30186d040>, name:Apple Watch, ma...
# 911268  <<HKDevice: 0x30186d040>, name:Apple Watch, ma...
# 911269  <<HKDevice: 0x30186d040>, name:Apple Watch, ma...
# 911270  <<HKDevice: 0x30186d040>, name:Apple Watch, ma...
# 911271  <<HKDevice: 0x30186d040>, name:Apple Watch, ma...
#
# [911272 rows x 9 columns]

# %%
records_df.loc[records_df['sourceName'] == "iPhone (2)"]
# Out:
#                                           type  sourceName sourceVersion  \
# 0               HKQuantityTypeIdentifierHeight  iPhone (2)        16.6.1
# 10            HKQuantityTypeIdentifierBodyMass  iPhone (2)          16.0
# 11            HKQuantityTypeIdentifierBodyMass  iPhone (2)        16.6.1
# 133140       HKQuantityTypeIdentifierStepCount  iPhone (2)        13.4.1
# 133141       HKQuantityTypeIdentifierStepCount  iPhone (2)        13.4.1
# ...                                        ...         ...           ...
# 900239   HKCategoryTypeIdentifierSleepAnalysis  iPhone (2)        17.6.1
# 903662  HKCategoryTypeIdentifierAppleStandHour  iPhone (2)        17.2.1
# 906341  HKCategoryTypeIdentifierAppleStandHour  iPhone (2)        17.5.1
# 906342  HKCategoryTypeIdentifierAppleStandHour  iPhone (2)        17.5.1
# 906577  HKCategoryTypeIdentifierAppleStandHour  iPhone (2)        17.5.1
#
#          unit               creationDate                  startDate  \
# 0          ft  2023-09-17 10:41:20 -0500  2023-09-17 10:41:20 -0500
# 10         lb  2022-09-20 09:55:06 -0500  2022-09-20 09:55:06 -0500
# 11         lb  2023-09-17 10:41:20 -0500  2023-09-17 10:41:20 -0500
# 133140  count  2021-01-23 13:16:51 -0500  2021-01-23 13:06:18 -0500
# 133141  count  2021-01-23 15:31:03 -0500  2021-01-23 15:20:00 -0500
# ...       ...                        ...                        ...
# 900239    NaN  2024-10-28 05:00:23 -0500  2024-10-27 22:30:38 -0500
# 903662    NaN  2024-02-15 16:20:50 -0500  2024-02-15 15:00:00 -0500
# 906341    NaN  2024-07-04 16:20:48 -0500  2024-07-04 14:00:00 -0500
# 906342    NaN  2024-07-04 16:21:12 -0500  2024-07-04 14:00:00 -0500
# 906577    NaN  2024-07-16 17:28:49 -0500  2024-07-16 07:00:00 -0500
#
#                           endDate                               value  \
# 0       2023-09-17 10:41:20 -0500                                5.25
# 10      2022-09-20 09:55:06 -0500                                 110
# 11      2023-09-17 10:41:20 -0500                                 110
# 133140  2021-01-23 13:10:23 -0500                                  48
# 133141  2021-01-23 15:29:14 -0500                                  23
# ...                           ...                                 ...
# 900239  2024-10-28 05:00:22 -0500   HKCategoryValueSleepAnalysisInBed
# 903662  2024-02-15 16:00:00 -0500  HKCategoryValueAppleStandHourStood
# 906341  2024-07-04 15:00:00 -0500  HKCategoryValueAppleStandHourStood
# 906342  2024-07-04 15:00:00 -0500  HKCategoryValueAppleStandHourStood
# 906577  2024-07-16 08:00:00 -0500  HKCategoryValueAppleStandHourStood
#
#                                                    device
# 0                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 133140  <<HKDevice: 0x3018d51d0>, name:iPhone, manufac...
# 133141  <<HKDevice: 0x3018d51d0>, name:iPhone, manufac...
# ...                                                   ...
# 900239                                                NaN
# 903662                                                NaN
# 906341                                                NaN
# 906342                                                NaN
# 906577                                                NaN
#
# [160729 rows x 9 columns]

# %%
records_df.loc[records_df['sourceName'] == "iPhone"]
# Out:
#                                                   type sourceName  \
# 102992               HKQuantityTypeIdentifierStepCount     iPhone
# 102993               HKQuantityTypeIdentifierStepCount     iPhone
# 102994               HKQuantityTypeIdentifierStepCount     iPhone
# 102995               HKQuantityTypeIdentifierStepCount     iPhone
# 102996               HKQuantityTypeIdentifierStepCount     iPhone
# ...                                                ...        ...
# 224884  HKQuantityTypeIdentifierDistanceWalkingRunning     iPhone
# 224885  HKQuantityTypeIdentifierDistanceWalkingRunning     iPhone
# 224886  HKQuantityTypeIdentifierDistanceWalkingRunning     iPhone
# 224887  HKQuantityTypeIdentifierDistanceWalkingRunning     iPhone
# 224888  HKQuantityTypeIdentifierDistanceWalkingRunning     iPhone
#
#        sourceVersion   unit               creationDate  \
# 102992        11.2.6  count  2018-02-20 21:23:38 -0500
# 102993        11.2.6  count  2018-02-21 14:51:45 -0500
# 102994        11.2.6  count  2018-02-21 15:47:20 -0500
# 102995        11.2.6  count  2018-02-21 15:47:20 -0500
# 102996        11.2.6  count  2018-02-21 15:47:20 -0500
# ...              ...    ...                        ...
# 224884          14.2     mi  2021-01-04 15:53:25 -0500
# 224885          14.2     mi  2021-01-04 16:19:25 -0500
# 224886          14.2     mi  2021-01-04 16:59:50 -0500
# 224887          14.2     mi  2021-01-04 18:06:36 -0500
# 224888          14.2     mi  2021-01-04 21:19:22 -0500
#
#                         startDate                    endDate       value  \
# 102992  2018-02-20 21:06:51 -0500  2018-02-20 21:16:15 -0500          55
# 102993  2018-02-21 07:35:04 -0500  2018-02-21 07:38:28 -0500           8
# 102994  2018-02-21 14:44:13 -0500  2018-02-21 14:53:54 -0500          24
# 102995  2018-02-21 14:53:54 -0500  2018-02-21 15:03:35 -0500         266
# 102996  2018-02-21 15:03:35 -0500  2018-02-21 15:13:25 -0500          44
# ...                           ...                        ...         ...
# 224884  2021-01-04 15:42:25 -0500  2021-01-04 15:42:25 -0500  0.00961883
# 224885  2021-01-04 16:08:22 -0500  2021-01-04 16:15:27 -0500  0.00997922
# 224886  2021-01-04 16:46:54 -0500  2021-01-04 16:46:59 -0500  0.00560477
# 224887  2021-01-04 17:47:23 -0500  2021-01-04 17:55:27 -0500  0.00859978
# 224888  2021-01-04 21:01:23 -0500  2021-01-04 21:01:26 -0500  0.00382765
#
#                                                    device
# 102992  <<HKDevice: 0x301825810>, name:iPhone, manufac...
# 102993  <<HKDevice: 0x301825810>, name:iPhone, manufac...
# 102994  <<HKDevice: 0x301825810>, name:iPhone, manufac...
# 102995  <<HKDevice: 0x301825810>, name:iPhone, manufac...
# 102996  <<HKDevice: 0x301825810>, name:iPhone, manufac...
# ...                                                   ...
# 224884  <<HKDevice: 0x3018d47d0>, name:iPhone, manufac...
# 224885  <<HKDevice: 0x3018d47d0>, name:iPhone, manufac...
# 224886  <<HKDevice: 0x3018d47d0>, name:iPhone, manufac...
# 224887  <<HKDevice: 0x3018d47d0>, name:iPhone, manufac...
# 224888  <<HKDevice: 0x3018d47d0>, name:iPhone, manufac...
#
# [60102 rows x 9 columns]

# %%
records_df['device'].loc[102992]
# Out:
# '<<HKDevice: 0x301825810>, name:iPhone, manufacturer:Apple, model:iPhone, hardware:iPhone8,4, software:11.2.6, creation date:2018-02-21 01:23:27 +0000>'

# %%
records_df['device'].loc[133140]
# Out:
# '<<HKDevice: 0x3018d51d0>, name:iPhone, manufacturer:Apple Inc., model:iPhone, hardware:iPhone12,8, software:13.4.1, creation date:2021-01-23 18:00:29 +0000>'

# %%
workouts_df
# Out:
#                workoutActivityType           duration durationUnit  \
# 0       HKWorkoutActivityTypeOther                  0          min
# 1     HKWorkoutActivityTypeWalking  34.62768211166064          min
# 2     HKWorkoutActivityTypeRunning  17.38285479942958          min
# 3     HKWorkoutActivityTypeRunning  11.51686753034592          min
# 4    HKWorkoutActivityTypeSwimming   6.07142174243927          min
# ..                             ...                ...          ...
# 241   HKWorkoutActivityTypeRunning   9.06705576578776          min
# 242  HKWorkoutActivityTypeCooldown  28.62752670049667          min
# 243  HKWorkoutActivityTypeSwimming  77.92724243203799          min
# 244  HKWorkoutActivityTypeSwimming    62.294687606891          min
# 245  HKWorkoutActivityTypeSwimming  63.09930336872737          min
#
#                sourceName sourceVersion               creationDate  \
# 0                  Health        11.3.1  2018-06-29 14:38:15 -0500
# 1    Jannah’s Apple Watch           9.3  2023-09-17 17:26:39 -0500
# 2    Jannah’s Apple Watch           9.3  2023-09-18 18:24:44 -0500
# 3    Jannah’s Apple Watch           9.3  2023-09-21 15:01:49 -0500
# 4    Jannah’s Apple Watch           9.3  2023-09-26 15:56:23 -0500
# ..                    ...           ...                        ...
# 241  Jannah’s Apple Watch        10.6.1  2024-10-29 19:13:03 -0500
# 242  Jannah’s Apple Watch        10.6.1  2024-10-29 19:41:48 -0500
# 243  Jannah’s Apple Watch          11.0  2025-01-31 16:35:38 -0500
# 244  Jannah’s Apple Watch          11.0  2025-02-03 16:31:21 -0500
# 245  Jannah’s Apple Watch          11.0  2025-02-07 16:24:12 -0500
#
#                      startDate                    endDate  \
# 0    2018-06-29 14:37:00 -0500  2018-06-29 14:37:00 -0500
# 1    2023-09-17 16:51:58 -0500  2023-09-17 17:26:35 -0500
# 2    2023-09-18 18:07:19 -0500  2023-09-18 18:24:42 -0500
# 3    2023-09-21 14:50:17 -0500  2023-09-21 15:01:48 -0500
# 4    2023-09-26 15:50:18 -0500  2023-09-26 15:56:22 -0500
# ..                         ...                        ...
# 241  2024-10-29 19:03:58 -0500  2024-10-29 19:13:02 -0500
# 242  2024-10-29 19:13:09 -0500  2024-10-29 19:41:47 -0500
# 243  2025-01-31 15:17:39 -0500  2025-01-31 16:35:35 -0500
# 244  2025-02-03 15:29:01 -0500  2025-02-03 16:31:19 -0500
# 245  2025-02-07 15:21:04 -0500  2025-02-07 16:24:10 -0500
#
#                                                 device
# 0                                                  NaN
# 1    <<HKDevice: 0x30186e5d0>, name:Apple Watch, ma...
# 2    <<HKDevice: 0x30186e5d0>, name:Apple Watch, ma...
# 3    <<HKDevice: 0x30186e5d0>, name:Apple Watch, ma...
# 4    <<HKDevice: 0x30186e5d0>, name:Apple Watch, ma...
# ..                                                 ...
# 241  <<HKDevice: 0x301810280>, name:Apple Watch, ma...
# 242  <<HKDevice: 0x301810280>, name:Apple Watch, ma...
# 243  <<HKDevice: 0x301800e10>, name:Apple Watch, ma...
# 244  <<HKDevice: 0x301800e10>, name:Apple Watch, ma...
# 245  <<HKDevice: 0x301800e10>, name:Apple Watch, ma...
#
# [246 rows x 9 columns]

# %%
activity_summary_df
# Out:
#     dateComponents activeEnergyBurned activeEnergyBurnedGoal  \
# 0       2022-09-20             79.454                    240
# 1       2022-09-21             92.923                    240
# 2       2022-09-22            151.574                    240
# 3       2022-09-23             61.259                    240
# 4       2022-09-24             62.416                    240
# ..             ...                ...                    ...
# 797     2025-02-22            290.453                    270
# 798     2025-02-23            250.286                    270
# 799     2025-02-24            302.848                    270
# 800     2025-02-25            255.962                    270
# 801     2025-02-26             186.83                    270
#
#     activeEnergyBurnedUnit appleMoveTime appleMoveTimeGoal appleExerciseTime  \
# 0                      Cal             0                 0                 0
# 1                      Cal             0                 0                 0
# 2                      Cal             0                 0                 0
# 3                      Cal             0                 0                 0
# 4                      Cal             0                 0                 0
# ..                     ...           ...               ...               ...
# 797                    Cal             0                 0                 9
# 798                    Cal             0                 0                 5
# 799                    Cal             0                 0                 8
# 800                    Cal             0                 0                11
# 801                    Cal             0                 0                 4
#
#     appleExerciseTimeGoal appleStandHours appleStandHoursGoal
# 0                       0               0                   0
# 1                       0               0                   0
# 2                       0               0                   0
# 3                       0               0                   0
# 4                       0               0                   0
# ..                    ...             ...                 ...
# 797                    20              16                  12
# 798                    20              13                  12
# 799                    20              18                  12
# 800                    20              14                  12
# 801                    20              11                  12
#
# [802 rows x 10 columns]

# %% [markdown]
# **Analyze records_df**

# %%
records_df.head()
# Out:
#                                type            sourceName sourceVersion unit  \
# 0    HKQuantityTypeIdentifierHeight            iPhone (2)        16.6.1   ft
# 1    HKQuantityTypeIdentifierHeight  Jannah’s Apple Watch           9.3   ft
# 2  HKQuantityTypeIdentifierBodyMass                Health        11.2.6   lb
# 3  HKQuantityTypeIdentifierBodyMass                Health        11.2.6   lb
# 4  HKQuantityTypeIdentifierBodyMass                Health        11.2.6   lb
#
#                 creationDate                  startDate  \
# 0  2023-09-17 10:41:20 -0500  2023-09-17 10:41:20 -0500
# 1  2023-09-17 16:11:26 -0500  2023-09-17 16:11:26 -0500
# 2  2018-04-01 13:08:42 -0500  2018-04-01 13:08:00 -0500
# 3  2018-04-03 19:11:31 -0500  2018-04-03 19:11:00 -0500
# 4  2018-04-05 21:03:57 -0500  2018-04-05 21:03:00 -0500
#
#                      endDate value device
# 0  2023-09-17 10:41:20 -0500  5.25    NaN
# 1  2023-09-17 16:11:26 -0500  5.25    NaN
# 2  2018-04-01 13:08:00 -0500   120    NaN
# 3  2018-04-03 19:11:00 -0500   120    NaN
# 4  2018-04-05 21:03:00 -0500   120    NaN

# %%
records_df['type'].unique()
# Out:
# array(['HKQuantityTypeIdentifierHeight',
#        'HKQuantityTypeIdentifierBodyMass',
#        'HKQuantityTypeIdentifierHeartRate',
#        'HKQuantityTypeIdentifierRespiratoryRate',
#        'HKQuantityTypeIdentifierStepCount',
#        'HKQuantityTypeIdentifierDistanceWalkingRunning',
#        'HKQuantityTypeIdentifierBasalEnergyBurned',
#        'HKQuantityTypeIdentifierActiveEnergyBurned',
#        'HKQuantityTypeIdentifierFlightsClimbed',
#        'HKQuantityTypeIdentifierAppleExerciseTime',
#        'HKQuantityTypeIdentifierDistanceCycling',
#        'HKQuantityTypeIdentifierDistanceSwimming',
#        'HKQuantityTypeIdentifierSwimmingStrokeCount',
#        'HKQuantityTypeIdentifierRestingHeartRate',
#        'HKQuantityTypeIdentifierVO2Max',
#        'HKQuantityTypeIdentifierWalkingHeartRateAverage',
#        'HKQuantityTypeIdentifierEnvironmentalAudioExposure',
#        'HKQuantityTypeIdentifierHeadphoneAudioExposure',
#        'HKQuantityTypeIdentifierWalkingDoubleSupportPercentage',
#        'HKQuantityTypeIdentifierSixMinuteWalkTestDistance',
#        'HKQuantityTypeIdentifierAppleStandTime',
#        'HKQuantityTypeIdentifierWalkingSpeed',
#        'HKQuantityTypeIdentifierWalkingStepLength',
#        'HKQuantityTypeIdentifierWalkingAsymmetryPercentage',
#        'HKQuantityTypeIdentifierStairAscentSpeed',
#        'HKQuantityTypeIdentifierStairDescentSpeed',
#        'HKDataTypeSleepDurationGoal',
#        'HKQuantityTypeIdentifierAppleWalkingSteadiness',
#        'HKQuantityTypeIdentifierTimeInDaylight',
#        'HKQuantityTypeIdentifierPhysicalEffort',
#        'HKCategoryTypeIdentifierSleepAnalysis',
#        'HKCategoryTypeIdentifierAppleStandHour',
#        'HKCategoryTypeIdentifierMenstrualFlow',
#        'HKCategoryTypeIdentifierMindfulSession',
#        'HKCategoryTypeIdentifierAudioExposureEvent',
#        'HKQuantityTypeIdentifierHeartRateVariabilitySDNN'], dtype=object)

# %%
records_df.duplicated(keep = 'first')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 911267    False
# 911268    False
# 911269    False
# 911270    False
# 911271    False
# Length: 911272, dtype: bool

# %% [markdown]
# #OK no duplicates

# %%
records_df.isnull().sum()
# Out:
# type                  0
# sourceName            0
# sourceVersion        56
# unit              20074
# creationDate          0
# startDate             0
# endDate               0
# value                 0
# device           203031
# dtype: int64

# %%
df_expanded = records_df['device'].str.extract(r'hardware:([\w\d,]+)')
df_expanded = df_expanded[0].str.rstrip(',')
df_expanded
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#             ...
# 911267    Watch6,10
# 911268    Watch6,10
# 911269    Watch6,10
# 911270    Watch6,10
# 911271    Watch6,10
# Name: 0, Length: 911272, dtype: object

# %%
df_expanded = df_expanded.to_frame(name='d_Type')
df_expanded
# Out:
#            d_Type
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 911267  Watch6,10
# 911268  Watch6,10
# 911269  Watch6,10
# 911270  Watch6,10
# 911271  Watch6,10
#
# [911272 rows x 1 columns]

# %%
df_expanded['d_Type'].unique()
# Out:
# array([nan, 'Watch6,14', 'Watch6,10', 'iPhone8,4', 'iPhone6,1',
#        'iPhone12,8'], dtype=object)

# %% [markdown]
# #Replace current device column with new one from a dataframe.

# %%
records_df = records_df.join(df_expanded)
records_df
# Out:
#                                                     type  \
# 0                         HKQuantityTypeIdentifierHeight
# 1                         HKQuantityTypeIdentifierHeight
# 2                       HKQuantityTypeIdentifierBodyMass
# 3                       HKQuantityTypeIdentifierBodyMass
# 4                       HKQuantityTypeIdentifierBodyMass
# ...                                                  ...
# 911267  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911268  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911269  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911270  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911271  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
#
#                   sourceName sourceVersion unit               creationDate  \
# 0                 iPhone (2)        16.6.1   ft  2023-09-17 10:41:20 -0500
# 1       Jannah’s Apple Watch           9.3   ft  2023-09-17 16:11:26 -0500
# 2                     Health        11.2.6   lb  2018-04-01 13:08:42 -0500
# 3                     Health        11.2.6   lb  2018-04-03 19:11:31 -0500
# 4                     Health        11.2.6   lb  2018-04-05 21:03:57 -0500
# ...                      ...           ...  ...                        ...
# 911267  Jannah’s Apple Watch          11.0   ms  2025-02-25 21:29:58 -0500
# 911268  Jannah’s Apple Watch          11.0   ms  2025-02-26 06:45:04 -0500
# 911269  Jannah’s Apple Watch          11.0   ms  2025-02-26 07:57:41 -0500
# 911270  Jannah’s Apple Watch          11.0   ms  2025-02-26 13:43:06 -0500
# 911271  Jannah’s Apple Watch          11.0   ms  2025-02-26 15:09:12 -0500
#
#                         startDate                    endDate    value  \
# 0       2023-09-17 10:41:20 -0500  2023-09-17 10:41:20 -0500     5.25
# 1       2023-09-17 16:11:26 -0500  2023-09-17 16:11:26 -0500     5.25
# 2       2018-04-01 13:08:00 -0500  2018-04-01 13:08:00 -0500      120
# 3       2018-04-03 19:11:00 -0500  2018-04-03 19:11:00 -0500      120
# 4       2018-04-05 21:03:00 -0500  2018-04-05 21:03:00 -0500      120
# ...                           ...                        ...      ...
# 911267  2025-02-25 21:28:57 -0500  2025-02-25 21:29:54 -0500  144.231
# 911268  2025-02-26 06:44:03 -0500  2025-02-26 06:45:03 -0500  120.072
# 911269  2025-02-26 07:56:40 -0500  2025-02-26 07:57:39 -0500  38.8269
# 911270  2025-02-26 13:42:05 -0500  2025-02-26 13:43:04 -0500  39.7098
# 911271  2025-02-26 15:08:11 -0500  2025-02-26 15:09:11 -0500  27.7803
#
#                                                    device     d_Type
# 0                                                     NaN        NaN
# 1                                                     NaN        NaN
# 2                                                     NaN        NaN
# 3                                                     NaN        NaN
# 4                                                     NaN        NaN
# ...                                                   ...        ...
# 911267  <<HKDevice: 0x30186d040>, name:Apple Watch, ma...  Watch6,10
# 911268  <<HKDevice: 0x30186d040>, name:Apple Watch, ma...  Watch6,10
# 911269  <<HKDevice: 0x30186d040>, name:Apple Watch, ma...  Watch6,10
# 911270  <<HKDevice: 0x30186d040>, name:Apple Watch, ma...  Watch6,10
# 911271  <<HKDevice: 0x30186d040>, name:Apple Watch, ma...  Watch6,10
#
# [911272 rows x 10 columns]

# %%
records_df.drop(columns = ['device'], inplace = True)
records_df
# Out:
#                                                     type  \
# 0                         HKQuantityTypeIdentifierHeight
# 1                         HKQuantityTypeIdentifierHeight
# 2                       HKQuantityTypeIdentifierBodyMass
# 3                       HKQuantityTypeIdentifierBodyMass
# 4                       HKQuantityTypeIdentifierBodyMass
# ...                                                  ...
# 911267  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911268  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911269  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911270  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911271  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
#
#                   sourceName sourceVersion unit               creationDate  \
# 0                 iPhone (2)        16.6.1   ft  2023-09-17 10:41:20 -0500
# 1       Jannah’s Apple Watch           9.3   ft  2023-09-17 16:11:26 -0500
# 2                     Health        11.2.6   lb  2018-04-01 13:08:42 -0500
# 3                     Health        11.2.6   lb  2018-04-03 19:11:31 -0500
# 4                     Health        11.2.6   lb  2018-04-05 21:03:57 -0500
# ...                      ...           ...  ...                        ...
# 911267  Jannah’s Apple Watch          11.0   ms  2025-02-25 21:29:58 -0500
# 911268  Jannah’s Apple Watch          11.0   ms  2025-02-26 06:45:04 -0500
# 911269  Jannah’s Apple Watch          11.0   ms  2025-02-26 07:57:41 -0500
# 911270  Jannah’s Apple Watch          11.0   ms  2025-02-26 13:43:06 -0500
# 911271  Jannah’s Apple Watch          11.0   ms  2025-02-26 15:09:12 -0500
#
#                         startDate                    endDate    value  \
# 0       2023-09-17 10:41:20 -0500  2023-09-17 10:41:20 -0500     5.25
# 1       2023-09-17 16:11:26 -0500  2023-09-17 16:11:26 -0500     5.25
# 2       2018-04-01 13:08:00 -0500  2018-04-01 13:08:00 -0500      120
# 3       2018-04-03 19:11:00 -0500  2018-04-03 19:11:00 -0500      120
# 4       2018-04-05 21:03:00 -0500  2018-04-05 21:03:00 -0500      120
# ...                           ...                        ...      ...
# 911267  2025-02-25 21:28:57 -0500  2025-02-25 21:29:54 -0500  144.231
# 911268  2025-02-26 06:44:03 -0500  2025-02-26 06:45:03 -0500  120.072
# 911269  2025-02-26 07:56:40 -0500  2025-02-26 07:57:39 -0500  38.8269
# 911270  2025-02-26 13:42:05 -0500  2025-02-26 13:43:04 -0500  39.7098
# 911271  2025-02-26 15:08:11 -0500  2025-02-26 15:09:11 -0500  27.7803
#
#            d_Type
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 911267  Watch6,10
# 911268  Watch6,10
# 911269  Watch6,10
# 911270  Watch6,10
# 911271  Watch6,10
#
# [911272 rows x 9 columns]

# %%
records_df.rename(columns = {'d_Type':'device'}, inplace = True)
records_df
# Out:
#                                                     type  \
# 0                         HKQuantityTypeIdentifierHeight
# 1                         HKQuantityTypeIdentifierHeight
# 2                       HKQuantityTypeIdentifierBodyMass
# 3                       HKQuantityTypeIdentifierBodyMass
# 4                       HKQuantityTypeIdentifierBodyMass
# ...                                                  ...
# 911267  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911268  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911269  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911270  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911271  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
#
#                   sourceName sourceVersion unit               creationDate  \
# 0                 iPhone (2)        16.6.1   ft  2023-09-17 10:41:20 -0500
# 1       Jannah’s Apple Watch           9.3   ft  2023-09-17 16:11:26 -0500
# 2                     Health        11.2.6   lb  2018-04-01 13:08:42 -0500
# 3                     Health        11.2.6   lb  2018-04-03 19:11:31 -0500
# 4                     Health        11.2.6   lb  2018-04-05 21:03:57 -0500
# ...                      ...           ...  ...                        ...
# 911267  Jannah’s Apple Watch          11.0   ms  2025-02-25 21:29:58 -0500
# 911268  Jannah’s Apple Watch          11.0   ms  2025-02-26 06:45:04 -0500
# 911269  Jannah’s Apple Watch          11.0   ms  2025-02-26 07:57:41 -0500
# 911270  Jannah’s Apple Watch          11.0   ms  2025-02-26 13:43:06 -0500
# 911271  Jannah’s Apple Watch          11.0   ms  2025-02-26 15:09:12 -0500
#
#                         startDate                    endDate    value  \
# 0       2023-09-17 10:41:20 -0500  2023-09-17 10:41:20 -0500     5.25
# 1       2023-09-17 16:11:26 -0500  2023-09-17 16:11:26 -0500     5.25
# 2       2018-04-01 13:08:00 -0500  2018-04-01 13:08:00 -0500      120
# 3       2018-04-03 19:11:00 -0500  2018-04-03 19:11:00 -0500      120
# 4       2018-04-05 21:03:00 -0500  2018-04-05 21:03:00 -0500      120
# ...                           ...                        ...      ...
# 911267  2025-02-25 21:28:57 -0500  2025-02-25 21:29:54 -0500  144.231
# 911268  2025-02-26 06:44:03 -0500  2025-02-26 06:45:03 -0500  120.072
# 911269  2025-02-26 07:56:40 -0500  2025-02-26 07:57:39 -0500  38.8269
# 911270  2025-02-26 13:42:05 -0500  2025-02-26 13:43:04 -0500  39.7098
# 911271  2025-02-26 15:08:11 -0500  2025-02-26 15:09:11 -0500  27.7803
#
#            device
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 911267  Watch6,10
# 911268  Watch6,10
# 911269  Watch6,10
# 911270  Watch6,10
# 911271  Watch6,10
#
# [911272 rows x 9 columns]

# %%
records_df.dropna(subset = ['device'], inplace = True)
records_df
# Out:
#                                                     type  \
# 13                     HKQuantityTypeIdentifierHeartRate
# 14                     HKQuantityTypeIdentifierHeartRate
# 15                     HKQuantityTypeIdentifierHeartRate
# 16                     HKQuantityTypeIdentifierHeartRate
# 17                     HKQuantityTypeIdentifierHeartRate
# ...                                                  ...
# 911267  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911268  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911269  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911270  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911271  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
#
#                   sourceName sourceVersion       unit  \
# 13      Jannah’s Apple Watch           9.3  count/min
# 14      Jannah’s Apple Watch           9.3  count/min
# 15      Jannah’s Apple Watch           9.3  count/min
# 16      Jannah’s Apple Watch           9.3  count/min
# 17      Jannah’s Apple Watch           9.3  count/min
# ...                      ...           ...        ...
# 911267  Jannah’s Apple Watch          11.0         ms
# 911268  Jannah’s Apple Watch          11.0         ms
# 911269  Jannah’s Apple Watch          11.0         ms
# 911270  Jannah’s Apple Watch          11.0         ms
# 911271  Jannah’s Apple Watch          11.0         ms
#
#                      creationDate                  startDate  \
# 13      2023-09-17 10:44:10 -0500  2023-09-17 10:42:00 -0500
# 14      2023-09-17 10:45:48 -0500  2023-09-17 10:45:47 -0500
# 15      2023-09-17 10:48:58 -0500  2023-09-17 10:47:40 -0500
# 16      2023-09-17 10:50:02 -0500  2023-09-17 10:47:48 -0500
# 17      2023-09-17 10:57:10 -0500  2023-09-17 10:56:18 -0500
# ...                           ...                        ...
# 911267  2025-02-25 21:29:58 -0500  2025-02-25 21:28:57 -0500
# 911268  2025-02-26 06:45:04 -0500  2025-02-26 06:44:03 -0500
# 911269  2025-02-26 07:57:41 -0500  2025-02-26 07:56:40 -0500
# 911270  2025-02-26 13:43:06 -0500  2025-02-26 13:42:05 -0500
# 911271  2025-02-26 15:09:12 -0500  2025-02-26 15:08:11 -0500
#
#                           endDate    value     device
# 13      2023-09-17 10:42:00 -0500       71  Watch6,14
# 14      2023-09-17 10:45:47 -0500      104  Watch6,14
# 15      2023-09-17 10:47:40 -0500  63.4445  Watch6,14
# 16      2023-09-17 10:47:48 -0500       55  Watch6,14
# 17      2023-09-17 10:56:18 -0500      106  Watch6,14
# ...                           ...      ...        ...
# 911267  2025-02-25 21:29:54 -0500  144.231  Watch6,10
# 911268  2025-02-26 06:45:03 -0500  120.072  Watch6,10
# 911269  2025-02-26 07:57:39 -0500  38.8269  Watch6,10
# 911270  2025-02-26 13:43:04 -0500  39.7098  Watch6,10
# 911271  2025-02-26 15:09:11 -0500  27.7803  Watch6,10
#
# [707848 rows x 9 columns]

# %% [markdown]
# #I don't really care about source version so lets drop it!

# %%
records_df.drop('sourceVersion', axis = 1, inplace = True)
records_df
# Out:
#                                                     type  \
# 13                     HKQuantityTypeIdentifierHeartRate
# 14                     HKQuantityTypeIdentifierHeartRate
# 15                     HKQuantityTypeIdentifierHeartRate
# 16                     HKQuantityTypeIdentifierHeartRate
# 17                     HKQuantityTypeIdentifierHeartRate
# ...                                                  ...
# 911267  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911268  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911269  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911270  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911271  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
#
#                   sourceName       unit               creationDate  \
# 13      Jannah’s Apple Watch  count/min  2023-09-17 10:44:10 -0500
# 14      Jannah’s Apple Watch  count/min  2023-09-17 10:45:48 -0500
# 15      Jannah’s Apple Watch  count/min  2023-09-17 10:48:58 -0500
# 16      Jannah’s Apple Watch  count/min  2023-09-17 10:50:02 -0500
# 17      Jannah’s Apple Watch  count/min  2023-09-17 10:57:10 -0500
# ...                      ...        ...                        ...
# 911267  Jannah’s Apple Watch         ms  2025-02-25 21:29:58 -0500
# 911268  Jannah’s Apple Watch         ms  2025-02-26 06:45:04 -0500
# 911269  Jannah’s Apple Watch         ms  2025-02-26 07:57:41 -0500
# 911270  Jannah’s Apple Watch         ms  2025-02-26 13:43:06 -0500
# 911271  Jannah’s Apple Watch         ms  2025-02-26 15:09:12 -0500
#
#                         startDate                    endDate    value  \
# 13      2023-09-17 10:42:00 -0500  2023-09-17 10:42:00 -0500       71
# 14      2023-09-17 10:45:47 -0500  2023-09-17 10:45:47 -0500      104
# 15      2023-09-17 10:47:40 -0500  2023-09-17 10:47:40 -0500  63.4445
# 16      2023-09-17 10:47:48 -0500  2023-09-17 10:47:48 -0500       55
# 17      2023-09-17 10:56:18 -0500  2023-09-17 10:56:18 -0500      106
# ...                           ...                        ...      ...
# 911267  2025-02-25 21:28:57 -0500  2025-02-25 21:29:54 -0500  144.231
# 911268  2025-02-26 06:44:03 -0500  2025-02-26 06:45:03 -0500  120.072
# 911269  2025-02-26 07:56:40 -0500  2025-02-26 07:57:39 -0500  38.8269
# 911270  2025-02-26 13:42:05 -0500  2025-02-26 13:43:04 -0500  39.7098
# 911271  2025-02-26 15:08:11 -0500  2025-02-26 15:09:11 -0500  27.7803
#
#            device
# 13      Watch6,14
# 14      Watch6,14
# 15      Watch6,14
# 16      Watch6,14
# 17      Watch6,14
# ...           ...
# 911267  Watch6,10
# 911268  Watch6,10
# 911269  Watch6,10
# 911270  Watch6,10
# 911271  Watch6,10
#
# [707848 rows x 8 columns]

# %% [markdown]
# #Since there are missing unit values, i think the best option is removing the missing units because what good is a value without the unit to differentiate it

# %%
records_df.isnull().sum()
# Out:
# type               0
# sourceName         0
# unit            8445
# creationDate       0
# startDate          0
# endDate            0
# value              0
# device             0
# dtype: int64

# %%
#drop rows where unit is null
records_df.dropna(subset=['unit'], axis = 0, inplace = True)
records_df
# Out:
#                                                     type  \
# 13                     HKQuantityTypeIdentifierHeartRate
# 14                     HKQuantityTypeIdentifierHeartRate
# 15                     HKQuantityTypeIdentifierHeartRate
# 16                     HKQuantityTypeIdentifierHeartRate
# 17                     HKQuantityTypeIdentifierHeartRate
# ...                                                  ...
# 911267  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911268  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911269  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911270  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911271  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
#
#                   sourceName       unit               creationDate  \
# 13      Jannah’s Apple Watch  count/min  2023-09-17 10:44:10 -0500
# 14      Jannah’s Apple Watch  count/min  2023-09-17 10:45:48 -0500
# 15      Jannah’s Apple Watch  count/min  2023-09-17 10:48:58 -0500
# 16      Jannah’s Apple Watch  count/min  2023-09-17 10:50:02 -0500
# 17      Jannah’s Apple Watch  count/min  2023-09-17 10:57:10 -0500
# ...                      ...        ...                        ...
# 911267  Jannah’s Apple Watch         ms  2025-02-25 21:29:58 -0500
# 911268  Jannah’s Apple Watch         ms  2025-02-26 06:45:04 -0500
# 911269  Jannah’s Apple Watch         ms  2025-02-26 07:57:41 -0500
# 911270  Jannah’s Apple Watch         ms  2025-02-26 13:43:06 -0500
# 911271  Jannah’s Apple Watch         ms  2025-02-26 15:09:12 -0500
#
#                         startDate                    endDate    value  \
# 13      2023-09-17 10:42:00 -0500  2023-09-17 10:42:00 -0500       71
# 14      2023-09-17 10:45:47 -0500  2023-09-17 10:45:47 -0500      104
# 15      2023-09-17 10:47:40 -0500  2023-09-17 10:47:40 -0500  63.4445
# 16      2023-09-17 10:47:48 -0500  2023-09-17 10:47:48 -0500       55
# 17      2023-09-17 10:56:18 -0500  2023-09-17 10:56:18 -0500      106
# ...                           ...                        ...      ...
# 911267  2025-02-25 21:28:57 -0500  2025-02-25 21:29:54 -0500  144.231
# 911268  2025-02-26 06:44:03 -0500  2025-02-26 06:45:03 -0500  120.072
# 911269  2025-02-26 07:56:40 -0500  2025-02-26 07:57:39 -0500  38.8269
# 911270  2025-02-26 13:42:05 -0500  2025-02-26 13:43:04 -0500  39.7098
# 911271  2025-02-26 15:08:11 -0500  2025-02-26 15:09:11 -0500  27.7803
#
#            device
# 13      Watch6,14
# 14      Watch6,14
# 15      Watch6,14
# 16      Watch6,14
# 17      Watch6,14
# ...           ...
# 911267  Watch6,10
# 911268  Watch6,10
# 911269  Watch6,10
# 911270  Watch6,10
# 911271  Watch6,10
#
# [699403 rows x 8 columns]

# %%
records_df.isnull().sum()
# Out:
# type            0
# sourceName      0
# unit            0
# creationDate    0
# startDate       0
# endDate         0
# value           0
# device          0
# dtype: int64

# %% [markdown]
# #Now that the data preprocessing is done, lets find out what device Jannah records her data on the most and make a visual about it

# %%
totalSource = records_df['device'].value_counts()
totalSource
# Out:
# device
# Watch6,14     439302
# iPhone12,8    159699
# iPhone8,4      41578
# Watch6,10      40300
# iPhone6,1      18524
# Name: count, dtype: int64

# %%
plotSource = totalSource.plot.pie(y='sourceName', figsize=(10, 10), autopct='%1.1f%%')
plt.ylabel('')
plt.xlabel('')
plt.title('Jannah\'s Workout Devices')
plt.show()

# %% [markdown]
# #Jannah records most of her data on the Apple Watch the most!

# %% [markdown]
# #Lets explore the other data in this dataframe

# %%
records_df
# Out:
#                                                     type  \
# 13                     HKQuantityTypeIdentifierHeartRate
# 14                     HKQuantityTypeIdentifierHeartRate
# 15                     HKQuantityTypeIdentifierHeartRate
# 16                     HKQuantityTypeIdentifierHeartRate
# 17                     HKQuantityTypeIdentifierHeartRate
# ...                                                  ...
# 911267  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911268  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911269  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911270  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911271  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
#
#                   sourceName       unit               creationDate  \
# 13      Jannah’s Apple Watch  count/min  2023-09-17 10:44:10 -0500
# 14      Jannah’s Apple Watch  count/min  2023-09-17 10:45:48 -0500
# 15      Jannah’s Apple Watch  count/min  2023-09-17 10:48:58 -0500
# 16      Jannah’s Apple Watch  count/min  2023-09-17 10:50:02 -0500
# 17      Jannah’s Apple Watch  count/min  2023-09-17 10:57:10 -0500
# ...                      ...        ...                        ...
# 911267  Jannah’s Apple Watch         ms  2025-02-25 21:29:58 -0500
# 911268  Jannah’s Apple Watch         ms  2025-02-26 06:45:04 -0500
# 911269  Jannah’s Apple Watch         ms  2025-02-26 07:57:41 -0500
# 911270  Jannah’s Apple Watch         ms  2025-02-26 13:43:06 -0500
# 911271  Jannah’s Apple Watch         ms  2025-02-26 15:09:12 -0500
#
#                         startDate                    endDate    value  \
# 13      2023-09-17 10:42:00 -0500  2023-09-17 10:42:00 -0500       71
# 14      2023-09-17 10:45:47 -0500  2023-09-17 10:45:47 -0500      104
# 15      2023-09-17 10:47:40 -0500  2023-09-17 10:47:40 -0500  63.4445
# 16      2023-09-17 10:47:48 -0500  2023-09-17 10:47:48 -0500       55
# 17      2023-09-17 10:56:18 -0500  2023-09-17 10:56:18 -0500      106
# ...                           ...                        ...      ...
# 911267  2025-02-25 21:28:57 -0500  2025-02-25 21:29:54 -0500  144.231
# 911268  2025-02-26 06:44:03 -0500  2025-02-26 06:45:03 -0500  120.072
# 911269  2025-02-26 07:56:40 -0500  2025-02-26 07:57:39 -0500  38.8269
# 911270  2025-02-26 13:42:05 -0500  2025-02-26 13:43:04 -0500  39.7098
# 911271  2025-02-26 15:08:11 -0500  2025-02-26 15:09:11 -0500  27.7803
#
#            device
# 13      Watch6,14
# 14      Watch6,14
# 15      Watch6,14
# 16      Watch6,14
# 17      Watch6,14
# ...           ...
# 911267  Watch6,10
# 911268  Watch6,10
# 911269  Watch6,10
# 911270  Watch6,10
# 911271  Watch6,10
#
# [699403 rows x 8 columns]

# %%
records_df['type'].unique()
# Out:
# array(['HKQuantityTypeIdentifierHeartRate',
#        'HKQuantityTypeIdentifierRespiratoryRate',
#        'HKQuantityTypeIdentifierStepCount',
#        'HKQuantityTypeIdentifierDistanceWalkingRunning',
#        'HKQuantityTypeIdentifierBasalEnergyBurned',
#        'HKQuantityTypeIdentifierActiveEnergyBurned',
#        'HKQuantityTypeIdentifierFlightsClimbed',
#        'HKQuantityTypeIdentifierAppleExerciseTime',
#        'HKQuantityTypeIdentifierDistanceCycling',
#        'HKQuantityTypeIdentifierDistanceSwimming',
#        'HKQuantityTypeIdentifierSwimmingStrokeCount',
#        'HKQuantityTypeIdentifierEnvironmentalAudioExposure',
#        'HKQuantityTypeIdentifierWalkingDoubleSupportPercentage',
#        'HKQuantityTypeIdentifierWalkingSpeed',
#        'HKQuantityTypeIdentifierWalkingStepLength',
#        'HKQuantityTypeIdentifierWalkingAsymmetryPercentage',
#        'HKQuantityTypeIdentifierAppleWalkingSteadiness',
#        'HKQuantityTypeIdentifierTimeInDaylight',
#        'HKQuantityTypeIdentifierHeartRateVariabilitySDNN'], dtype=object)

# %% [markdown]
# #Grab rows with Heart Rate Identifier

# %%
heart_rate = records_df[records_df['type'] == 'HKQuantityTypeIdentifierHeartRate']
heart_rate
# Out:
#                                      type            sourceName       unit  \
# 13      HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# 14      HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# 15      HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# 16      HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# 17      HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# ...                                   ...                   ...        ...
# 102019  HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# 102020  HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# 102021  HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# 102022  HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# 102023  HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
#
#                      creationDate                  startDate  \
# 13      2023-09-17 10:44:10 -0500  2023-09-17 10:42:00 -0500
# 14      2023-09-17 10:45:48 -0500  2023-09-17 10:45:47 -0500
# 15      2023-09-17 10:48:58 -0500  2023-09-17 10:47:40 -0500
# 16      2023-09-17 10:50:02 -0500  2023-09-17 10:47:48 -0500
# 17      2023-09-17 10:57:10 -0500  2023-09-17 10:56:18 -0500
# ...                           ...                        ...
# 102019  2025-02-26 18:24:48 -0500  2025-02-26 18:21:35 -0500
# 102020  2025-02-26 18:29:45 -0500  2025-02-26 18:26:21 -0500
# 102021  2025-02-26 18:35:36 -0500  2025-02-26 18:31:44 -0500
# 102022  2025-02-26 18:39:16 -0500  2025-02-26 18:34:00 -0500
# 102023  2025-02-26 18:43:39 -0500  2025-02-26 18:42:10 -0500
#
#                           endDate    value     device
# 13      2023-09-17 10:42:00 -0500       71  Watch6,14
# 14      2023-09-17 10:45:47 -0500      104  Watch6,14
# 15      2023-09-17 10:47:40 -0500  63.4445  Watch6,14
# 16      2023-09-17 10:47:48 -0500       55  Watch6,14
# 17      2023-09-17 10:56:18 -0500      106  Watch6,14
# ...                           ...      ...        ...
# 102019  2025-02-26 18:21:35 -0500       80  Watch6,10
# 102020  2025-02-26 18:26:21 -0500       80  Watch6,10
# 102021  2025-02-26 18:31:44 -0500       77  Watch6,10
# 102022  2025-02-26 18:34:00 -0500       79  Watch6,10
# 102023  2025-02-26 18:42:10 -0500       80  Watch6,10
#
# [102011 rows x 8 columns]

# %%
heart_rate.dtypes
# Out:
# type            object
# sourceName      object
# unit            object
# creationDate    object
# startDate       object
# endDate         object
# value           object
# device          object
# dtype: object

# %% [markdown]
# #**Let's analyze her average heart rate! :)**

# %%
heart_rate['value'] = pd.to_numeric(heart_rate['value'], errors='coerce')
# Out:
# /tmp/ipykernel_4235/755980374.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heart_rate['value'] = pd.to_numeric(heart_rate['value'], errors='coerce')

# %% [markdown]
# #Jannah's average heart rate for all time!. I'd say its really healthy! **84 Count/Min**:

# %%
average_heart_rate_all_time = np.mean(heart_rate['value'])
average_heart_rate_all_time
# Out:
# np.float64(84.43259424375802)

# %% [markdown]
# #Let's find out Jannah's average heart rate for each specific day to see which days she works out the most and which ones shes just bed rotting

# %%
heart_rate['creationDate'] = pd.to_datetime(heart_rate['creationDate']).dt.date
heart_rate
# Out:
# /tmp/ipykernel_4235/4255072033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heart_rate['creationDate'] = pd.to_datetime(heart_rate['creationDate']).dt.date
#                                      type            sourceName       unit  \
# 13      HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# 14      HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# 15      HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# 16      HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# 17      HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# ...                                   ...                   ...        ...
# 102019  HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# 102020  HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# 102021  HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# 102022  HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
# 102023  HKQuantityTypeIdentifierHeartRate  Jannah’s Apple Watch  count/min
#
#        creationDate                  startDate                    endDate  \
# 13       2023-09-17  2023-09-17 10:42:00 -0500  2023-09-17 10:42:00 -0500
# 14       2023-09-17  2023-09-17 10:45:47 -0500  2023-09-17 10:45:47 -0500
# 15       2023-09-17  2023-09-17 10:47:40 -0500  2023-09-17 10:47:40 -0500
# 16       2023-09-17  2023-09-17 10:47:48 -0500  2023-09-17 10:47:48 -0500
# 17       2023-09-17  2023-09-17 10:56:18 -0500  2023-09-17 10:56:18 -0500
# ...             ...                        ...                        ...
# 102019   2025-02-26  2025-02-26 18:21:35 -0500  2025-02-26 18:21:35 -0500
# 102020   2025-02-26  2025-02-26 18:26:21 -0500  2025-02-26 18:26:21 -0500
# 102021   2025-02-26  2025-02-26 18:31:44 -0500  2025-02-26 18:31:44 -0500
# 102022   2025-02-26  2025-02-26 18:34:00 -0500  2025-02-26 18:34:00 -0500
# 102023   2025-02-26  2025-02-26 18:42:10 -0500  2025-02-26 18:42:10 -0500
#
#            value     device
# 13       71.0000  Watch6,14
# 14      104.0000  Watch6,14
# 15       63.4445  Watch6,14
# 16       55.0000  Watch6,14
# 17      106.0000  Watch6,14
# ...          ...        ...
# 102019   80.0000  Watch6,10
# 102020   80.0000  Watch6,10
# 102021   77.0000  Watch6,10
# 102022   79.0000  Watch6,10
# 102023   80.0000  Watch6,10
#
# [102011 rows x 8 columns]

# %%
heart_rate_per_day = heart_rate.groupby('creationDate')['value'].mean()
heart_rate_per_day
# Out:
# creationDate
# 2023-09-17    91.276707
# 2023-09-18    70.471606
# 2023-09-19    88.811479
# 2023-09-20    70.439298
# 2023-09-21    91.571834
#                 ...
# 2025-02-22    74.085098
# 2025-02-23    69.281119
# 2025-02-24    83.692484
# 2025-02-25    75.424273
# 2025-02-26    90.063698
# Name: value, Length: 457, dtype: float64

# %%
heart_rate_per_day = heart_rate_per_day.to_frame()
heart_rate_per_day
# Out:
#                   value
# creationDate
# 2023-09-17    91.276707
# 2023-09-18    70.471606
# 2023-09-19    88.811479
# 2023-09-20    70.439298
# 2023-09-21    91.571834
# ...                 ...
# 2025-02-22    74.085098
# 2025-02-23    69.281119
# 2025-02-24    83.692484
# 2025-02-25    75.424273
# 2025-02-26    90.063698
#
# [457 rows x 1 columns]

# %% [markdown]
# #Because there's so many unique values, lets just get the 10 largest values

# %%
largest_ten_heart_rate = heart_rate_per_day.nlargest(10, 'value')
largest_ten_heart_rate
# Out:
#                    value
# creationDate
# 2024-05-30    178.534000
# 2024-05-02    162.250000
# 2024-12-23    155.600800
# 2025-01-05    154.086600
# 2024-11-14    153.952400
# 2024-12-10    151.226000
# 2024-11-18    149.155500
# 2024-12-13    145.377333
# 2025-01-15    144.625500
# 2025-01-04    143.674500

# %%
import seaborn as sns
sns.barplot(data = largest_ten_heart_rate, x = 'creationDate', y = 'value', hue = 'creationDate', legend = False, palette= "viridis")
plt.title('Average Heart Rate Per Day')
plt.xlabel('Date')
plt.ylabel('Average Heart Rate')
plt.xticks(rotation = 90)
plt.figure(figsize=(12, 8))
plt.close()
plt.show()

# %% [markdown]
# #Dang Jannah, how the fuck did your heart rate get up to 175?!

# %% [markdown]
# #Grab rows with respritory rate

# %%
respritory_rate = records_df[records_df['type'] == 'HKQuantityTypeIdentifierRespiratoryRate']
respritory_rate
# Out:
#                                            type            sourceName  \
# 102024  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# 102025  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# 102026  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# 102027  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# 102028  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# ...                                         ...                   ...
# 102987  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# 102988  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# 102989  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# 102990  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# 102991  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
#
#              unit               creationDate                  startDate  \
# 102024  count/min  2025-01-27 06:02:53 -0500  2025-01-26 23:20:52 -0500
# 102025  count/min  2025-01-27 06:02:53 -0500  2025-01-26 23:32:22 -0500
# 102026  count/min  2025-01-27 06:02:53 -0500  2025-01-26 23:37:22 -0500
# 102027  count/min  2025-01-27 06:02:53 -0500  2025-01-26 23:51:52 -0500
# 102028  count/min  2025-01-27 06:02:53 -0500  2025-01-27 00:02:22 -0500
# ...           ...                        ...                        ...
# 102987  count/min  2025-02-23 06:23:24 -0500  2025-02-23 05:28:08 -0500
# 102988  count/min  2025-02-23 06:23:24 -0500  2025-02-23 05:38:08 -0500
# 102989  count/min  2025-02-23 06:23:24 -0500  2025-02-23 05:52:09 -0500
# 102990  count/min  2025-02-23 06:23:24 -0500  2025-02-23 06:04:09 -0500
# 102991  count/min  2025-02-23 06:23:24 -0500  2025-02-23 06:11:39 -0500
#
#                           endDate value     device
# 102024  2025-01-26 23:20:52 -0500    24  Watch6,10
# 102025  2025-01-26 23:32:22 -0500    23  Watch6,10
# 102026  2025-01-26 23:37:22 -0500    23  Watch6,10
# 102027  2025-01-26 23:51:52 -0500    14  Watch6,10
# 102028  2025-01-27 00:02:22 -0500    16  Watch6,10
# ...                           ...   ...        ...
# 102987  2025-02-23 05:28:08 -0500    15  Watch6,10
# 102988  2025-02-23 05:38:08 -0500    15  Watch6,10
# 102989  2025-02-23 05:52:09 -0500  15.5  Watch6,10
# 102990  2025-02-23 06:04:09 -0500    16  Watch6,10
# 102991  2025-02-23 06:11:39 -0500  15.5  Watch6,10
#
# [968 rows x 8 columns]

# %%
respritory_rate.dtypes
# Out:
# type            object
# sourceName      object
# unit            object
# creationDate    object
# startDate       object
# endDate         object
# value           object
# device          object
# dtype: object

# %%
respritory_rate['value'] = pd.to_numeric(respritory_rate['value'], errors='coerce')
# Out:
# /tmp/ipykernel_4235/846790443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   respritory_rate['value'] = pd.to_numeric(respritory_rate['value'], errors='coerce')

# %% [markdown]
# #Good god, your respritory rate is normal: 15.13 count/min

# %%
average_respritory_rate_all_time = np.mean(respritory_rate['value'])
average_respritory_rate_all_time
# Out:
# np.float64(15.133264462809917)

# %%
respritory_rate['creationDate'] = pd.to_datetime(respritory_rate['creationDate']).dt.date
respritory_rate
# Out:
# /tmp/ipykernel_4235/1888443391.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   respritory_rate['creationDate'] = pd.to_datetime(respritory_rate['creationDate']).dt.date
#                                            type            sourceName  \
# 102024  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# 102025  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# 102026  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# 102027  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# 102028  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# ...                                         ...                   ...
# 102987  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# 102988  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# 102989  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# 102990  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
# 102991  HKQuantityTypeIdentifierRespiratoryRate  Jannah’s Apple Watch
#
#              unit creationDate                  startDate  \
# 102024  count/min   2025-01-27  2025-01-26 23:20:52 -0500
# 102025  count/min   2025-01-27  2025-01-26 23:32:22 -0500
# 102026  count/min   2025-01-27  2025-01-26 23:37:22 -0500
# 102027  count/min   2025-01-27  2025-01-26 23:51:52 -0500
# 102028  count/min   2025-01-27  2025-01-27 00:02:22 -0500
# ...           ...          ...                        ...
# 102987  count/min   2025-02-23  2025-02-23 05:28:08 -0500
# 102988  count/min   2025-02-23  2025-02-23 05:38:08 -0500
# 102989  count/min   2025-02-23  2025-02-23 05:52:09 -0500
# 102990  count/min   2025-02-23  2025-02-23 06:04:09 -0500
# 102991  count/min   2025-02-23  2025-02-23 06:11:39 -0500
#
#                           endDate  value     device
# 102024  2025-01-26 23:20:52 -0500   24.0  Watch6,10
# 102025  2025-01-26 23:32:22 -0500   23.0  Watch6,10
# 102026  2025-01-26 23:37:22 -0500   23.0  Watch6,10
# 102027  2025-01-26 23:51:52 -0500   14.0  Watch6,10
# 102028  2025-01-27 00:02:22 -0500   16.0  Watch6,10
# ...                           ...    ...        ...
# 102987  2025-02-23 05:28:08 -0500   15.0  Watch6,10
# 102988  2025-02-23 05:38:08 -0500   15.0  Watch6,10
# 102989  2025-02-23 05:52:09 -0500   15.5  Watch6,10
# 102990  2025-02-23 06:04:09 -0500   16.0  Watch6,10
# 102991  2025-02-23 06:11:39 -0500   15.5  Watch6,10
#
# [968 rows x 8 columns]

# %%
respritory_rate_per_day = respritory_rate.groupby('creationDate')['value'].mean()
respritory_rate_per_day
# Out:
# creationDate
# 2025-01-27    16.075000
# 2025-01-28    15.200000
# 2025-01-29    16.000000
# 2025-01-30    15.276316
# 2025-01-31    15.636364
# 2025-02-01    16.481481
# 2025-02-02    15.666667
# 2025-02-03    14.983333
# 2025-02-04    16.025641
# 2025-02-06    15.020833
# 2025-02-08    15.345238
# 2025-02-09    15.570000
# 2025-02-10    14.928571
# 2025-02-11    14.513889
# 2025-02-12    14.609756
# 2025-02-13    14.723684
# 2025-02-14    14.805556
# 2025-02-15    14.546512
# 2025-02-16    14.802326
# 2025-02-17    15.000000
# 2025-02-18    14.819444
# 2025-02-19    14.975000
# 2025-02-20    14.702703
# 2025-02-21    14.557143
# 2025-02-22    14.514286
# 2025-02-23    15.104651
# Name: value, dtype: float64

# %%
respritory_rate_per_day = respritory_rate_per_day.to_frame()
respritory_rate_per_day
# Out:
#                   value
# creationDate
# 2025-01-27    16.075000
# 2025-01-28    15.200000
# 2025-01-29    16.000000
# 2025-01-30    15.276316
# 2025-01-31    15.636364
# 2025-02-01    16.481481
# 2025-02-02    15.666667
# 2025-02-03    14.983333
# 2025-02-04    16.025641
# 2025-02-06    15.020833
# 2025-02-08    15.345238
# 2025-02-09    15.570000
# 2025-02-10    14.928571
# 2025-02-11    14.513889
# 2025-02-12    14.609756
# 2025-02-13    14.723684
# 2025-02-14    14.805556
# 2025-02-15    14.546512
# 2025-02-16    14.802326
# 2025-02-17    15.000000
# 2025-02-18    14.819444
# 2025-02-19    14.975000
# 2025-02-20    14.702703
# 2025-02-21    14.557143
# 2025-02-22    14.514286
# 2025-02-23    15.104651

# %%
sns.barplot(data = respritory_rate_per_day, x = 'creationDate', y = 'value', hue = 'creationDate', legend = False, palette= "viridis")
plt.title('Average Respritory Rate Per Day')
plt.xlabel('Date')
plt.ylabel('Average Respritory Rate')
plt.xticks(rotation = 90)
plt.figure(figsize=(12, 8))
plt.close()
plt.show()

# %% [markdown]
# #Based on the graph above, its generally really normal

# %% [markdown]
# #Grab rows with Step Count

# %%
step_count = records_df[records_df['type'] == 'HKQuantityTypeIdentifierStepCount']
step_count
# Out:
#                                      type            sourceName   unit  \
# 102992  HKQuantityTypeIdentifierStepCount                iPhone  count
# 102993  HKQuantityTypeIdentifierStepCount                iPhone  count
# 102994  HKQuantityTypeIdentifierStepCount                iPhone  count
# 102995  HKQuantityTypeIdentifierStepCount                iPhone  count
# 102996  HKQuantityTypeIdentifierStepCount                iPhone  count
# ...                                   ...                   ...    ...
# 194930  HKQuantityTypeIdentifierStepCount  Jannah’s Apple Watch  count
# 194931  HKQuantityTypeIdentifierStepCount  Jannah’s Apple Watch  count
# 194932  HKQuantityTypeIdentifierStepCount  Jannah’s Apple Watch  count
# 194933  HKQuantityTypeIdentifierStepCount  Jannah’s Apple Watch  count
# 194934  HKQuantityTypeIdentifierStepCount  Jannah’s Apple Watch  count
#
#                      creationDate                  startDate  \
# 102992  2018-02-20 21:23:38 -0500  2018-02-20 21:06:51 -0500
# 102993  2018-02-21 14:51:45 -0500  2018-02-21 07:35:04 -0500
# 102994  2018-02-21 15:47:20 -0500  2018-02-21 14:44:13 -0500
# 102995  2018-02-21 15:47:20 -0500  2018-02-21 14:53:54 -0500
# 102996  2018-02-21 15:47:20 -0500  2018-02-21 15:03:35 -0500
# ...                           ...                        ...
# 194930  2025-02-26 19:02:06 -0500  2025-02-26 18:59:31 -0500
# 194931  2025-02-26 19:02:07 -0500  2025-02-26 19:00:01 -0500
# 194932  2025-02-26 19:05:37 -0500  2025-02-26 19:01:34 -0500
# 194933  2025-02-26 19:05:37 -0500  2025-02-26 19:02:50 -0500
# 194934  2025-02-26 19:36:21 -0500  2025-02-26 19:26:18 -0500
#
#                           endDate value     device
# 102992  2018-02-20 21:16:15 -0500    55  iPhone8,4
# 102993  2018-02-21 07:38:28 -0500     8  iPhone8,4
# 102994  2018-02-21 14:53:54 -0500    24  iPhone8,4
# 102995  2018-02-21 15:03:35 -0500   266  iPhone8,4
# 102996  2018-02-21 15:13:25 -0500    44  iPhone8,4
# ...                           ...   ...        ...
# 194930  2025-02-26 18:59:38 -0500     3  Watch6,10
# 194931  2025-02-26 19:00:53 -0500    16  Watch6,10
# 194932  2025-02-26 19:01:36 -0500     4  Watch6,10
# 194933  2025-02-26 19:02:55 -0500    22  Watch6,10
# 194934  2025-02-26 19:26:49 -0500    13  Watch6,10
#
# [91943 rows x 8 columns]

# %%
step_count.dtypes
# Out:
# type            object
# sourceName      object
# unit            object
# creationDate    object
# startDate       object
# endDate         object
# value           object
# device          object
# dtype: object

# %%
step_count['value'] = pd.to_numeric(step_count['value'], errors='coerce')
# Out:
# /tmp/ipykernel_4235/327123713.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   step_count['value'] = pd.to_numeric(step_count['value'], errors='coerce')

# %% [markdown]
# #Total step count all entires

# %%
sum_step_count_all_time = np.sum(step_count['value'])
sum_step_count_all_time
# Out:
# np.int64(12159096)

# %%
step_count['creationDate'] = pd.to_datetime(step_count['creationDate']).dt.date
step_count
# Out:
# /tmp/ipykernel_4235/2228490283.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   step_count['creationDate'] = pd.to_datetime(step_count['creationDate']).dt.date
#                                      type            sourceName   unit  \
# 102992  HKQuantityTypeIdentifierStepCount                iPhone  count
# 102993  HKQuantityTypeIdentifierStepCount                iPhone  count
# 102994  HKQuantityTypeIdentifierStepCount                iPhone  count
# 102995  HKQuantityTypeIdentifierStepCount                iPhone  count
# 102996  HKQuantityTypeIdentifierStepCount                iPhone  count
# ...                                   ...                   ...    ...
# 194930  HKQuantityTypeIdentifierStepCount  Jannah’s Apple Watch  count
# 194931  HKQuantityTypeIdentifierStepCount  Jannah’s Apple Watch  count
# 194932  HKQuantityTypeIdentifierStepCount  Jannah’s Apple Watch  count
# 194933  HKQuantityTypeIdentifierStepCount  Jannah’s Apple Watch  count
# 194934  HKQuantityTypeIdentifierStepCount  Jannah’s Apple Watch  count
#
#        creationDate                  startDate                    endDate  \
# 102992   2018-02-20  2018-02-20 21:06:51 -0500  2018-02-20 21:16:15 -0500
# 102993   2018-02-21  2018-02-21 07:35:04 -0500  2018-02-21 07:38:28 -0500
# 102994   2018-02-21  2018-02-21 14:44:13 -0500  2018-02-21 14:53:54 -0500
# 102995   2018-02-21  2018-02-21 14:53:54 -0500  2018-02-21 15:03:35 -0500
# 102996   2018-02-21  2018-02-21 15:03:35 -0500  2018-02-21 15:13:25 -0500
# ...             ...                        ...                        ...
# 194930   2025-02-26  2025-02-26 18:59:31 -0500  2025-02-26 18:59:38 -0500
# 194931   2025-02-26  2025-02-26 19:00:01 -0500  2025-02-26 19:00:53 -0500
# 194932   2025-02-26  2025-02-26 19:01:34 -0500  2025-02-26 19:01:36 -0500
# 194933   2025-02-26  2025-02-26 19:02:50 -0500  2025-02-26 19:02:55 -0500
# 194934   2025-02-26  2025-02-26 19:26:18 -0500  2025-02-26 19:26:49 -0500
#
#         value     device
# 102992     55  iPhone8,4
# 102993      8  iPhone8,4
# 102994     24  iPhone8,4
# 102995    266  iPhone8,4
# 102996     44  iPhone8,4
# ...       ...        ...
# 194930      3  Watch6,10
# 194931     16  Watch6,10
# 194932      4  Watch6,10
# 194933     22  Watch6,10
# 194934     13  Watch6,10
#
# [91943 rows x 8 columns]

# %%
step_count_per_day = step_count.groupby('creationDate')['value'].sum()
step_count_per_day
# Out:
# creationDate
# 2016-04-30      139
# 2016-05-04      804
# 2016-05-05     1942
# 2016-05-06      607
# 2016-05-07      417
#               ...
# 2025-02-22    12375
# 2025-02-23    12560
# 2025-02-24    11674
# 2025-02-25     8470
# 2025-02-26     8695
# Name: value, Length: 3075, dtype: int64

# %%
step_count_per_day = step_count_per_day.to_frame()
largest_ten_step_count = step_count_per_day.nlargest(10, 'value')
largest_ten_step_count
# Out:
#               value
# creationDate
# 2023-12-23    35891
# 2024-08-07    32912
# 2024-10-26    30847
# 2024-04-29    29457
# 2023-09-29    28980
# 2024-07-07    28830
# 2024-06-27    28627
# 2024-08-08    28545
# 2024-08-05    28392
# 2024-08-02    27333

# %% [markdown]
# #Dang, my sis is a workout machine

# %%
sns.barplot(data = largest_ten_step_count, x = 'creationDate', y = 'value', hue = 'creationDate', legend = False, palette= "viridis")
plt.title('Total Step Count Per Day')
plt.xlabel('Date')
plt.ylabel('Total Step Count')
plt.xticks(rotation = 90)
plt.figure(figsize=(12, 8))
plt.close()
plt.show()

# %% [markdown]
# #How many miles does jannah walk/run

# %%
runWalk = records_df[records_df['type'] == 'HKQuantityTypeIdentifierDistanceWalkingRunning']
runWalk
# Out:
#                                                   type            sourceName  \
# 194935  HKQuantityTypeIdentifierDistanceWalkingRunning                iPhone
# 194936  HKQuantityTypeIdentifierDistanceWalkingRunning                iPhone
# 194937  HKQuantityTypeIdentifierDistanceWalkingRunning                iPhone
# 194938  HKQuantityTypeIdentifierDistanceWalkingRunning                iPhone
# 194939  HKQuantityTypeIdentifierDistanceWalkingRunning                iPhone
# ...                                                ...                   ...
# 302573  HKQuantityTypeIdentifierDistanceWalkingRunning  Jannah’s Apple Watch
# 302574  HKQuantityTypeIdentifierDistanceWalkingRunning  Jannah’s Apple Watch
# 302575  HKQuantityTypeIdentifierDistanceWalkingRunning  Jannah’s Apple Watch
# 302576  HKQuantityTypeIdentifierDistanceWalkingRunning  Jannah’s Apple Watch
# 302577  HKQuantityTypeIdentifierDistanceWalkingRunning  Jannah’s Apple Watch
#
#        unit               creationDate                  startDate  \
# 194935   mi  2018-02-20 21:23:38 -0500  2018-02-20 21:06:51 -0500
# 194936   mi  2018-02-21 14:51:45 -0500  2018-02-21 07:35:04 -0500
# 194937   mi  2018-02-21 15:47:20 -0500  2018-02-21 14:44:13 -0500
# 194938   mi  2018-02-21 15:47:20 -0500  2018-02-21 14:53:54 -0500
# 194939   mi  2018-02-21 15:47:20 -0500  2018-02-21 15:03:35 -0500
# ...     ...                        ...                        ...
# 302573   mi  2025-02-26 19:02:06 -0500  2025-02-26 18:59:31 -0500
# 302574   mi  2025-02-26 19:02:07 -0500  2025-02-26 19:00:01 -0500
# 302575   mi  2025-02-26 19:05:37 -0500  2025-02-26 19:01:34 -0500
# 302576   mi  2025-02-26 19:05:37 -0500  2025-02-26 19:02:50 -0500
# 302577   mi  2025-02-26 19:36:21 -0500  2025-02-26 19:26:18 -0500
#
#                           endDate       value     device
# 194935  2018-02-20 21:16:15 -0500   0.0243515  iPhone8,4
# 194936  2018-02-21 07:38:28 -0500  0.00233636  iPhone8,4
# 194937  2018-02-21 14:53:54 -0500  0.00850036  iPhone8,4
# 194938  2018-02-21 15:03:35 -0500   0.0956539  iPhone8,4
# 194939  2018-02-21 15:13:25 -0500   0.0158574  iPhone8,4
# ...                           ...         ...        ...
# 302573  2025-02-26 18:59:38 -0500  0.00127272  Watch6,10
# 302574  2025-02-26 19:00:53 -0500  0.00678784  Watch6,10
# 302575  2025-02-26 19:01:36 -0500  0.00169696  Watch6,10
# 302576  2025-02-26 19:02:55 -0500  0.00977421  Watch6,10
# 302577  2025-02-26 19:26:49 -0500  0.00740435  Watch6,10
#
# [107642 rows x 8 columns]

# %%
runWalk['value'] = pd.to_numeric(runWalk['value'], errors='coerce')
# Out:
# /tmp/ipykernel_4235/3197075278.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runWalk['value'] = pd.to_numeric(runWalk['value'], errors='coerce')

# %% [markdown]
# #Total Run/Walk Distance for all Entries

# %%
sum_run_walk_all_time = np.sum(runWalk['value'])
sum_run_walk_all_time
# Out:
# np.float64(5107.0837965929)

# %%
runWalk['creationDate'] = pd.to_datetime(runWalk['creationDate']).dt.date
# Out:
# /tmp/ipykernel_4235/3566177166.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runWalk['creationDate'] = pd.to_datetime(runWalk['creationDate']).dt.date

# %%
runWalk_per_day = runWalk.groupby('creationDate')['value'].sum()
runWalk_per_day
# Out:
# creationDate
# 2016-04-30    0.063150
# 2016-05-04    0.405867
# 2016-05-05    0.939103
# 2016-05-06    0.307007
# 2016-05-07    0.182515
#                 ...
# 2025-02-22    5.560217
# 2025-02-23    5.044715
# 2025-02-24    4.774577
# 2025-02-25    3.404984
# 2025-02-26    3.344190
# Name: value, Length: 3075, dtype: float64

# %%
runWalk_per_day = runWalk_per_day.to_frame()
largest_ten_runWalk = runWalk_per_day.nlargest(10, 'value')
largest_ten_runWalk
# Out:
#                   value
# creationDate
# 2023-12-23    15.862423
# 2024-10-26    13.702995
# 2024-08-07    12.572978
# 2024-08-08    12.303890
# 2024-07-07    11.623984
# 2023-09-29    11.451871
# 2024-08-05    11.289909
# 2024-04-27    11.262063
# 2023-11-24    10.806247
# 2024-06-27    10.519572

# %% [markdown]
# #What happened on January 1st, 2024??

# %%
sns.barplot(data = largest_ten_runWalk, x = 'creationDate', y = 'value', hue = 'creationDate', legend = False, palette= "viridis")
plt.title('Total Running/Walking Distance Per Day')
plt.xlabel('Date')
plt.ylabel('Total Running/Walking Distance')
plt.xticks(rotation = 90)
plt.figure(figsize=(12, 8))
plt.close()
plt.show()

# %% [markdown]
# #Analyze Active Energy Burned

# %%
energyBurned = records_df[records_df['type'] == 'HKQuantityTypeIdentifierActiveEnergyBurned']
energyBurned
# Out:
#                                               type            sourceName unit  \
# 427430  HKQuantityTypeIdentifierActiveEnergyBurned            iPhone (2)  Cal
# 427431  HKQuantityTypeIdentifierActiveEnergyBurned            iPhone (2)  Cal
# 427432  HKQuantityTypeIdentifierActiveEnergyBurned            iPhone (2)  Cal
# 427433  HKQuantityTypeIdentifierActiveEnergyBurned            iPhone (2)  Cal
# 427434  HKQuantityTypeIdentifierActiveEnergyBurned            iPhone (2)  Cal
# ...                                            ...                   ...  ...
# 594135  HKQuantityTypeIdentifierActiveEnergyBurned  Jannah’s Apple Watch  Cal
# 594136  HKQuantityTypeIdentifierActiveEnergyBurned  Jannah’s Apple Watch  Cal
# 594137  HKQuantityTypeIdentifierActiveEnergyBurned  Jannah’s Apple Watch  Cal
# 594138  HKQuantityTypeIdentifierActiveEnergyBurned  Jannah’s Apple Watch  Cal
# 594139  HKQuantityTypeIdentifierActiveEnergyBurned  Jannah’s Apple Watch  Cal
#
#                      creationDate                  startDate  \
# 427430  2022-09-20 08:47:26 -0500  2022-09-19 09:14:26 -0500
# 427431  2022-09-20 08:47:26 -0500  2022-09-19 09:50:50 -0500
# 427432  2022-09-20 08:47:26 -0500  2022-09-19 11:37:01 -0500
# 427433  2022-09-20 08:47:26 -0500  2022-09-19 13:04:33 -0500
# 427434  2022-09-20 08:47:26 -0500  2022-09-19 13:15:01 -0500
# ...                           ...                        ...
# 594135  2025-02-26 19:09:00 -0500  2025-02-26 19:06:59 -0500
# 594136  2025-02-26 19:09:02 -0500  2025-02-26 19:08:31 -0500
# 594137  2025-02-26 19:21:26 -0500  2025-02-26 19:08:51 -0500
# 594138  2025-02-26 19:36:21 -0500  2025-02-26 19:20:28 -0500
# 594139  2025-02-26 19:36:21 -0500  2025-02-26 19:21:49 -0500
#
#                           endDate   value      device
# 427430  2022-09-19 09:22:12 -0500   1.857  iPhone12,8
# 427431  2022-09-19 09:59:59 -0500    0.87  iPhone12,8
# 427432  2022-09-19 11:38:22 -0500   1.196  iPhone12,8
# 427433  2022-09-19 13:14:28 -0500   7.825  iPhone12,8
# 427434  2022-09-19 13:25:04 -0500  10.343  iPhone12,8
# ...                           ...     ...         ...
# 594135  2025-02-26 19:08:00 -0500     0.2   Watch6,10
# 594136  2025-02-26 19:08:51 -0500   0.062   Watch6,10
# 594137  2025-02-26 19:17:44 -0500   1.229   Watch6,10
# 594138  2025-02-26 19:20:58 -0500   0.092   Watch6,10
# 594139  2025-02-26 19:23:32 -0500   0.316   Watch6,10
#
# [166710 rows x 8 columns]

# %%
energyBurned['value'] = pd.to_numeric(energyBurned['value'], errors='coerce')
# Out:
# /tmp/ipykernel_4235/1481969465.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energyBurned['value'] = pd.to_numeric(energyBurned['value'], errors='coerce')

# %% [markdown]
# #1 Cal Burned on average

# %%
energyBurned_all_time = np.mean(energyBurned['value'])
energyBurned_all_time
# Out:
# np.float64(1.0096722572131247)

# %%
energyBurned['creationDate'] = pd.to_datetime(energyBurned['creationDate']).dt.date
# Out:
# /tmp/ipykernel_4235/1315118190.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energyBurned['creationDate'] = pd.to_datetime(energyBurned['creationDate']).dt.date

# %%
energyBurned_per_day = energyBurned.groupby('creationDate')['value'].mean()
energyBurned_per_day
# Out:
# creationDate
# 2022-09-20    4.578604
# 2022-09-21    2.997516
# 2022-09-22    4.458059
# 2022-09-23    1.361311
# 2022-09-24    1.949563
#                 ...
# 2025-02-22    0.816580
# 2025-02-23    2.308284
# 2025-02-24    1.057693
# 2025-02-25    1.305929
# 2025-02-26    0.929502
# Name: value, Length: 840, dtype: float64

# %% [markdown]
# #Dang girl! You burned a lot of energy!!!!

# %%
energyBurned_per_day = energyBurned_per_day.to_frame()
largest_ten_energyBurned = energyBurned_per_day.nlargest(10, 'value')
largest_ten_energyBurned
# Out:
#                   value
# creationDate
# 2024-01-20    38.086000
# 2025-01-05    34.630789
# 2024-12-23    34.629600
# 2024-12-28    29.577400
# 2025-01-01    28.043400
# 2024-12-21    27.549333
# 2025-01-18    27.342600
# 2024-12-14    27.318000
# 2025-01-16    27.264600
# 2024-01-17    26.655000

# %%
sns.barplot(data = largest_ten_energyBurned, x = 'creationDate', y = 'value', hue = 'creationDate', legend = False, palette= "viridis")
plt.title('Average Energy Burned Per Day')
plt.xlabel('Date')
plt.ylabel('Average Energy Burned (Largest 10)')
plt.xticks(rotation = 90)
plt.figure(figsize=(12, 8))
plt.close()
plt.show()

# %% [markdown]
# #Analyze Basal Energy Burned

# %%
basalenergyBurned = records_df[records_df['type'] == 'HKQuantityTypeIdentifierBasalEnergyBurned']
basalenergyBurned
# Out:
#                                              type            sourceName unit  \
# 302578  HKQuantityTypeIdentifierBasalEnergyBurned            iPhone (2)  Cal
# 302579  HKQuantityTypeIdentifierBasalEnergyBurned            iPhone (2)  Cal
# 302580  HKQuantityTypeIdentifierBasalEnergyBurned            iPhone (2)  Cal
# 302581  HKQuantityTypeIdentifierBasalEnergyBurned            iPhone (2)  Cal
# 302582  HKQuantityTypeIdentifierBasalEnergyBurned            iPhone (2)  Cal
# ...                                           ...                   ...  ...
# 427425  HKQuantityTypeIdentifierBasalEnergyBurned  Jannah’s Apple Watch  Cal
# 427426  HKQuantityTypeIdentifierBasalEnergyBurned  Jannah’s Apple Watch  Cal
# 427427  HKQuantityTypeIdentifierBasalEnergyBurned  Jannah’s Apple Watch  Cal
# 427428  HKQuantityTypeIdentifierBasalEnergyBurned  Jannah’s Apple Watch  Cal
# 427429  HKQuantityTypeIdentifierBasalEnergyBurned  Jannah’s Apple Watch  Cal
#
#                      creationDate                  startDate  \
# 302578  2022-09-20 08:47:26 -0500  2022-09-19 08:52:15 -0500
# 302579  2022-09-20 08:47:26 -0500  2022-09-19 09:14:26 -0500
# 302580  2022-09-20 08:47:26 -0500  2022-09-19 09:35:15 -0500
# 302581  2022-09-20 08:47:26 -0500  2022-09-19 09:50:50 -0500
# 302582  2022-09-20 08:47:26 -0500  2022-09-19 10:05:52 -0500
# ...                           ...                        ...
# 427425  2025-02-26 18:59:32 -0500  2025-02-26 18:43:56 -0500
# 427426  2025-02-26 19:15:19 -0500  2025-02-26 18:59:18 -0500
# 427427  2025-02-26 19:15:19 -0500  2025-02-26 18:59:28 -0500
# 427428  2025-02-26 19:36:21 -0500  2025-02-26 19:14:29 -0500
# 427429  2025-02-26 19:36:21 -0500  2025-02-26 19:15:00 -0500
#
#                           endDate   value      device
# 302578  2022-09-19 09:14:26 -0500  19.008  iPhone12,8
# 302579  2022-09-19 09:35:15 -0500  17.816  iPhone12,8
# 302580  2022-09-19 09:50:50 -0500  13.203  iPhone12,8
# 302581  2022-09-19 10:05:52 -0500  12.347  iPhone12,8
# 302582  2022-09-19 10:11:43 -0500   5.011  iPhone12,8
# ...                           ...     ...         ...
# 427425  2025-02-26 18:59:18 -0500  13.735   Watch6,10
# 427426  2025-02-26 18:59:28 -0500   0.184   Watch6,10
# 427427  2025-02-26 19:14:29 -0500  14.868   Watch6,10
# 427428  2025-02-26 19:15:00 -0500   0.489   Watch6,10
# 427429  2025-02-26 19:31:53 -0500  15.788   Watch6,10
#
# [124852 rows x 8 columns]

# %%
basalenergyBurned['value'] = pd.to_numeric(basalenergyBurned['value'], errors='coerce')
# Out:
# /tmp/ipykernel_4235/727465406.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basalenergyBurned['value'] = pd.to_numeric(basalenergyBurned['value'], errors='coerce')

# %%
basalenergyBurned_all_time = np.mean(basalenergyBurned['value'])
basalenergyBurned_all_time
# Out:
# np.float64(8.346309558517286)

# %%
basalenergyBurned['creationDate'] = pd.to_datetime(basalenergyBurned['creationDate']).dt.date
basalenergyBurned_per_day = basalenergyBurned.groupby('creationDate')['value'].mean()
basalenergyBurned_per_day
# Out:
# /tmp/ipykernel_4235/3096128175.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basalenergyBurned['creationDate'] = pd.to_datetime(basalenergyBurned['creationDate']).dt.date
# creationDate
# 2022-09-20    16.897102
# 2022-09-21    15.367051
# 2022-09-22    16.743697
# 2022-09-23    15.553528
# 2022-09-24    17.576630
#                 ...
# 2025-02-22     7.583674
# 2025-02-23     8.592960
# 2025-02-24     8.396502
# 2025-02-25     8.993587
# 2025-02-26     6.010109
# Name: value, Length: 841, dtype: float64

# %%
basalenergyBurned_per_day = basalenergyBurned_per_day.to_frame()
largest_ten_basalenergyBurned = basalenergyBurned_per_day.nlargest(10, 'value')
largest_ten_basalenergyBurned
# Out:
#                   value
# creationDate
# 2024-01-21    70.127000
# 2024-01-22    57.322848
# 2024-01-20    50.388923
# 2023-12-08    45.067900
# 2023-09-16    39.879485
# 2023-08-20    38.975161
# 2024-06-16    38.889283
# 2023-07-02    37.012219
# 2023-08-02    36.205805
# 2023-08-15    35.736487

# %%
sns.barplot(data = largest_ten_basalenergyBurned, x = 'creationDate', y = 'value', hue = 'creationDate', legend = False, palette= "viridis")
plt.title('Average Basal Energy Burned Per Day')
plt.xlabel('Date')
plt.ylabel('Average Basal Energy Burned (Largest 10)')
plt.xticks(rotation = 90)
plt.figure(figsize=(12, 8))
plt.close()
plt.show()

# %% [markdown]
# #Grab rows with flights climbed

# %%
flightsClimbed = records_df[records_df['type'] == 'HKQuantityTypeIdentifierFlightsClimbed']
flightsClimbed
# Out:
#                                           type            sourceName   unit  \
# 594140  HKQuantityTypeIdentifierFlightsClimbed            iPhone (2)  count
# 594141  HKQuantityTypeIdentifierFlightsClimbed            iPhone (2)  count
# 594142  HKQuantityTypeIdentifierFlightsClimbed            iPhone (2)  count
# 594143  HKQuantityTypeIdentifierFlightsClimbed            iPhone (2)  count
# 594144  HKQuantityTypeIdentifierFlightsClimbed            iPhone (2)  count
# ...                                        ...                   ...    ...
# 596678  HKQuantityTypeIdentifierFlightsClimbed  Jannah’s Apple Watch  count
# 596679  HKQuantityTypeIdentifierFlightsClimbed  Jannah’s Apple Watch  count
# 596680  HKQuantityTypeIdentifierFlightsClimbed            iPhone (2)  count
# 596681  HKQuantityTypeIdentifierFlightsClimbed            iPhone (2)  count
# 596682  HKQuantityTypeIdentifierFlightsClimbed  Jannah’s Apple Watch  count
#
#                      creationDate                  startDate  \
# 594140  2021-03-17 09:30:28 -0500  2021-03-17 09:19:53 -0500
# 594141  2021-03-28 14:16:51 -0500  2021-03-28 14:04:16 -0500
# 594142  2021-04-12 07:27:57 -0500  2021-04-12 07:14:49 -0500
# 594143  2021-04-12 12:43:12 -0500  2021-04-12 12:21:52 -0500
# 594144  2021-04-13 07:25:21 -0500  2021-04-13 07:04:13 -0500
# ...                           ...                        ...
# 596678  2025-02-25 09:36:50 -0500  2025-02-25 09:24:37 -0500
# 596679  2025-02-25 10:39:44 -0500  2025-02-25 10:26:23 -0500
# 596680  2025-02-25 10:41:21 -0500  2025-02-25 10:26:22 -0500
# 596681  2025-02-26 12:47:26 -0500  2025-02-26 12:34:26 -0500
# 596682  2025-02-26 12:45:46 -0500  2025-02-26 12:34:26 -0500
#
#                           endDate value      device
# 594140  2021-03-17 09:19:56 -0500     1  iPhone12,8
# 594141  2021-03-28 14:04:18 -0500     1  iPhone12,8
# 594142  2021-04-12 07:14:52 -0500     1  iPhone12,8
# 594143  2021-04-12 12:22:05 -0500     2  iPhone12,8
# 594144  2021-04-13 07:04:16 -0500     1  iPhone12,8
# ...                           ...   ...         ...
# 596678  2025-02-25 09:24:40 -0500     1   Watch6,10
# 596679  2025-02-25 10:26:26 -0500     1   Watch6,10
# 596680  2025-02-25 10:26:24 -0500     1  iPhone12,8
# 596681  2025-02-26 12:34:29 -0500     1  iPhone12,8
# 596682  2025-02-26 12:34:28 -0500     1   Watch6,10
#
# [2543 rows x 8 columns]

# %%
flightsClimbed['value'] = pd.to_numeric(flightsClimbed['value'], errors='coerce')
# Out:
# /tmp/ipykernel_4235/2585046829.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flightsClimbed['value'] = pd.to_numeric(flightsClimbed['value'], errors='coerce')

# %%
flightsClimbed_all_time = np.mean(flightsClimbed['value'])
flightsClimbed_all_time
# Out:
# np.float64(1.8167518678725914)

# %%
flightsClimbed['creationDate'] = pd.to_datetime(flightsClimbed['creationDate']).dt.date
flightsClimbed_per_day = flightsClimbed.groupby('creationDate')['value'].mean()
flightsClimbed_per_day
# Out:
# /tmp/ipykernel_4235/2205602870.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flightsClimbed['creationDate'] = pd.to_datetime(flightsClimbed['creationDate']).dt.date
# creationDate
# 2021-03-17    1.000000
# 2021-03-28    1.000000
# 2021-04-12    1.500000
# 2021-04-13    1.500000
# 2021-04-19    1.500000
#                 ...
# 2025-02-18    1.500000
# 2025-02-22    1.500000
# 2025-02-24    1.666667
# 2025-02-25    1.333333
# 2025-02-26    1.000000
# Name: value, Length: 779, dtype: float64

# %%
flightsClimbed_per_day = flightsClimbed_per_day.to_frame()
largest_ten_flightsClimbed = flightsClimbed_per_day.nlargest(10, 'value')
largest_ten_flightsClimbed
# Out:
#                  value
# creationDate
# 2022-06-09    6.000000
# 2022-08-17    5.500000
# 2022-09-21    5.500000
# 2022-10-11    5.000000
# 2024-08-11    5.000000
# 2022-02-10    4.500000
# 2022-04-16    4.000000
# 2023-01-12    4.000000
# 2022-04-27    3.750000
# 2023-05-08    3.666667

# %%
sns.barplot(data = largest_ten_flightsClimbed, x = 'creationDate', y = 'value', hue = 'creationDate', legend = False, palette= "viridis")
plt.title('Average Basal Flights Climbed Per Day (Largest 10)')
plt.xlabel('Date')
plt.ylabel('Average Basal Energy Burned')
plt.xticks(rotation = 90)
plt.figure(figsize=(12, 8))
plt.close()
plt.show()

# %% [markdown]
# #Cycling Distance, even though we barely do this :(

# %%
cyclingDistance = records_df[records_df['type'] == 'HKQuantityTypeIdentifierDistanceCycling']
cyclingDistance
# Out:
#                                            type            sourceName unit  \
# 606261  HKQuantityTypeIdentifierDistanceCycling  Jannah’s Apple Watch   mi
# 606262  HKQuantityTypeIdentifierDistanceCycling  Jannah’s Apple Watch   mi
# 606263  HKQuantityTypeIdentifierDistanceCycling  Jannah’s Apple Watch   mi
# 606264  HKQuantityTypeIdentifierDistanceCycling  Jannah’s Apple Watch   mi
# 606265  HKQuantityTypeIdentifierDistanceCycling  Jannah’s Apple Watch   mi
# ...                                         ...                   ...  ...
# 608974  HKQuantityTypeIdentifierDistanceCycling  Jannah’s Apple Watch   mi
# 608975  HKQuantityTypeIdentifierDistanceCycling  Jannah’s Apple Watch   mi
# 608976  HKQuantityTypeIdentifierDistanceCycling  Jannah’s Apple Watch   mi
# 608977  HKQuantityTypeIdentifierDistanceCycling  Jannah’s Apple Watch   mi
# 608978  HKQuantityTypeIdentifierDistanceCycling  Jannah’s Apple Watch   mi
#
#                      creationDate                  startDate  \
# 606261  2024-02-11 16:32:31 -0500  2024-02-11 16:30:03 -0500
# 606262  2024-02-11 16:32:31 -0500  2024-02-11 16:30:04 -0500
# 606263  2024-02-11 16:32:31 -0500  2024-02-11 16:30:05 -0500
# 606264  2024-02-11 16:32:31 -0500  2024-02-11 16:30:06 -0500
# 606265  2024-02-11 16:32:31 -0500  2024-02-11 16:30:07 -0500
# ...                           ...                        ...
# 608974  2024-12-19 22:52:36 -0500  2024-08-21 14:45:41 -0500
# 608975  2024-12-19 22:52:36 -0500  2024-08-21 14:47:41 -0500
# 608976  2024-12-19 22:52:36 -0500  2024-08-21 14:50:52 -0500
# 608977  2024-12-19 22:52:37 -0500  2024-08-21 14:53:01 -0500
# 608978  2024-12-19 22:52:37 -0500  2024-08-21 14:55:00 -0500
#
#                           endDate        value     device
# 606261  2024-02-11 16:30:04 -0500   0.00166382  Watch6,14
# 606262  2024-02-11 16:30:05 -0500  0.000496923  Watch6,14
# 606263  2024-02-11 16:30:06 -0500  0.000525638  Watch6,14
# 606264  2024-02-11 16:30:07 -0500   0.00221452  Watch6,14
# 606265  2024-02-11 16:30:09 -0500   0.00246729  Watch6,14
# ...                           ...          ...        ...
# 608974  2024-08-21 14:47:41 -0500     0.322541  Watch6,14
# 608975  2024-08-21 14:50:52 -0500     0.266346  Watch6,14
# 608976  2024-08-21 14:53:01 -0500     0.236452  Watch6,14
# 608977  2024-08-21 14:55:00 -0500     0.264996  Watch6,14
# 608978  2024-08-21 14:55:37 -0500    0.0531546  Watch6,14
#
# [2718 rows x 8 columns]

# %% [markdown]
# # 0.023 overall average because we don't bike like that

# %%
cyclingDistance['value'] = pd.to_numeric(cyclingDistance['value'], errors='coerce')
cyclingDistance_all_time = np.mean(cyclingDistance['value'])
cyclingDistance_all_time
# Out:
# /tmp/ipykernel_4235/364274692.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cyclingDistance['value'] = pd.to_numeric(cyclingDistance['value'], errors='coerce')
# np.float64(0.023103018278350623)

# %%
cyclingDistance['creationDate'] = pd.to_datetime(cyclingDistance['creationDate']).dt.date
cyclingDistance_per_day = cyclingDistance.groupby('creationDate')['value'].mean()
cyclingDistance_per_day
# Out:
# /tmp/ipykernel_4235/1879045465.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cyclingDistance['creationDate'] = pd.to_datetime(cyclingDistance['creationDate']).dt.date
# creationDate
# 2024-02-11    0.001884
# 2024-03-03    0.000108
# 2024-03-12    0.014840
# 2024-04-14    0.001301
# 2024-06-11    0.208137
# 2024-07-02    0.231989
# 2024-07-05    0.290548
# 2024-07-08    0.237611
# 2024-07-11    0.252825
# 2024-08-06    0.232574
# 2024-08-12    0.227790
# 2024-08-21    0.070305
# 2024-09-14    0.207723
# 2024-12-10    0.218875
# 2024-12-19    0.245958
# Name: value, dtype: float64

# %%
cyclingDistance_per_day = cyclingDistance_per_day.to_frame()
largest_ten_cyclingDistance = cyclingDistance_per_day.nlargest(10, 'value')
largest_ten_cyclingDistance
# Out:
#                  value
# creationDate
# 2024-07-05    0.290548
# 2024-07-11    0.252825
# 2024-12-19    0.245958
# 2024-07-08    0.237611
# 2024-08-06    0.232574
# 2024-07-02    0.231989
# 2024-08-12    0.227790
# 2024-12-10    0.218875
# 2024-06-11    0.208137
# 2024-09-14    0.207723

# %% [markdown]
# #0.29 miles is highest because we don't bike often, only in the spring/early summer

# %%
sns.barplot(data = largest_ten_cyclingDistance, x = 'creationDate', y = 'value', hue = 'creationDate', legend = False, palette= "viridis")
plt.title('Average Cycling Distance per Day (Largest 10)')
plt.xlabel('Date')
plt.ylabel('Average Cycling Distance')
plt.xticks(rotation = 90)
plt.figure(figsize=(12, 8))
plt.close()
plt.show()

# %% [markdown]
# #Jannah's a Swimmer so this will be very valuable data analysis

# %%
swimmingDistance = records_df[records_df['type'] == 'HKQuantityTypeIdentifierDistanceSwimming']
swimmingDistance
# Out:
#                                             type            sourceName unit  \
# 608979  HKQuantityTypeIdentifierDistanceSwimming  Jannah’s Apple Watch   yd
# 608980  HKQuantityTypeIdentifierDistanceSwimming  Jannah’s Apple Watch   yd
# 608981  HKQuantityTypeIdentifierDistanceSwimming  Jannah’s Apple Watch   yd
# 608982  HKQuantityTypeIdentifierDistanceSwimming  Jannah’s Apple Watch   yd
# 608983  HKQuantityTypeIdentifierDistanceSwimming  Jannah’s Apple Watch   yd
# ...                                          ...                   ...  ...
# 609529  HKQuantityTypeIdentifierDistanceSwimming  Jannah’s Apple Watch   yd
# 609530  HKQuantityTypeIdentifierDistanceSwimming  Jannah’s Apple Watch   yd
# 609531  HKQuantityTypeIdentifierDistanceSwimming  Jannah’s Apple Watch   yd
# 609532  HKQuantityTypeIdentifierDistanceSwimming  Jannah’s Apple Watch   yd
# 609533  HKQuantityTypeIdentifierDistanceSwimming  Jannah’s Apple Watch   yd
#
#                      creationDate                  startDate  \
# 608979  2023-09-28 15:20:10 -0500  2023-09-28 15:19:04 -0500
# 608980  2023-09-28 15:20:46 -0500  2023-09-28 15:19:36 -0500
# 608981  2023-09-28 15:21:22 -0500  2023-09-28 15:20:08 -0500
# 608982  2023-09-28 15:21:56 -0500  2023-09-28 15:20:40 -0500
# 608983  2023-09-28 15:22:34 -0500  2023-09-28 15:21:15 -0500
# ...                           ...                        ...
# 609529  2025-02-07 16:17:57 -0500  2025-02-07 16:15:52 -0500
# 609530  2025-02-07 16:19:43 -0500  2025-02-07 16:19:12 -0500
# 609531  2025-02-07 16:20:13 -0500  2025-02-07 16:19:40 -0500
# 609532  2025-02-07 16:20:42 -0500  2025-02-07 16:20:08 -0500
# 609533  2025-02-07 16:21:16 -0500  2025-02-07 16:20:37 -0500
#
#                           endDate value     device
# 608979  2023-09-28 15:19:31 -0500    25  Watch6,14
# 608980  2023-09-28 15:20:05 -0500    25  Watch6,14
# 608981  2023-09-28 15:20:40 -0500    25  Watch6,14
# 608982  2023-09-28 15:21:15 -0500    25  Watch6,14
# 608983  2023-09-28 15:21:50 -0500    25  Watch6,14
# ...                           ...   ...        ...
# 609529  2025-02-07 16:17:52 -0500    25  Watch6,10
# 609530  2025-02-07 16:19:38 -0500    25  Watch6,10
# 609531  2025-02-07 16:20:07 -0500    25  Watch6,10
# 609532  2025-02-07 16:20:37 -0500    25  Watch6,10
# 609533  2025-02-07 16:21:08 -0500    25  Watch6,10
#
# [554 rows x 8 columns]

# %% [markdown]
# #25 yds, on average, im assuming its more on competition days

# %%
swimmingDistance['value'] = pd.to_numeric(swimmingDistance['value'], errors='coerce')
swimmingDistance_all_time = np.mean(swimmingDistance['value'])
swimmingDistance_all_time
# Out:
# /tmp/ipykernel_4235/1322983731.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   swimmingDistance['value'] = pd.to_numeric(swimmingDistance['value'], errors='coerce')
# np.float64(25.22563176895307)

# %% [markdown]
# #Not as high as I thought

# %%
swimmingDistance['creationDate'] = pd.to_datetime(swimmingDistance['creationDate']).dt.date
swimmingDistance_per_day = swimmingDistance.groupby('creationDate')['value'].mean()
swimmingDistance_per_day
# Out:
# /tmp/ipykernel_4235/3884362417.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   swimmingDistance['creationDate'] = pd.to_datetime(swimmingDistance['creationDate']).dt.date
# creationDate
# 2023-09-28    25.000000
# 2023-10-03    25.000000
# 2023-10-28    25.000000
# 2023-10-31    25.000000
# 2024-04-15    25.000000
# 2024-04-18    25.000000
# 2024-04-22    25.000000
# 2024-04-25    25.000000
# 2024-06-08    25.000000
# 2024-07-06    25.000000
# 2024-07-09    25.000000
# 2024-07-13    25.000000
# 2024-07-18    25.000000
# 2024-07-20    25.000000
# 2025-01-31    25.000000
# 2025-02-03    25.000000
# 2025-02-07    27.192982
# Name: value, dtype: float64

# %%
swimmingDistance_per_day = swimmingDistance_per_day.to_frame()
sns.barplot(data = swimmingDistance, x = 'creationDate', y = 'value', hue = 'creationDate', legend = False, palette= "viridis")
plt.title('Average Cycling Swimming Distance per Day')
plt.xlabel('Date')
plt.ylabel('Average Swimming Distance')
plt.xticks(rotation = 90)
plt.figure(figsize=(12, 8))
plt.close()
plt.show()

# %% [markdown]
# #Get rows for Swim Strokes, but there was none

# %% [markdown]
# #Get rows for Environmental Audio Exposure

# %%
environmentalAudio = records_df[records_df['type'] == 'HKQuantityTypeIdentifierEnvironmentalAudioExposure']
environmentalAudio
# Out:
#                                                      type  \
# 610660  HKQuantityTypeIdentifierEnvironmentalAudioExpo...
# 610661  HKQuantityTypeIdentifierEnvironmentalAudioExpo...
# 610662  HKQuantityTypeIdentifierEnvironmentalAudioExpo...
# 610663  HKQuantityTypeIdentifierEnvironmentalAudioExpo...
# 610664  HKQuantityTypeIdentifierEnvironmentalAudioExpo...
# ...                                                   ...
# 623382  HKQuantityTypeIdentifierEnvironmentalAudioExpo...
# 623383  HKQuantityTypeIdentifierEnvironmentalAudioExpo...
# 623384  HKQuantityTypeIdentifierEnvironmentalAudioExpo...
# 623385  HKQuantityTypeIdentifierEnvironmentalAudioExpo...
# 623386  HKQuantityTypeIdentifierEnvironmentalAudioExpo...
#
#                   sourceName    unit               creationDate  \
# 610660  Jannah’s Apple Watch  dBASPL  2023-09-17 10:51:46 -0500
# 610661  Jannah’s Apple Watch  dBASPL  2023-09-17 11:13:00 -0500
# 610662  Jannah’s Apple Watch  dBASPL  2023-09-17 11:53:55 -0500
# 610663  Jannah’s Apple Watch  dBASPL  2023-09-17 12:18:45 -0500
# 610664  Jannah’s Apple Watch  dBASPL  2023-09-17 12:41:50 -0500
# ...                      ...     ...                        ...
# 623382  Jannah’s Apple Watch  dBASPL  2025-02-26 15:53:04 -0500
# 623383  Jannah’s Apple Watch  dBASPL  2025-02-26 16:28:34 -0500
# 623384  Jannah’s Apple Watch  dBASPL  2025-02-26 16:59:15 -0500
# 623385  Jannah’s Apple Watch  dBASPL  2025-02-26 17:44:12 -0500
# 623386  Jannah’s Apple Watch  dBASPL  2025-02-26 17:44:12 -0500
#
#                         startDate                    endDate    value  \
# 610660  2023-09-17 10:41:41 -0500  2023-09-17 11:11:39 -0500  58.8286
# 610661  2023-09-17 11:11:39 -0500  2023-09-17 11:41:34 -0500  53.2652
# 610662  2023-09-17 11:41:34 -0500  2023-09-17 12:11:30 -0500  57.3122
# 610663  2023-09-17 12:11:30 -0500  2023-09-17 12:41:25 -0500  56.5711
# 610664  2023-09-17 12:41:25 -0500  2023-09-17 13:11:20 -0500  65.1424
# ...                           ...                        ...      ...
# 623382  2025-02-26 15:51:19 -0500  2025-02-26 16:21:14 -0500   69.975
# 623383  2025-02-26 16:21:14 -0500  2025-02-26 16:51:14 -0500  61.5631
# 623384  2025-02-26 16:51:14 -0500  2025-02-26 17:21:09 -0500  53.1741
# 623385  2025-02-26 17:21:09 -0500  2025-02-26 17:22:04 -0500  68.6578
# 623386  2025-02-26 17:44:07 -0500  2025-02-26 18:14:02 -0500  55.0715
#
#            device
# 610660  Watch6,14
# 610661  Watch6,14
# 610662  Watch6,14
# 610663  Watch6,14
# 610664  Watch6,14
# ...           ...
# 623382  Watch6,10
# 623383  Watch6,10
# 623384  Watch6,10
# 623385  Watch6,10
# 623386  Watch6,10
#
# [12727 rows x 8 columns]

# %% [markdown]
# #Jannah isn't too exposed to high noise environments on average

# %%
environmentalAudio['value'] = pd.to_numeric(environmentalAudio['value'], errors='coerce')
environmentalAudio_all_time = np.mean(environmentalAudio['value'])
environmentalAudio_all_time
# Out:
# /tmp/ipykernel_4235/1520317012.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   environmentalAudio['value'] = pd.to_numeric(environmentalAudio['value'], errors='coerce')
# np.float64(58.896066975720906)

# %%
environmentalAudio['creationDate'] = pd.to_datetime(environmentalAudio['creationDate']).dt.date
environmentalAudio_per_day = environmentalAudio.groupby('creationDate')['value'].mean()
environmentalAudio_per_day
# Out:
# /tmp/ipykernel_4235/2690513043.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   environmentalAudio['creationDate'] = pd.to_datetime(environmentalAudio['creationDate']).dt.date
# creationDate
# 2023-09-17    59.346350
# 2023-09-18    59.408434
# 2023-09-19    62.642149
# 2023-09-20    60.528317
# 2023-09-21    58.295005
#                 ...
# 2025-02-22    56.488112
# 2025-02-23    53.856252
# 2025-02-24    62.456855
# 2025-02-25    58.571535
# 2025-02-26    68.559396
# Name: value, Length: 389, dtype: float64

# %% [markdown]
# #Not too high of an audio exposure

# %%
environmentalAudio_per_day = environmentalAudio_per_day.to_frame()
largest_ten_environmentalAudio = environmentalAudio_per_day.nlargest(10, 'value')
largest_ten_environmentalAudio
# Out:
#                   value
# creationDate
# 2024-08-31    78.803230
# 2024-05-22    72.998028
# 2023-11-19    72.942164
# 2024-08-27    72.699100
# 2023-11-08    71.355691
# 2024-01-23    70.668738
# 2024-03-03    69.756941
# 2025-02-07    69.290558
# 2023-11-03    69.238548
# 2023-10-07    69.057975

# %%
sns.barplot(data = largest_ten_environmentalAudio, x = 'creationDate', y = 'value', hue = 'creationDate', legend = False, palette= "viridis")
plt.title('Average Environmental Audio Exposure Per Day (Largest 10)')
plt.xlabel('Date')
plt.ylabel('Average Environmental Audio Exposure')
plt.xticks(rotation = 90)
plt.figure(figsize=(12, 8))
plt.close()
plt.show()

# %% [markdown]
# #Get rows with walking double support percentage, aka, walking really slow

# %%
walkingDoubleSupport = records_df[records_df['type'] == 'HKQuantityTypeIdentifierWalkingDoubleSupportPercentage']
walkingDoubleSupport
# Out:
#                                                      type  sourceName unit  \
# 623780  HKQuantityTypeIdentifierWalkingDoubleSupportPe...  iPhone (2)    %
# 623781  HKQuantityTypeIdentifierWalkingDoubleSupportPe...  iPhone (2)    %
# 623782  HKQuantityTypeIdentifierWalkingDoubleSupportPe...  iPhone (2)    %
# 623783  HKQuantityTypeIdentifierWalkingDoubleSupportPe...  iPhone (2)    %
# 623784  HKQuantityTypeIdentifierWalkingDoubleSupportPe...  iPhone (2)    %
# ...                                                   ...         ...  ...
# 642706  HKQuantityTypeIdentifierWalkingDoubleSupportPe...  iPhone (2)    %
# 642707  HKQuantityTypeIdentifierWalkingDoubleSupportPe...  iPhone (2)    %
# 642708  HKQuantityTypeIdentifierWalkingDoubleSupportPe...  iPhone (2)    %
# 642709  HKQuantityTypeIdentifierWalkingDoubleSupportPe...  iPhone (2)    %
# 642710  HKQuantityTypeIdentifierWalkingDoubleSupportPe...  iPhone (2)    %
#
#                      creationDate                  startDate  \
# 623780  2021-01-27 13:23:32 -0500  2021-01-27 12:40:14 -0500
# 623781  2021-01-27 13:23:32 -0500  2021-01-27 12:48:26 -0500
# 623782  2021-01-27 13:23:32 -0500  2021-01-27 12:53:25 -0500
# 623783  2021-01-27 13:23:32 -0500  2021-01-27 12:55:11 -0500
# 623784  2021-01-27 13:23:32 -0500  2021-01-27 12:58:13 -0500
# ...                           ...                        ...
# 642706  2025-02-26 14:14:08 -0500  2025-02-26 13:52:31 -0500
# 642707  2025-02-26 14:14:08 -0500  2025-02-26 14:00:39 -0500
# 642708  2025-02-26 14:14:08 -0500  2025-02-26 14:02:08 -0500
# 642709  2025-02-26 16:36:27 -0500  2025-02-26 15:54:54 -0500
# 642710  2025-02-26 16:36:27 -0500  2025-02-26 16:06:03 -0500
#
#                           endDate  value      device
# 623780  2021-01-27 12:40:17 -0500   0.31  iPhone12,8
# 623781  2021-01-27 12:53:25 -0500  0.298  iPhone12,8
# 623782  2021-01-27 12:54:59 -0500  0.277  iPhone12,8
# 623783  2021-01-27 12:57:42 -0500  0.281  iPhone12,8
# 623784  2021-01-27 13:03:13 -0500  0.285  iPhone12,8
# ...                           ...    ...         ...
# 642706  2025-02-26 13:52:33 -0500  0.275  iPhone12,8
# 642707  2025-02-26 14:01:03 -0500   0.28  iPhone12,8
# 642708  2025-02-26 14:02:46 -0500  0.256  iPhone12,8
# 642709  2025-02-26 15:55:17 -0500  0.274  iPhone12,8
# 642710  2025-02-26 16:06:23 -0500  0.229  iPhone12,8
#
# [18931 rows x 8 columns]

# %% [markdown]
# #29%

# %%
walkingDoubleSupport['value'] = pd.to_numeric(walkingDoubleSupport['value'], errors='coerce')
walkingDoubleSupport_all_time = np.mean(walkingDoubleSupport['value'])
walkingDoubleSupport_all_time
# Out:
# /tmp/ipykernel_4235/1341940705.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   walkingDoubleSupport['value'] = pd.to_numeric(walkingDoubleSupport['value'], errors='coerce')
# np.float64(0.29557244730864723)

# %%
walkingDoubleSupport['creationDate'] = pd.to_datetime(walkingDoubleSupport['creationDate']).dt.date
walkingDoubleSupport_per_day = walkingDoubleSupport.groupby('creationDate')['value'].mean()
walkingDoubleSupport_per_day
# Out:
# /tmp/ipykernel_4235/120809820.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   walkingDoubleSupport['creationDate'] = pd.to_datetime(walkingDoubleSupport['creationDate']).dt.date
# creationDate
# 2021-01-27    0.294875
# 2021-01-28    0.308000
# 2021-01-30    0.301444
# 2021-02-03    0.292308
# 2021-02-04    0.306333
#                 ...
# 2025-02-18    0.282176
# 2025-02-22    0.280667
# 2025-02-23    0.285826
# 2025-02-25    0.276692
# 2025-02-26    0.274880
# Name: value, Length: 1042, dtype: float64

# %%
walkingDoubleSupport_per_day = walkingDoubleSupport_per_day.to_frame()
largest_ten_walkingDoubleSupport = walkingDoubleSupport_per_day.nlargest(10, 'value')
largest_ten_walkingDoubleSupport
# Out:
#                  value
# creationDate
# 2022-03-18    0.343000
# 2023-06-18    0.342500
# 2023-04-14    0.342000
# 2023-06-10    0.339000
# 2023-04-06    0.336800
# 2023-01-18    0.336450
# 2023-08-22    0.335733
# 2023-01-16    0.335130
# 2023-04-19    0.334455
# 2023-05-11    0.334333

# %%
sns.barplot(data = largest_ten_walkingDoubleSupport, x = 'creationDate', y = 'value', hue = 'creationDate', legend = False, palette= "viridis")
plt.title('Average Walking Double Support Per Day (Largest 10)')
plt.xlabel('Date')
plt.ylabel('Average Walking Double Support')
plt.xticks(rotation = 90)
plt.figure(figsize=(12, 8))
plt.close()
plt.show()

# %% [markdown]
# #Get rows with walking speed

# %%
walkingSpeed = records_df[records_df['type'] == 'HKQuantityTypeIdentifierWalkingSpeed']
walkingSpeed
# Out:
#                                         type  sourceName   unit  \
# 665289  HKQuantityTypeIdentifierWalkingSpeed  iPhone (2)  mi/hr
# 665290  HKQuantityTypeIdentifierWalkingSpeed  iPhone (2)  mi/hr
# 665291  HKQuantityTypeIdentifierWalkingSpeed  iPhone (2)  mi/hr
# 665292  HKQuantityTypeIdentifierWalkingSpeed  iPhone (2)  mi/hr
# 665293  HKQuantityTypeIdentifierWalkingSpeed  iPhone (2)  mi/hr
# ...                                      ...         ...    ...
# 686640  HKQuantityTypeIdentifierWalkingSpeed  iPhone (2)  mi/hr
# 686641  HKQuantityTypeIdentifierWalkingSpeed  iPhone (2)  mi/hr
# 686642  HKQuantityTypeIdentifierWalkingSpeed  iPhone (2)  mi/hr
# 686643  HKQuantityTypeIdentifierWalkingSpeed  iPhone (2)  mi/hr
# 686644  HKQuantityTypeIdentifierWalkingSpeed  iPhone (2)  mi/hr
#
#                      creationDate                  startDate  \
# 665289  2021-01-27 13:23:32 -0500  2021-01-27 12:40:14 -0500
# 665290  2021-01-27 13:23:32 -0500  2021-01-27 12:48:26 -0500
# 665291  2021-01-27 13:23:32 -0500  2021-01-27 12:53:25 -0500
# 665292  2021-01-27 13:23:32 -0500  2021-01-27 12:55:11 -0500
# 665293  2021-01-27 13:23:32 -0500  2021-01-27 12:58:13 -0500
# ...                           ...                        ...
# 686640  2025-02-26 14:14:08 -0500  2025-02-26 13:52:31 -0500
# 686641  2025-02-26 14:14:08 -0500  2025-02-26 14:00:39 -0500
# 686642  2025-02-26 14:14:08 -0500  2025-02-26 14:02:08 -0500
# 686643  2025-02-26 16:36:27 -0500  2025-02-26 15:54:54 -0500
# 686644  2025-02-26 16:36:27 -0500  2025-02-26 16:06:03 -0500
#
#                           endDate    value      device
# 665289  2021-01-27 12:40:17 -0500  2.23694  iPhone12,8
# 665290  2021-01-27 12:53:25 -0500  2.72906  iPhone12,8
# 665291  2021-01-27 12:54:59 -0500  3.10934  iPhone12,8
# 665292  2021-01-27 12:57:42 -0500   3.0646  iPhone12,8
# 665293  2021-01-27 13:03:13 -0500  3.01986  iPhone12,8
# ...                           ...      ...         ...
# 686640  2025-02-26 13:52:33 -0500  2.61722  iPhone12,8
# 686641  2025-02-26 14:01:03 -0500  2.63958  iPhone12,8
# 686642  2025-02-26 14:02:46 -0500  3.01986  iPhone12,8
# 686643  2025-02-26 15:55:17 -0500  2.81854  iPhone12,8
# 686644  2025-02-26 16:06:23 -0500  3.71331  iPhone12,8
#
# [21356 rows x 8 columns]

# %% [markdown]
# #2.5 mi/hr is like speed walking

# %%
walkingSpeed['value'] = pd.to_numeric(walkingSpeed['value'], errors='coerce')
walkingSpeed_all_time = np.mean(walkingSpeed['value'])
walkingSpeed_all_time
# Out:
# /tmp/ipykernel_4235/1885217299.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   walkingSpeed['value'] = pd.to_numeric(walkingSpeed['value'], errors='coerce')
# np.float64(2.5068634560310916)

# %%
walkingSpeed['creationDate'] = pd.to_datetime(walkingSpeed['creationDate']).dt.date
walkingSpeed_per_day = walkingSpeed.groupby('creationDate')['value'].mean()
walkingSpeed_per_day
# Out:
# /tmp/ipykernel_4235/1970144605.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   walkingSpeed['creationDate'] = pd.to_datetime(walkingSpeed['creationDate']).dt.date
# creationDate
# 2021-01-27    2.801433
# 2021-01-28    2.125090
# 2021-01-30    2.606619
# 2021-02-03    2.661155
# 2021-02-04    2.604788
#                 ...
# 2025-02-18    2.343813
# 2025-02-22    2.360828
# 2025-02-23    2.298674
# 2025-02-25    2.505369
# 2025-02-26    2.584076
# Name: value, Length: 1051, dtype: float64

# %% [markdown]
# #certain days, jannahs walking speed is almost 4 mi/hr

# %%
walkingSpeed_per_day = walkingSpeed_per_day.to_frame()
largest_ten_walkingSpeed = walkingSpeed_per_day.nlargest(10, 'value')
largest_ten_walkingSpeed
# Out:
#                  value
# creationDate
# 2022-03-26    3.690940
# 2021-12-13    3.662184
# 2022-04-21    3.576612
# 2021-05-03    3.571109
# 2021-05-10    3.566315
# 2021-12-09    3.563119
# 2022-01-20    3.546788
# 2021-04-19    3.536082
# 2021-12-14    3.525756
# 2021-10-06    3.521933

# %%
sns.barplot(data = largest_ten_walkingSpeed, x = 'creationDate', y = 'value', hue = 'creationDate', legend = False, palette= "viridis")
plt.title('Average Walking Speed Per Day (Largest 10)')
plt.xlabel('Date')
plt.ylabel('Average Walking Speed')
plt.xticks(rotation = 90)
plt.figure(figsize=(12, 8))
plt.close()
plt.show()

# %% [markdown]
# #Get rows with Walking Step Length

# %%
walkingStep = records_df[records_df['type'] == 'HKQuantityTypeIdentifierWalkingStepLength']
walkingStep
# Out:
#                                              type  sourceName unit  \
# 686645  HKQuantityTypeIdentifierWalkingStepLength  iPhone (2)   in
# 686646  HKQuantityTypeIdentifierWalkingStepLength  iPhone (2)   in
# 686647  HKQuantityTypeIdentifierWalkingStepLength  iPhone (2)   in
# 686648  HKQuantityTypeIdentifierWalkingStepLength  iPhone (2)   in
# 686649  HKQuantityTypeIdentifierWalkingStepLength  iPhone (2)   in
# ...                                           ...         ...  ...
# 707996  HKQuantityTypeIdentifierWalkingStepLength  iPhone (2)   in
# 707997  HKQuantityTypeIdentifierWalkingStepLength  iPhone (2)   in
# 707998  HKQuantityTypeIdentifierWalkingStepLength  iPhone (2)   in
# 707999  HKQuantityTypeIdentifierWalkingStepLength  iPhone (2)   in
# 708000  HKQuantityTypeIdentifierWalkingStepLength  iPhone (2)   in
#
#                      creationDate                  startDate  \
# 686645  2021-01-27 13:23:32 -0500  2021-01-27 12:40:14 -0500
# 686646  2021-01-27 13:23:32 -0500  2021-01-27 12:48:26 -0500
# 686647  2021-01-27 13:23:32 -0500  2021-01-27 12:53:25 -0500
# 686648  2021-01-27 13:23:32 -0500  2021-01-27 12:55:11 -0500
# 686649  2021-01-27 13:23:32 -0500  2021-01-27 12:58:13 -0500
# ...                           ...                        ...
# 707996  2025-02-26 14:14:08 -0500  2025-02-26 13:52:31 -0500
# 707997  2025-02-26 14:14:08 -0500  2025-02-26 14:00:39 -0500
# 707998  2025-02-26 14:14:08 -0500  2025-02-26 14:02:08 -0500
# 707999  2025-02-26 16:36:27 -0500  2025-02-26 15:54:54 -0500
# 708000  2025-02-26 16:36:27 -0500  2025-02-26 16:06:03 -0500
#
#                           endDate    value      device
# 686645  2021-01-27 12:40:17 -0500  25.1969  iPhone12,8
# 686646  2021-01-27 12:53:25 -0500  28.7402  iPhone12,8
# 686647  2021-01-27 12:54:59 -0500  31.4961  iPhone12,8
# 686648  2021-01-27 12:57:42 -0500  31.1024  iPhone12,8
# 686649  2021-01-27 13:03:13 -0500  31.1024  iPhone12,8
# ...                           ...      ...         ...
# 707996  2025-02-26 13:52:33 -0500  24.4094  iPhone12,8
# 707997  2025-02-26 14:01:03 -0500   26.378  iPhone12,8
# 707998  2025-02-26 14:02:46 -0500  29.5276  iPhone12,8
# 707999  2025-02-26 15:55:17 -0500  27.1654  iPhone12,8
# 708000  2025-02-26 16:06:23 -0500  33.4646  iPhone12,8
#
# [21356 rows x 8 columns]

# %% [markdown]
# #About 26 in, thats pretty long since for some of those years, she was shorter and is 5'3

# %%
walkingStep['value'] = pd.to_numeric(walkingStep['value'], errors='coerce')
walkingStep_all_time = np.mean(walkingStep['value'])
walkingStep_all_time
# Out:
# /tmp/ipykernel_4235/3424829391.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   walkingStep['value'] = pd.to_numeric(walkingStep['value'], errors='coerce')
# np.float64(25.788404649747147)

# %%
walkingStep['creationDate'] = pd.to_datetime(walkingStep['creationDate']).dt.date
walkingStep_per_day = walkingStep.groupby('creationDate')['value'].mean()
walkingStep_per_day
# Out:
# /tmp/ipykernel_4235/2140070905.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   walkingStep['creationDate'] = pd.to_datetime(walkingStep['creationDate']).dt.date
# creationDate
# 2021-01-27    29.689700
# 2021-01-28    21.653500
# 2021-01-30    27.911332
# 2021-02-03    27.812161
# 2021-02-04    27.209122
#                 ...
# 2025-02-18    24.256344
# 2025-02-22    24.136892
# 2025-02-23    24.519688
# 2025-02-25    25.658441
# 2025-02-26    25.692633
# Name: value, Length: 1051, dtype: float64

# %%
walkingStep_per_day = walkingStep_per_day.to_frame()
largest_ten_walkingStep = walkingStep_per_day.nlargest(10, 'value')
largest_ten_walkingStep
# Out:
#                   value
# creationDate
# 2022-03-26    37.401600
# 2021-12-13    36.220500
# 2021-12-09    34.814429
# 2021-12-17    34.227394
# 2022-01-20    34.120767
# 2021-05-10    33.970786
# 2021-12-14    33.918869
# 2021-10-06    33.902044
# 2021-05-03    33.886421
# 2022-04-21    33.858300

# %%
sns.barplot(data = largest_ten_walkingStep, x = 'creationDate', y = 'value', hue = 'creationDate', legend = False, palette= "viridis")
plt.title('Average Walking Step Length Per Day (Largest 10)')
plt.xlabel('Date')
plt.ylabel('Average Walking Step Length')
plt.xticks(rotation = 90)
plt.figure(figsize=(12, 8))
plt.close()
plt.show()

# %% [markdown]
# #Get rows with Walking Assymetry Percentage, aka does jannah have asymetrical legs

# %%
walking_assymetry_percentage = records_df[records_df['type'] == 'HKQuantityTypeIdentifierWalkingAsymmetryPercentage']
walking_assymetry_percentage
# Out:
#                                                      type  sourceName unit  \
# 708001  HKQuantityTypeIdentifierWalkingAsymmetryPercen...  iPhone (2)    %
# 708002  HKQuantityTypeIdentifierWalkingAsymmetryPercen...  iPhone (2)    %
# 708003  HKQuantityTypeIdentifierWalkingAsymmetryPercen...  iPhone (2)    %
# 708004  HKQuantityTypeIdentifierWalkingAsymmetryPercen...  iPhone (2)    %
# 708005  HKQuantityTypeIdentifierWalkingAsymmetryPercen...  iPhone (2)    %
# ...                                                   ...         ...  ...
# 719730  HKQuantityTypeIdentifierWalkingAsymmetryPercen...  iPhone (2)    %
# 719731  HKQuantityTypeIdentifierWalkingAsymmetryPercen...  iPhone (2)    %
# 719732  HKQuantityTypeIdentifierWalkingAsymmetryPercen...  iPhone (2)    %
# 719733  HKQuantityTypeIdentifierWalkingAsymmetryPercen...  iPhone (2)    %
# 719734  HKQuantityTypeIdentifierWalkingAsymmetryPercen...  iPhone (2)    %
#
#                      creationDate                  startDate  \
# 708001  2021-01-27 13:23:32 -0500  2021-01-27 12:48:26 -0500
# 708002  2021-01-27 13:23:32 -0500  2021-01-27 12:53:25 -0500
# 708003  2021-01-27 13:23:32 -0500  2021-01-27 12:55:11 -0500
# 708004  2021-01-27 13:23:32 -0500  2021-01-27 12:58:13 -0500
# 708005  2021-01-27 13:23:32 -0500  2021-01-27 13:03:13 -0500
# ...                           ...                        ...
# 719730  2025-02-26 14:14:08 -0500  2025-02-26 13:15:15 -0500
# 719731  2025-02-26 14:14:08 -0500  2025-02-26 14:00:39 -0500
# 719732  2025-02-26 14:14:08 -0500  2025-02-26 14:02:08 -0500
# 719733  2025-02-26 16:36:27 -0500  2025-02-26 15:54:54 -0500
# 719734  2025-02-26 16:36:27 -0500  2025-02-26 16:06:03 -0500
#
#                           endDate value      device
# 708001  2021-01-27 12:53:25 -0500     0  iPhone12,8
# 708002  2021-01-27 12:54:59 -0500     0  iPhone12,8
# 708003  2021-01-27 12:57:42 -0500     0  iPhone12,8
# 708004  2021-01-27 13:03:13 -0500     0  iPhone12,8
# 708005  2021-01-27 13:04:21 -0500  0.05  iPhone12,8
# ...                           ...   ...         ...
# 719730  2025-02-26 13:17:51 -0500  0.01  iPhone12,8
# 719731  2025-02-26 14:01:03 -0500     0  iPhone12,8
# 719732  2025-02-26 14:02:46 -0500     0  iPhone12,8
# 719733  2025-02-26 15:55:17 -0500  0.06  iPhone12,8
# 719734  2025-02-26 16:06:23 -0500     0  iPhone12,8
#
# [11734 rows x 8 columns]

# %% [markdown]
# #Not very asymetrical. You have average symmetry. Mom was wrong girl...

# %%
walking_assymetry_percentage['value'] = pd.to_numeric(walking_assymetry_percentage['value'], errors='coerce')
walking_assymetry_percentage_all_time = np.mean(walking_assymetry_percentage['value'])
walking_assymetry_percentage_all_time
# Out:
# /tmp/ipykernel_4235/3376920180.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   walking_assymetry_percentage['value'] = pd.to_numeric(walking_assymetry_percentage['value'], errors='coerce')
# np.float64(0.03752599284131583)

# %%
walking_assymetry_percentage['creationDate'] = pd.to_datetime(walking_assymetry_percentage['creationDate']).dt.date
walking_assymetry_percentage_per_day = walking_assymetry_percentage.groupby('creationDate')['value'].mean()
walking_assymetry_percentage_per_day
# Out:
# /tmp/ipykernel_4235/1332107246.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   walking_assymetry_percentage['creationDate'] = pd.to_datetime(walking_assymetry_percentage['creationDate']).dt.date
# creationDate
# 2021-01-27    0.004545
# 2021-01-30    0.045000
# 2021-02-03    0.004211
# 2021-02-04    0.013750
# 2021-02-09    0.000000
#                 ...
# 2025-02-18    0.016000
# 2025-02-22    0.005000
# 2025-02-23    0.058000
# 2025-02-25    0.068500
# 2025-02-26    0.013571
# Name: value, Length: 1003, dtype: float64

# %%
walking_assymetry_percentage_per_day = walking_assymetry_percentage_per_day.to_frame()
largest_ten_walking_assymetry_percentage_per_day = walking_assymetry_percentage_per_day.nlargest(10, 'value')
largest_ten_walking_assymetry_percentage_per_day
# Out:
#                  value
# creationDate
# 2023-06-18    0.695000
# 2024-09-29    0.480000
# 2022-12-12    0.465000
# 2024-07-21    0.446000
# 2024-05-24    0.405000
# 2024-06-04    0.393056
# 2023-05-11    0.387143
# 2022-09-24    0.365000
# 2024-06-17    0.340000
# 2023-12-26    0.326667

# %%
sns.barplot(data = largest_ten_walking_assymetry_percentage_per_day, x = 'creationDate', y = 'value', hue = 'creationDate', legend = False, palette= "viridis")
plt.title('Average Walking Assymetry Percentage Per Day (Largest 10)')
plt.xlabel('Date')
plt.ylabel('Average Walking Assymetry Percentage')
plt.xticks(rotation = 90)
plt.figure(figsize=(12, 8))
plt.close()
plt.show()

# %% [markdown]
# #Get rows for walking steadiness, but there was none

# %% [markdown]
# #Get rows that say how much time spent in daylight

# %%
daylight = records_df[records_df['type'] == 'HKQuantityTypeIdentifierTimeInDaylight']
daylight
# Out:
#                                           type            sourceName unit  \
# 721780  HKQuantityTypeIdentifierTimeInDaylight  Jannah’s Apple Watch  min
# 721781  HKQuantityTypeIdentifierTimeInDaylight  Jannah’s Apple Watch  min
# 721782  HKQuantityTypeIdentifierTimeInDaylight  Jannah’s Apple Watch  min
# 721783  HKQuantityTypeIdentifierTimeInDaylight  Jannah’s Apple Watch  min
# 721784  HKQuantityTypeIdentifierTimeInDaylight  Jannah’s Apple Watch  min
# ...                                        ...                   ...  ...
# 723260  HKQuantityTypeIdentifierTimeInDaylight  Jannah’s Apple Watch  min
# 723261  HKQuantityTypeIdentifierTimeInDaylight  Jannah’s Apple Watch  min
# 723262  HKQuantityTypeIdentifierTimeInDaylight  Jannah’s Apple Watch  min
# 723263  HKQuantityTypeIdentifierTimeInDaylight  Jannah’s Apple Watch  min
# 723264  HKQuantityTypeIdentifierTimeInDaylight  Jannah’s Apple Watch  min
#
#                      creationDate                  startDate  \
# 721780  2023-11-27 15:20:36 -0500  2023-11-27 14:57:32 -0500
# 721781  2023-11-27 16:36:26 -0500  2023-11-27 15:02:32 -0500
# 721782  2023-11-30 10:41:15 -0500  2023-11-30 10:14:57 -0500
# 721783  2023-11-30 12:41:41 -0500  2023-11-30 12:30:54 -0500
# 721784  2023-11-30 14:17:47 -0500  2023-11-30 14:04:47 -0500
# ...                           ...                        ...
# 723260  2025-02-26 12:47:23 -0500  2025-02-26 12:29:59 -0500
# 723261  2025-02-26 12:47:23 -0500  2025-02-26 12:34:59 -0500
# 723262  2025-02-26 13:32:46 -0500  2025-02-26 13:11:24 -0500
# 723263  2025-02-26 13:32:46 -0500  2025-02-26 13:16:24 -0500
# 723264  2025-02-26 16:34:16 -0500  2025-02-26 16:06:48 -0500
#
#                           endDate value     device
# 721780  2023-11-27 15:02:32 -0500     5  Watch6,14
# 721781  2023-11-27 15:07:32 -0500     1  Watch6,14
# 721782  2023-11-30 10:19:57 -0500     1  Watch6,14
# 721783  2023-11-30 12:35:54 -0500     4  Watch6,14
# 721784  2023-11-30 14:09:47 -0500     3  Watch6,14
# ...                           ...   ...        ...
# 723260  2025-02-26 12:34:59 -0500     5  Watch6,10
# 723261  2025-02-26 12:39:59 -0500     3  Watch6,10
# 723262  2025-02-26 13:16:24 -0500     5  Watch6,10
# 723263  2025-02-26 13:21:24 -0500     3  Watch6,10
# 723264  2025-02-26 16:11:48 -0500     4  Watch6,10
#
# [1485 rows x 8 columns]

# %% [markdown]
# #We don't spend a lot of time outside. That explains our low vitamin D. We spend an average of 4 minutes outside. Like ugh naur.

# %%
daylight['value'] = pd.to_numeric(daylight['value'], errors='coerce')
daylight_all_time = np.mean(daylight['value'])
daylight_all_time
# Out:
# /tmp/ipykernel_4235/3335017098.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daylight['value'] = pd.to_numeric(daylight['value'], errors='coerce')
# np.float64(4.092929292929293)

# %%
daylight['creationDate'] = pd.to_datetime(daylight['creationDate']).dt.date
daylight_per_day = walkingStep.groupby('creationDate')['value'].mean()
daylight_per_day
# Out:
# /tmp/ipykernel_4235/1516724778.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daylight['creationDate'] = pd.to_datetime(daylight['creationDate']).dt.date
# creationDate
# 2021-01-27    29.689700
# 2021-01-28    21.653500
# 2021-01-30    27.911332
# 2021-02-03    27.812161
# 2021-02-04    27.209122
#                 ...
# 2025-02-18    24.256344
# 2025-02-22    24.136892
# 2025-02-23    24.519688
# 2025-02-25    25.658441
# 2025-02-26    25.692633
# Name: value, Length: 1051, dtype: float64

# %% [markdown]
# #We spent a lot of time outside mainly during COVID

# %%
daylight_per_day = daylight_per_day.to_frame()
largest_ten_daylight = daylight_per_day.nlargest(10, 'value')
largest_ten_daylight
# Out:
#                   value
# creationDate
# 2022-03-26    37.401600
# 2021-12-13    36.220500
# 2021-12-09    34.814429
# 2021-12-17    34.227394
# 2022-01-20    34.120767
# 2021-05-10    33.970786
# 2021-12-14    33.918869
# 2021-10-06    33.902044
# 2021-05-03    33.886421
# 2022-04-21    33.858300

# %%
sns.barplot(data = largest_ten_daylight, x = 'creationDate', y = 'value', hue = 'creationDate', legend = False, palette= "viridis")
plt.title('Average Time spent in Daylight Per Day (Largest 10)')
plt.xlabel('Date')
plt.ylabel('Average Time spent in Daylight')
plt.xticks(rotation = 90)
plt.figure(figsize=(12, 8))
plt.close()
plt.show()

# %% [markdown]
# #Get rows with Heart Rate Variability

# %%
heartRate = records_df[records_df['type'] == 'HKQuantityTypeIdentifierHeartRateVariabilitySDNN']
heartRate
# Out:
#                                                     type  \
# 909455  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 909456  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 909457  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 909458  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 909459  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# ...                                                  ...
# 911267  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911268  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911269  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911270  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 911271  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
#
#                   sourceName unit               creationDate  \
# 909455  Jannah’s Apple Watch   ms  2023-09-17 10:48:41 -0500
# 909456  Jannah’s Apple Watch   ms  2023-09-17 15:26:14 -0500
# 909457  Jannah’s Apple Watch   ms  2023-09-17 18:55:03 -0500
# 909458  Jannah’s Apple Watch   ms  2023-09-18 00:12:19 -0500
# 909459  Jannah’s Apple Watch   ms  2023-09-18 02:23:54 -0500
# ...                      ...  ...                        ...
# 911267  Jannah’s Apple Watch   ms  2025-02-25 21:29:58 -0500
# 911268  Jannah’s Apple Watch   ms  2025-02-26 06:45:04 -0500
# 911269  Jannah’s Apple Watch   ms  2025-02-26 07:57:41 -0500
# 911270  Jannah’s Apple Watch   ms  2025-02-26 13:43:06 -0500
# 911271  Jannah’s Apple Watch   ms  2025-02-26 15:09:12 -0500
#
#                         startDate                    endDate    value  \
# 909455  2023-09-17 10:47:40 -0500  2023-09-17 10:48:35 -0500  195.918
# 909456  2023-09-17 15:25:13 -0500  2023-09-17 15:26:13 -0500  147.235
# 909457  2023-09-17 18:54:02 -0500  2023-09-17 18:55:01 -0500  148.095
# 909458  2023-09-18 00:11:18 -0500  2023-09-18 00:12:17 -0500  166.914
# 909459  2023-09-18 02:22:53 -0500  2023-09-18 02:23:53 -0500  79.9569
# ...                           ...                        ...      ...
# 911267  2025-02-25 21:28:57 -0500  2025-02-25 21:29:54 -0500  144.231
# 911268  2025-02-26 06:44:03 -0500  2025-02-26 06:45:03 -0500  120.072
# 911269  2025-02-26 07:56:40 -0500  2025-02-26 07:57:39 -0500  38.8269
# 911270  2025-02-26 13:42:05 -0500  2025-02-26 13:43:04 -0500  39.7098
# 911271  2025-02-26 15:08:11 -0500  2025-02-26 15:09:11 -0500  27.7803
#
#            device
# 909455  Watch6,14
# 909456  Watch6,14
# 909457  Watch6,14
# 909458  Watch6,14
# 909459  Watch6,14
# ...           ...
# 911267  Watch6,10
# 911268  Watch6,10
# 911269  Watch6,10
# 911270  Watch6,10
# 911271  Watch6,10
#
# [1817 rows x 8 columns]

# %% [markdown]
# #If you don't workout, this level would be stressful. But I think that this is good for someone who worksout consistently.

# %%
heartRate['value'] = pd.to_numeric(heartRate['value'], errors='coerce')
heartRate_all_time = np.mean(heartRate['value'])
heartRate_all_time
# Out:
# /tmp/ipykernel_4235/644265215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heartRate['value'] = pd.to_numeric(heartRate['value'], errors='coerce')
# np.float64(97.62904865162355)

# %%
heartRate['creationDate'] = pd.to_datetime(heartRate['creationDate']).dt.date
heartRate_per_day = heartRate.groupby('creationDate')['value'].mean()
heartRate_per_day
# Out:
# /tmp/ipykernel_4235/2042328363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heartRate['creationDate'] = pd.to_datetime(heartRate['creationDate']).dt.date
# creationDate
# 2023-09-17    163.749333
# 2023-09-18    104.862386
# 2023-09-19    109.575417
# 2023-09-20    104.425250
# 2023-09-21    101.039750
#                  ...
# 2025-02-22     83.224133
# 2025-02-23     93.119400
# 2025-02-24     90.432667
# 2025-02-25     82.634000
# 2025-02-26     56.597250
# Name: value, Length: 385, dtype: float64

# %% [markdown]
# #I think highest heart rate variability is when you are competing

# %%
heartRate_per_day = heartRate_per_day.to_frame()
largest_ten_heartRate = heartRate_per_day.nlargest(10, 'value')
largest_ten_heartRate
# Out:
#                    value
# creationDate
# 2023-09-22    190.811233
# 2024-02-09    185.082000
# 2024-06-15    178.744000
# 2023-10-22    168.788000
# 2024-09-16    165.260000
# 2025-01-28    163.776000
# 2023-09-17    163.749333
# 2024-10-01    163.476500
# 2024-05-09    162.080600
# 2024-01-10    154.345000

# %%
sns.barplot(data = largest_ten_heartRate, x = 'creationDate', y = 'value', hue = 'creationDate', legend = False, palette= "viridis")
plt.title('Average Heart Rate Variability Per Day (Largest 10)')
plt.xlabel('Date')
plt.ylabel('Average Heart Rate Variability')
plt.xticks(rotation = 90)
plt.figure(figsize=(12, 8))
plt.close()
plt.show()

# %% [markdown]
# #Adding new features and converting old ones so maybe I can use it in PowerBI and for a correlation matrix

# %%
records_df.drop(columns=['sourceName'], inplace=True)
records_df
# Out:
#                                                     type       unit  \
# 13                     HKQuantityTypeIdentifierHeartRate  count/min
# 14                     HKQuantityTypeIdentifierHeartRate  count/min
# 15                     HKQuantityTypeIdentifierHeartRate  count/min
# 16                     HKQuantityTypeIdentifierHeartRate  count/min
# 17                     HKQuantityTypeIdentifierHeartRate  count/min
# ...                                                  ...        ...
# 911267  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911268  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911269  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911270  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911271  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
#
#                      creationDate                  startDate  \
# 13      2023-09-17 10:44:10 -0500  2023-09-17 10:42:00 -0500
# 14      2023-09-17 10:45:48 -0500  2023-09-17 10:45:47 -0500
# 15      2023-09-17 10:48:58 -0500  2023-09-17 10:47:40 -0500
# 16      2023-09-17 10:50:02 -0500  2023-09-17 10:47:48 -0500
# 17      2023-09-17 10:57:10 -0500  2023-09-17 10:56:18 -0500
# ...                           ...                        ...
# 911267  2025-02-25 21:29:58 -0500  2025-02-25 21:28:57 -0500
# 911268  2025-02-26 06:45:04 -0500  2025-02-26 06:44:03 -0500
# 911269  2025-02-26 07:57:41 -0500  2025-02-26 07:56:40 -0500
# 911270  2025-02-26 13:43:06 -0500  2025-02-26 13:42:05 -0500
# 911271  2025-02-26 15:09:12 -0500  2025-02-26 15:08:11 -0500
#
#                           endDate    value     device
# 13      2023-09-17 10:42:00 -0500       71  Watch6,14
# 14      2023-09-17 10:45:47 -0500      104  Watch6,14
# 15      2023-09-17 10:47:40 -0500  63.4445  Watch6,14
# 16      2023-09-17 10:47:48 -0500       55  Watch6,14
# 17      2023-09-17 10:56:18 -0500      106  Watch6,14
# ...                           ...      ...        ...
# 911267  2025-02-25 21:29:54 -0500  144.231  Watch6,10
# 911268  2025-02-26 06:45:03 -0500  120.072  Watch6,10
# 911269  2025-02-26 07:57:39 -0500  38.8269  Watch6,10
# 911270  2025-02-26 13:43:04 -0500  39.7098  Watch6,10
# 911271  2025-02-26 15:09:11 -0500  27.7803  Watch6,10
#
# [699403 rows x 7 columns]

# %%
records_df['creationYear'] = pd.to_datetime(records_df['creationDate']).dt.year
records_df['creationMonth'] = pd.to_datetime(records_df['creationDate']).dt.month
records_df['creationDay'] = pd.to_datetime(records_df['creationDate']).dt.day

records_df['startYear'] = pd.to_datetime(records_df['startDate']).dt.year
records_df['startMonth'] = pd.to_datetime(records_df['startDate']).dt.month
records_df['startDay'] = pd.to_datetime(records_df['startDate']).dt.day

records_df['endYear'] = pd.to_datetime(records_df['endDate']).dt.year
records_df['endMonth'] = pd.to_datetime(records_df['endDate']).dt.month
records_df['endDay'] = pd.to_datetime(records_df['endDate']).dt.day

records_df
# Out:
#                                                     type       unit  \
# 13                     HKQuantityTypeIdentifierHeartRate  count/min
# 14                     HKQuantityTypeIdentifierHeartRate  count/min
# 15                     HKQuantityTypeIdentifierHeartRate  count/min
# 16                     HKQuantityTypeIdentifierHeartRate  count/min
# 17                     HKQuantityTypeIdentifierHeartRate  count/min
# ...                                                  ...        ...
# 911267  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911268  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911269  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911270  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911271  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
#
#                      creationDate                  startDate  \
# 13      2023-09-17 10:44:10 -0500  2023-09-17 10:42:00 -0500
# 14      2023-09-17 10:45:48 -0500  2023-09-17 10:45:47 -0500
# 15      2023-09-17 10:48:58 -0500  2023-09-17 10:47:40 -0500
# 16      2023-09-17 10:50:02 -0500  2023-09-17 10:47:48 -0500
# 17      2023-09-17 10:57:10 -0500  2023-09-17 10:56:18 -0500
# ...                           ...                        ...
# 911267  2025-02-25 21:29:58 -0500  2025-02-25 21:28:57 -0500
# 911268  2025-02-26 06:45:04 -0500  2025-02-26 06:44:03 -0500
# 911269  2025-02-26 07:57:41 -0500  2025-02-26 07:56:40 -0500
# 911270  2025-02-26 13:43:06 -0500  2025-02-26 13:42:05 -0500
# 911271  2025-02-26 15:09:12 -0500  2025-02-26 15:08:11 -0500
#
#                           endDate    value     device  creationYear  \
# 13      2023-09-17 10:42:00 -0500       71  Watch6,14          2023
# 14      2023-09-17 10:45:47 -0500      104  Watch6,14          2023
# 15      2023-09-17 10:47:40 -0500  63.4445  Watch6,14          2023
# 16      2023-09-17 10:47:48 -0500       55  Watch6,14          2023
# 17      2023-09-17 10:56:18 -0500      106  Watch6,14          2023
# ...                           ...      ...        ...           ...
# 911267  2025-02-25 21:29:54 -0500  144.231  Watch6,10          2025
# 911268  2025-02-26 06:45:03 -0500  120.072  Watch6,10          2025
# 911269  2025-02-26 07:57:39 -0500  38.8269  Watch6,10          2025
# 911270  2025-02-26 13:43:04 -0500  39.7098  Watch6,10          2025
# 911271  2025-02-26 15:09:11 -0500  27.7803  Watch6,10          2025
#
#         creationMonth  creationDay  startYear  startMonth  startDay  endYear  \
# 13                  9           17       2023           9        17     2023
# 14                  9           17       2023           9        17     2023
# 15                  9           17       2023           9        17     2023
# 16                  9           17       2023           9        17     2023
# 17                  9           17       2023           9        17     2023
# ...               ...          ...        ...         ...       ...      ...
# 911267              2           25       2025           2        25     2025
# 911268              2           26       2025           2        26     2025
# 911269              2           26       2025           2        26     2025
# 911270              2           26       2025           2        26     2025
# 911271              2           26       2025           2        26     2025
#
#         endMonth  endDay
# 13             9      17
# 14             9      17
# 15             9      17
# 16             9      17
# 17             9      17
# ...          ...     ...
# 911267         2      25
# 911268         2      26
# 911269         2      26
# 911270         2      26
# 911271         2      26
#
# [699403 rows x 16 columns]

# %%
records_df['creationDate'] = pd.to_datetime(records_df['creationDate']).dt.tz_localize(None)

records_df
# Out:
#                                                     type       unit  \
# 13                     HKQuantityTypeIdentifierHeartRate  count/min
# 14                     HKQuantityTypeIdentifierHeartRate  count/min
# 15                     HKQuantityTypeIdentifierHeartRate  count/min
# 16                     HKQuantityTypeIdentifierHeartRate  count/min
# 17                     HKQuantityTypeIdentifierHeartRate  count/min
# ...                                                  ...        ...
# 911267  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911268  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911269  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911270  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911271  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
#
#               creationDate                  startDate  \
# 13     2023-09-17 10:44:10  2023-09-17 10:42:00 -0500
# 14     2023-09-17 10:45:48  2023-09-17 10:45:47 -0500
# 15     2023-09-17 10:48:58  2023-09-17 10:47:40 -0500
# 16     2023-09-17 10:50:02  2023-09-17 10:47:48 -0500
# 17     2023-09-17 10:57:10  2023-09-17 10:56:18 -0500
# ...                    ...                        ...
# 911267 2025-02-25 21:29:58  2025-02-25 21:28:57 -0500
# 911268 2025-02-26 06:45:04  2025-02-26 06:44:03 -0500
# 911269 2025-02-26 07:57:41  2025-02-26 07:56:40 -0500
# 911270 2025-02-26 13:43:06  2025-02-26 13:42:05 -0500
# 911271 2025-02-26 15:09:12  2025-02-26 15:08:11 -0500
#
#                           endDate    value     device  creationYear  \
# 13      2023-09-17 10:42:00 -0500       71  Watch6,14          2023
# 14      2023-09-17 10:45:47 -0500      104  Watch6,14          2023
# 15      2023-09-17 10:47:40 -0500  63.4445  Watch6,14          2023
# 16      2023-09-17 10:47:48 -0500       55  Watch6,14          2023
# 17      2023-09-17 10:56:18 -0500      106  Watch6,14          2023
# ...                           ...      ...        ...           ...
# 911267  2025-02-25 21:29:54 -0500  144.231  Watch6,10          2025
# 911268  2025-02-26 06:45:03 -0500  120.072  Watch6,10          2025
# 911269  2025-02-26 07:57:39 -0500  38.8269  Watch6,10          2025
# 911270  2025-02-26 13:43:04 -0500  39.7098  Watch6,10          2025
# 911271  2025-02-26 15:09:11 -0500  27.7803  Watch6,10          2025
#
#         creationMonth  creationDay  startYear  startMonth  startDay  endYear  \
# 13                  9           17       2023           9        17     2023
# 14                  9           17       2023           9        17     2023
# 15                  9           17       2023           9        17     2023
# 16                  9           17       2023           9        17     2023
# 17                  9           17       2023           9        17     2023
# ...               ...          ...        ...         ...       ...      ...
# 911267              2           25       2025           2        25     2025
# 911268              2           26       2025           2        26     2025
# 911269              2           26       2025           2        26     2025
# 911270              2           26       2025           2        26     2025
# 911271              2           26       2025           2        26     2025
#
#         endMonth  endDay
# 13             9      17
# 14             9      17
# 15             9      17
# 16             9      17
# 17             9      17
# ...          ...     ...
# 911267         2      25
# 911268         2      26
# 911269         2      26
# 911270         2      26
# 911271         2      26
#
# [699403 rows x 16 columns]

# %%
records_df['startDate'] = pd.to_datetime(records_df['startDate']).dt.tz_localize(None)
records_df['endDate'] = pd.to_datetime(records_df['endDate']).dt.tz_localize(None)
records_df
# Out:
#                                                     type       unit  \
# 13                     HKQuantityTypeIdentifierHeartRate  count/min
# 14                     HKQuantityTypeIdentifierHeartRate  count/min
# 15                     HKQuantityTypeIdentifierHeartRate  count/min
# 16                     HKQuantityTypeIdentifierHeartRate  count/min
# 17                     HKQuantityTypeIdentifierHeartRate  count/min
# ...                                                  ...        ...
# 911267  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911268  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911269  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911270  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911271  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
#
#               creationDate           startDate             endDate    value  \
# 13     2023-09-17 10:44:10 2023-09-17 10:42:00 2023-09-17 10:42:00       71
# 14     2023-09-17 10:45:48 2023-09-17 10:45:47 2023-09-17 10:45:47      104
# 15     2023-09-17 10:48:58 2023-09-17 10:47:40 2023-09-17 10:47:40  63.4445
# 16     2023-09-17 10:50:02 2023-09-17 10:47:48 2023-09-17 10:47:48       55
# 17     2023-09-17 10:57:10 2023-09-17 10:56:18 2023-09-17 10:56:18      106
# ...                    ...                 ...                 ...      ...
# 911267 2025-02-25 21:29:58 2025-02-25 21:28:57 2025-02-25 21:29:54  144.231
# 911268 2025-02-26 06:45:04 2025-02-26 06:44:03 2025-02-26 06:45:03  120.072
# 911269 2025-02-26 07:57:41 2025-02-26 07:56:40 2025-02-26 07:57:39  38.8269
# 911270 2025-02-26 13:43:06 2025-02-26 13:42:05 2025-02-26 13:43:04  39.7098
# 911271 2025-02-26 15:09:12 2025-02-26 15:08:11 2025-02-26 15:09:11  27.7803
#
#            device  creationYear  creationMonth  creationDay  startYear  \
# 13      Watch6,14          2023              9           17       2023
# 14      Watch6,14          2023              9           17       2023
# 15      Watch6,14          2023              9           17       2023
# 16      Watch6,14          2023              9           17       2023
# 17      Watch6,14          2023              9           17       2023
# ...           ...           ...            ...          ...        ...
# 911267  Watch6,10          2025              2           25       2025
# 911268  Watch6,10          2025              2           26       2025
# 911269  Watch6,10          2025              2           26       2025
# 911270  Watch6,10          2025              2           26       2025
# 911271  Watch6,10          2025              2           26       2025
#
#         startMonth  startDay  endYear  endMonth  endDay
# 13               9        17     2023         9      17
# 14               9        17     2023         9      17
# 15               9        17     2023         9      17
# 16               9        17     2023         9      17
# 17               9        17     2023         9      17
# ...            ...       ...      ...       ...     ...
# 911267           2        25     2025         2      25
# 911268           2        26     2025         2      26
# 911269           2        26     2025         2      26
# 911270           2        26     2025         2      26
# 911271           2        26     2025         2      26
#
# [699403 rows x 16 columns]

# %%
records_df.dtypes
# Out:
# type                     object
# unit                     object
# creationDate     datetime64[ns]
# startDate        datetime64[ns]
# endDate          datetime64[ns]
# value                    object
# device                   object
# creationYear              int32
# creationMonth             int32
# creationDay               int32
# startYear                 int32
# startMonth                int32
# startDay                  int32
# endYear                   int32
# endMonth                  int32
# endDay                    int32
# dtype: object

# %%
records_df['value'] = pd.to_numeric(records_df['value'], errors='coerce')
records_df
# Out:
#                                                     type       unit  \
# 13                     HKQuantityTypeIdentifierHeartRate  count/min
# 14                     HKQuantityTypeIdentifierHeartRate  count/min
# 15                     HKQuantityTypeIdentifierHeartRate  count/min
# 16                     HKQuantityTypeIdentifierHeartRate  count/min
# 17                     HKQuantityTypeIdentifierHeartRate  count/min
# ...                                                  ...        ...
# 911267  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911268  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911269  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911270  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911271  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
#
#               creationDate           startDate             endDate     value  \
# 13     2023-09-17 10:44:10 2023-09-17 10:42:00 2023-09-17 10:42:00   71.0000
# 14     2023-09-17 10:45:48 2023-09-17 10:45:47 2023-09-17 10:45:47  104.0000
# 15     2023-09-17 10:48:58 2023-09-17 10:47:40 2023-09-17 10:47:40   63.4445
# 16     2023-09-17 10:50:02 2023-09-17 10:47:48 2023-09-17 10:47:48   55.0000
# 17     2023-09-17 10:57:10 2023-09-17 10:56:18 2023-09-17 10:56:18  106.0000
# ...                    ...                 ...                 ...       ...
# 911267 2025-02-25 21:29:58 2025-02-25 21:28:57 2025-02-25 21:29:54  144.2310
# 911268 2025-02-26 06:45:04 2025-02-26 06:44:03 2025-02-26 06:45:03  120.0720
# 911269 2025-02-26 07:57:41 2025-02-26 07:56:40 2025-02-26 07:57:39   38.8269
# 911270 2025-02-26 13:43:06 2025-02-26 13:42:05 2025-02-26 13:43:04   39.7098
# 911271 2025-02-26 15:09:12 2025-02-26 15:08:11 2025-02-26 15:09:11   27.7803
#
#            device  creationYear  creationMonth  creationDay  startYear  \
# 13      Watch6,14          2023              9           17       2023
# 14      Watch6,14          2023              9           17       2023
# 15      Watch6,14          2023              9           17       2023
# 16      Watch6,14          2023              9           17       2023
# 17      Watch6,14          2023              9           17       2023
# ...           ...           ...            ...          ...        ...
# 911267  Watch6,10          2025              2           25       2025
# 911268  Watch6,10          2025              2           26       2025
# 911269  Watch6,10          2025              2           26       2025
# 911270  Watch6,10          2025              2           26       2025
# 911271  Watch6,10          2025              2           26       2025
#
#         startMonth  startDay  endYear  endMonth  endDay
# 13               9        17     2023         9      17
# 14               9        17     2023         9      17
# 15               9        17     2023         9      17
# 16               9        17     2023         9      17
# 17               9        17     2023         9      17
# ...            ...       ...      ...       ...     ...
# 911267           2        25     2025         2      25
# 911268           2        26     2025         2      26
# 911269           2        26     2025         2      26
# 911270           2        26     2025         2      26
# 911271           2        26     2025         2      26
#
# [699403 rows x 16 columns]

# %%
records_df.dtypes
# Out:
# type                     object
# unit                     object
# creationDate     datetime64[ns]
# startDate        datetime64[ns]
# endDate          datetime64[ns]
# value                   float64
# device                   object
# creationYear              int32
# creationMonth             int32
# creationDay               int32
# startYear                 int32
# startMonth                int32
# startDay                  int32
# endYear                   int32
# endMonth                  int32
# endDay                    int32
# dtype: object

# %%
records_df['type'].unique()
# Out:
# array(['HKQuantityTypeIdentifierHeartRate',
#        'HKQuantityTypeIdentifierRespiratoryRate',
#        'HKQuantityTypeIdentifierStepCount',
#        'HKQuantityTypeIdentifierDistanceWalkingRunning',
#        'HKQuantityTypeIdentifierBasalEnergyBurned',
#        'HKQuantityTypeIdentifierActiveEnergyBurned',
#        'HKQuantityTypeIdentifierFlightsClimbed',
#        'HKQuantityTypeIdentifierAppleExerciseTime',
#        'HKQuantityTypeIdentifierDistanceCycling',
#        'HKQuantityTypeIdentifierDistanceSwimming',
#        'HKQuantityTypeIdentifierSwimmingStrokeCount',
#        'HKQuantityTypeIdentifierEnvironmentalAudioExposure',
#        'HKQuantityTypeIdentifierWalkingDoubleSupportPercentage',
#        'HKQuantityTypeIdentifierWalkingSpeed',
#        'HKQuantityTypeIdentifierWalkingStepLength',
#        'HKQuantityTypeIdentifierWalkingAsymmetryPercentage',
#        'HKQuantityTypeIdentifierAppleWalkingSteadiness',
#        'HKQuantityTypeIdentifierTimeInDaylight',
#        'HKQuantityTypeIdentifierHeartRateVariabilitySDNN'], dtype=object)

# %%
records_df['creationHour'] = pd.to_datetime(records_df['creationDate']).dt.hour
records_df
# Out:
#                                                     type       unit  \
# 13                     HKQuantityTypeIdentifierHeartRate  count/min
# 14                     HKQuantityTypeIdentifierHeartRate  count/min
# 15                     HKQuantityTypeIdentifierHeartRate  count/min
# 16                     HKQuantityTypeIdentifierHeartRate  count/min
# 17                     HKQuantityTypeIdentifierHeartRate  count/min
# ...                                                  ...        ...
# 911267  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911268  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911269  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911270  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911271  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
#
#               creationDate           startDate             endDate     value  \
# 13     2023-09-17 10:44:10 2023-09-17 10:42:00 2023-09-17 10:42:00   71.0000
# 14     2023-09-17 10:45:48 2023-09-17 10:45:47 2023-09-17 10:45:47  104.0000
# 15     2023-09-17 10:48:58 2023-09-17 10:47:40 2023-09-17 10:47:40   63.4445
# 16     2023-09-17 10:50:02 2023-09-17 10:47:48 2023-09-17 10:47:48   55.0000
# 17     2023-09-17 10:57:10 2023-09-17 10:56:18 2023-09-17 10:56:18  106.0000
# ...                    ...                 ...                 ...       ...
# 911267 2025-02-25 21:29:58 2025-02-25 21:28:57 2025-02-25 21:29:54  144.2310
# 911268 2025-02-26 06:45:04 2025-02-26 06:44:03 2025-02-26 06:45:03  120.0720
# 911269 2025-02-26 07:57:41 2025-02-26 07:56:40 2025-02-26 07:57:39   38.8269
# 911270 2025-02-26 13:43:06 2025-02-26 13:42:05 2025-02-26 13:43:04   39.7098
# 911271 2025-02-26 15:09:12 2025-02-26 15:08:11 2025-02-26 15:09:11   27.7803
#
#            device  creationYear  creationMonth  creationDay  startYear  \
# 13      Watch6,14          2023              9           17       2023
# 14      Watch6,14          2023              9           17       2023
# 15      Watch6,14          2023              9           17       2023
# 16      Watch6,14          2023              9           17       2023
# 17      Watch6,14          2023              9           17       2023
# ...           ...           ...            ...          ...        ...
# 911267  Watch6,10          2025              2           25       2025
# 911268  Watch6,10          2025              2           26       2025
# 911269  Watch6,10          2025              2           26       2025
# 911270  Watch6,10          2025              2           26       2025
# 911271  Watch6,10          2025              2           26       2025
#
#         startMonth  startDay  endYear  endMonth  endDay  creationHour
# 13               9        17     2023         9      17            10
# 14               9        17     2023         9      17            10
# 15               9        17     2023         9      17            10
# 16               9        17     2023         9      17            10
# 17               9        17     2023         9      17            10
# ...            ...       ...      ...       ...     ...           ...
# 911267           2        25     2025         2      25            21
# 911268           2        26     2025         2      26             6
# 911269           2        26     2025         2      26             7
# 911270           2        26     2025         2      26            13
# 911271           2        26     2025         2      26            15
#
# [699403 rows x 17 columns]

# %%
records_df['startDateHour'] = pd.to_datetime(records_df['startDate']).dt.hour
records_df['endDateHour'] = pd.to_datetime(records_df['endDate']).dt.hour
records_df
# Out:
#                                                     type       unit  \
# 13                     HKQuantityTypeIdentifierHeartRate  count/min
# 14                     HKQuantityTypeIdentifierHeartRate  count/min
# 15                     HKQuantityTypeIdentifierHeartRate  count/min
# 16                     HKQuantityTypeIdentifierHeartRate  count/min
# 17                     HKQuantityTypeIdentifierHeartRate  count/min
# ...                                                  ...        ...
# 911267  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911268  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911269  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911270  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 911271  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
#
#               creationDate           startDate             endDate     value  \
# 13     2023-09-17 10:44:10 2023-09-17 10:42:00 2023-09-17 10:42:00   71.0000
# 14     2023-09-17 10:45:48 2023-09-17 10:45:47 2023-09-17 10:45:47  104.0000
# 15     2023-09-17 10:48:58 2023-09-17 10:47:40 2023-09-17 10:47:40   63.4445
# 16     2023-09-17 10:50:02 2023-09-17 10:47:48 2023-09-17 10:47:48   55.0000
# 17     2023-09-17 10:57:10 2023-09-17 10:56:18 2023-09-17 10:56:18  106.0000
# ...                    ...                 ...                 ...       ...
# 911267 2025-02-25 21:29:58 2025-02-25 21:28:57 2025-02-25 21:29:54  144.2310
# 911268 2025-02-26 06:45:04 2025-02-26 06:44:03 2025-02-26 06:45:03  120.0720
# 911269 2025-02-26 07:57:41 2025-02-26 07:56:40 2025-02-26 07:57:39   38.8269
# 911270 2025-02-26 13:43:06 2025-02-26 13:42:05 2025-02-26 13:43:04   39.7098
# 911271 2025-02-26 15:09:12 2025-02-26 15:08:11 2025-02-26 15:09:11   27.7803
#
#            device  creationYear  creationMonth  creationDay  startYear  \
# 13      Watch6,14          2023              9           17       2023
# 14      Watch6,14          2023              9           17       2023
# 15      Watch6,14          2023              9           17       2023
# 16      Watch6,14          2023              9           17       2023
# 17      Watch6,14          2023              9           17       2023
# ...           ...           ...            ...          ...        ...
# 911267  Watch6,10          2025              2           25       2025
# 911268  Watch6,10          2025              2           26       2025
# 911269  Watch6,10          2025              2           26       2025
# 911270  Watch6,10          2025              2           26       2025
# 911271  Watch6,10          2025              2           26       2025
#
#         startMonth  startDay  endYear  endMonth  endDay  creationHour  \
# 13               9        17     2023         9      17            10
# 14               9        17     2023         9      17            10
# 15               9        17     2023         9      17            10
# 16               9        17     2023         9      17            10
# 17               9        17     2023         9      17            10
# ...            ...       ...      ...       ...     ...           ...
# 911267           2        25     2025         2      25            21
# 911268           2        26     2025         2      26             6
# 911269           2        26     2025         2      26             7
# 911270           2        26     2025         2      26            13
# 911271           2        26     2025         2      26            15
#
#         startDateHour  endDateHour
# 13                 10           10
# 14                 10           10
# 15                 10           10
# 16                 10           10
# 17                 10           10
# ...               ...          ...
# 911267             21           21
# 911268              6            6
# 911269              7            7
# 911270             13           13
# 911271             15           15
#
# [699403 rows x 19 columns]

# %%
records_df['type'].unique()
# Out:
# array(['HKQuantityTypeIdentifierHeartRate',
#        'HKQuantityTypeIdentifierRespiratoryRate',
#        'HKQuantityTypeIdentifierStepCount',
#        'HKQuantityTypeIdentifierDistanceWalkingRunning',
#        'HKQuantityTypeIdentifierBasalEnergyBurned',
#        'HKQuantityTypeIdentifierActiveEnergyBurned',
#        'HKQuantityTypeIdentifierFlightsClimbed',
#        'HKQuantityTypeIdentifierAppleExerciseTime',
#        'HKQuantityTypeIdentifierDistanceCycling',
#        'HKQuantityTypeIdentifierDistanceSwimming',
#        'HKQuantityTypeIdentifierSwimmingStrokeCount',
#        'HKQuantityTypeIdentifierEnvironmentalAudioExposure',
#        'HKQuantityTypeIdentifierWalkingDoubleSupportPercentage',
#        'HKQuantityTypeIdentifierWalkingSpeed',
#        'HKQuantityTypeIdentifierWalkingStepLength',
#        'HKQuantityTypeIdentifierWalkingAsymmetryPercentage',
#        'HKQuantityTypeIdentifierAppleWalkingSteadiness',
#        'HKQuantityTypeIdentifierTimeInDaylight',
#        'HKQuantityTypeIdentifierHeartRateVariabilitySDNN'], dtype=object)

# %%
newDataframe = pd.DataFrame() #initialize empty dataframe
for type in records_df['type'].unique():
  toRemove = 'HKQuantityTypeIdentifier'
  result = toRemove.replace('HKQuantityTypeIdentifier', '')
  result = records_df[records_df['type'] == type]
  result = result.groupby(['creationYear', 'creationMonth', 'creationDay']).agg({
    'type': 'first',
    'unit': 'first',
    'creationDate' :'first',
    'startDate' :'first',
    'endDate' :'first',
    'value': 'mean',  # Average the heart rate values,
    'device' : 'first',
    'startYear' : 'first',
    'startMonth' : 'first',
    'startDay' : 'first',
    'endYear' : 'first',
    'endMonth' : 'first',
    'endDay' : 'first',
    'creationHour': 'first',
    'startDateHour': 'first',
    'endDateHour': 'first'}).reset_index()
newDataframe = pd.concat([newDataframe, result])

# %%
newDataframe
# Out:
#      creationYear  creationMonth  creationDay  \
# 0            2023              9           17
# 1            2023              9           18
# 2            2023              9           19
# 3            2023              9           20
# 4            2023              9           21
# ..            ...            ...          ...
# 380          2025              2           22
# 381          2025              2           23
# 382          2025              2           24
# 383          2025              2           25
# 384          2025              2           26
#
#                                                  type unit  \
# 0    HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 1    HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 2    HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 3    HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 4    HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# ..                                                ...  ...
# 380  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 381  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 382  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 383  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 384  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
#
#            creationDate           startDate             endDate       value  \
# 0   2023-09-17 10:48:41 2023-09-17 10:47:40 2023-09-17 10:48:35  163.749333
# 1   2023-09-18 00:12:19 2023-09-18 00:11:18 2023-09-18 00:12:17  104.862386
# 2   2023-09-19 02:23:53 2023-09-19 02:22:52 2023-09-19 02:23:52  109.575417
# 3   2023-09-20 02:23:53 2023-09-20 02:22:52 2023-09-20 02:23:51  104.425250
# 4   2023-09-21 02:23:53 2023-09-21 02:22:52 2023-09-21 02:23:52  101.039750
# ..                  ...                 ...                 ...         ...
# 380 2025-02-22 03:02:14 2025-02-22 03:01:13 2025-02-22 03:02:12   83.224133
# 381 2025-02-23 03:03:35 2025-02-23 03:02:34 2025-02-23 03:03:34   93.119400
# 382 2025-02-24 06:43:34 2025-02-24 06:42:33 2025-02-24 06:43:33   90.432667
# 383 2025-02-25 07:40:11 2025-02-25 07:39:10 2025-02-25 07:40:09   82.634000
# 384 2025-02-26 06:45:04 2025-02-26 06:44:03 2025-02-26 06:45:03   56.597250
#
#         device  startYear  startMonth  startDay  endYear  endMonth  endDay  \
# 0    Watch6,14       2023           9        17     2023         9      17
# 1    Watch6,14       2023           9        18     2023         9      18
# 2    Watch6,14       2023           9        19     2023         9      19
# 3    Watch6,14       2023           9        20     2023         9      20
# 4    Watch6,14       2023           9        21     2023         9      21
# ..         ...        ...         ...       ...      ...       ...     ...
# 380  Watch6,10       2025           2        22     2025         2      22
# 381  Watch6,10       2025           2        23     2025         2      23
# 382  Watch6,10       2025           2        24     2025         2      24
# 383  Watch6,10       2025           2        25     2025         2      25
# 384  Watch6,10       2025           2        26     2025         2      26
#
#      creationHour  startDateHour  endDateHour
# 0              10             10           10
# 1               0              0            0
# 2               2              2            2
# 3               2              2            2
# 4               2              2            2
# ..            ...            ...          ...
# 380             3              3            3
# 381             3              3            3
# 382             6              6            6
# 383             7              7            7
# 384             6              6            6
#
# [385 rows x 19 columns]

# %%
for i in newDataframe['creationHour']:
  if i >= 0 and i <= 11:
    newDataframe['timeOfDay'] = 'Morning'
  elif i >= 12 and i <= 16:
    newDataframe['timeOfDay'] = 'Afternoon'
  elif i >= 17 and i <= 20:
    newDataframe['timeOfDay'] = 'Evening'
  else:
    newDataframe['timeOfDay'] = 'Night'
newDataframe
# Out:
#      creationYear  creationMonth  creationDay  \
# 0            2023              9           17
# 1            2023              9           18
# 2            2023              9           19
# 3            2023              9           20
# 4            2023              9           21
# ..            ...            ...          ...
# 380          2025              2           22
# 381          2025              2           23
# 382          2025              2           24
# 383          2025              2           25
# 384          2025              2           26
#
#                                                  type unit  \
# 0    HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 1    HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 2    HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 3    HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 4    HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# ..                                                ...  ...
# 380  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 381  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 382  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 383  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 384  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
#
#            creationDate           startDate             endDate       value  \
# 0   2023-09-17 10:48:41 2023-09-17 10:47:40 2023-09-17 10:48:35  163.749333
# 1   2023-09-18 00:12:19 2023-09-18 00:11:18 2023-09-18 00:12:17  104.862386
# 2   2023-09-19 02:23:53 2023-09-19 02:22:52 2023-09-19 02:23:52  109.575417
# 3   2023-09-20 02:23:53 2023-09-20 02:22:52 2023-09-20 02:23:51  104.425250
# 4   2023-09-21 02:23:53 2023-09-21 02:22:52 2023-09-21 02:23:52  101.039750
# ..                  ...                 ...                 ...         ...
# 380 2025-02-22 03:02:14 2025-02-22 03:01:13 2025-02-22 03:02:12   83.224133
# 381 2025-02-23 03:03:35 2025-02-23 03:02:34 2025-02-23 03:03:34   93.119400
# 382 2025-02-24 06:43:34 2025-02-24 06:42:33 2025-02-24 06:43:33   90.432667
# 383 2025-02-25 07:40:11 2025-02-25 07:39:10 2025-02-25 07:40:09   82.634000
# 384 2025-02-26 06:45:04 2025-02-26 06:44:03 2025-02-26 06:45:03   56.597250
#
#         device  startYear  startMonth  startDay  endYear  endMonth  endDay  \
# 0    Watch6,14       2023           9        17     2023         9      17
# 1    Watch6,14       2023           9        18     2023         9      18
# 2    Watch6,14       2023           9        19     2023         9      19
# 3    Watch6,14       2023           9        20     2023         9      20
# 4    Watch6,14       2023           9        21     2023         9      21
# ..         ...        ...         ...       ...      ...       ...     ...
# 380  Watch6,10       2025           2        22     2025         2      22
# 381  Watch6,10       2025           2        23     2025         2      23
# 382  Watch6,10       2025           2        24     2025         2      24
# 383  Watch6,10       2025           2        25     2025         2      25
# 384  Watch6,10       2025           2        26     2025         2      26
#
#      creationHour  startDateHour  endDateHour timeOfDay
# 0              10             10           10   Morning
# 1               0              0            0   Morning
# 2               2              2            2   Morning
# 3               2              2            2   Morning
# 4               2              2            2   Morning
# ..            ...            ...          ...       ...
# 380             3              3            3   Morning
# 381             3              3            3   Morning
# 382             6              6            6   Morning
# 383             7              7            7   Morning
# 384             6              6            6   Morning
#
# [385 rows x 20 columns]

# %% [markdown]
# #Correlation Matrix

# %%
numeric_df = records_df.select_dtypes(include=['number'])
matrix = numeric_df.corr()

# plotting correlation matrix
plt.imshow(matrix, cmap='Blues')

# adding colorbar
plt.colorbar()

# extracting variable names
variables = []
for i in matrix.columns:
    variables.append(i)

# Adding labels to the matrix
plt.xticks(range(len(matrix)), variables, rotation=45, ha='right')
plt.yticks(range(len(matrix)), variables)

# Display the plot
plt.show()

# %%
#records_df.to_excel("records.xlsx", index=False)

# %% [markdown]
# # Grab the unique record statistics for each day!

# %%
records_df['type'].unique()
# Out:
# array(['HKQuantityTypeIdentifierHeartRate',
#        'HKQuantityTypeIdentifierRespiratoryRate',
#        'HKQuantityTypeIdentifierStepCount',
#        'HKQuantityTypeIdentifierDistanceWalkingRunning',
#        'HKQuantityTypeIdentifierBasalEnergyBurned',
#        'HKQuantityTypeIdentifierActiveEnergyBurned',
#        'HKQuantityTypeIdentifierFlightsClimbed',
#        'HKQuantityTypeIdentifierAppleExerciseTime',
#        'HKQuantityTypeIdentifierDistanceCycling',
#        'HKQuantityTypeIdentifierDistanceSwimming',
#        'HKQuantityTypeIdentifierSwimmingStrokeCount',
#        'HKQuantityTypeIdentifierEnvironmentalAudioExposure',
#        'HKQuantityTypeIdentifierWalkingDoubleSupportPercentage',
#        'HKQuantityTypeIdentifierWalkingSpeed',
#        'HKQuantityTypeIdentifierWalkingStepLength',
#        'HKQuantityTypeIdentifierWalkingAsymmetryPercentage',
#        'HKQuantityTypeIdentifierAppleWalkingSteadiness',
#        'HKQuantityTypeIdentifierTimeInDaylight',
#        'HKQuantityTypeIdentifierHeartRateVariabilitySDNN'], dtype=object)

# %%
newDataframe = pd.DataFrame() #initialize empty dataframe
for type in records_df['type'].unique():
  toRemove = 'HKQuantityTypeIdentifier'
  result = toRemove.replace('HKQuantityTypeIdentifier', '')
  result = records_df[records_df['type'] == type]
  result = result.groupby(['creationYear', 'creationMonth', 'creationDay']).agg({
    'type': 'first',
    'unit': 'first',
    'creationDate' :'first',
    'startDate' :'first',
    'endDate' :'first',
    'value': 'mean',  # Average the heart rate values,
    'device' : 'first',
    'startYear' : 'first',
    'startMonth' : 'first',
    'startDay' : 'first',
    'endYear' : 'first',
    'endMonth' : 'first',
    'endDay' : 'first',}).reset_index()
  newDataframe = pd.concat([newDataframe, result])

#respritoryRate_dataframe = records_df[records_df['type'] == 'HKQuantityTypeIdentifierRespiratoryRate']
#respritoryRate_dataframe = respritoryRate_dataframe.groupby(['creationYear', 'creationMonth', 'creationDay']).agg({
#    'type': 'first',
#    'unit': 'first',
#    'creationDate' :'first',
#    'startDate' :'first',
#    'endDate' :'first',
#    'value': 'mean',  # Average the heart rate values,
#    'device' : 'first',
#    'startYear' : 'first',
#    'startMonth' : 'first',
#    'startDay' : 'first',
#    'endYear' : 'first',
#    'endMonth' : 'first',
#    'endDay' : 'first',
#}).reset_index()
newDataframe
# Out:
#      creationYear  creationMonth  creationDay  \
# 0            2023              9           17
# 1            2023              9           18
# 2            2023              9           19
# 3            2023              9           20
# 4            2023              9           21
# ..            ...            ...          ...
# 380          2025              2           22
# 381          2025              2           23
# 382          2025              2           24
# 383          2025              2           25
# 384          2025              2           26
#
#                                                  type       unit  \
# 0                   HKQuantityTypeIdentifierHeartRate  count/min
# 1                   HKQuantityTypeIdentifierHeartRate  count/min
# 2                   HKQuantityTypeIdentifierHeartRate  count/min
# 3                   HKQuantityTypeIdentifierHeartRate  count/min
# 4                   HKQuantityTypeIdentifierHeartRate  count/min
# ..                                                ...        ...
# 380  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 381  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 382  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 383  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
# 384  HKQuantityTypeIdentifierHeartRateVariabilitySDNN         ms
#
#            creationDate           startDate             endDate      value  \
# 0   2023-09-17 10:44:10 2023-09-17 10:42:00 2023-09-17 10:42:00  91.276707
# 1   2023-09-18 00:12:20 2023-09-18 00:11:18 2023-09-18 00:11:18  70.471606
# 2   2023-09-19 00:00:14 2023-09-18 23:52:39 2023-09-18 23:52:39  88.811479
# 3   2023-09-20 00:05:31 2023-09-20 00:01:56 2023-09-20 00:01:56  70.439298
# 4   2023-09-21 00:04:58 2023-09-20 23:56:59 2023-09-20 23:56:59  91.571834
# ..                  ...                 ...                 ...        ...
# 380 2025-02-22 03:02:14 2025-02-22 03:01:13 2025-02-22 03:02:12  83.224133
# 381 2025-02-23 03:03:35 2025-02-23 03:02:34 2025-02-23 03:03:34  93.119400
# 382 2025-02-24 06:43:34 2025-02-24 06:42:33 2025-02-24 06:43:33  90.432667
# 383 2025-02-25 07:40:11 2025-02-25 07:39:10 2025-02-25 07:40:09  82.634000
# 384 2025-02-26 06:45:04 2025-02-26 06:44:03 2025-02-26 06:45:03  56.597250
#
#         device  startYear  startMonth  startDay  endYear  endMonth  endDay
# 0    Watch6,14       2023           9        17     2023         9      17
# 1    Watch6,14       2023           9        18     2023         9      18
# 2    Watch6,14       2023           9        18     2023         9      18
# 3    Watch6,14       2023           9        20     2023         9      20
# 4    Watch6,14       2023           9        20     2023         9      20
# ..         ...        ...         ...       ...      ...       ...     ...
# 380  Watch6,10       2025           2        22     2025         2      22
# 381  Watch6,10       2025           2        23     2025         2      23
# 382  Watch6,10       2025           2        24     2025         2      24
# 383  Watch6,10       2025           2        25     2025         2      25
# 384  Watch6,10       2025           2        26     2025         2      26
#
# [14657 rows x 16 columns]

# %%
newDataframe.to_excel("UniqueRecordsEachDay.xlsx", index=False)

# %% [markdown]
# #Look into later, build an ML model

# %% [markdown]
# #Look at Activity Table

# %%
activity_summary_df
# Out:
#     dateComponents activeEnergyBurned activeEnergyBurnedGoal  \
# 0       2022-09-20             79.454                    240
# 1       2022-09-21             92.923                    240
# 2       2022-09-22            151.574                    240
# 3       2022-09-23             61.259                    240
# 4       2022-09-24             62.416                    240
# ..             ...                ...                    ...
# 797     2025-02-22            290.453                    270
# 798     2025-02-23            250.286                    270
# 799     2025-02-24            302.848                    270
# 800     2025-02-25            255.962                    270
# 801     2025-02-26             186.83                    270
#
#     activeEnergyBurnedUnit appleMoveTime appleMoveTimeGoal appleExerciseTime  \
# 0                      Cal             0                 0                 0
# 1                      Cal             0                 0                 0
# 2                      Cal             0                 0                 0
# 3                      Cal             0                 0                 0
# 4                      Cal             0                 0                 0
# ..                     ...           ...               ...               ...
# 797                    Cal             0                 0                 9
# 798                    Cal             0                 0                 5
# 799                    Cal             0                 0                 8
# 800                    Cal             0                 0                11
# 801                    Cal             0                 0                 4
#
#     appleExerciseTimeGoal appleStandHours appleStandHoursGoal
# 0                       0               0                   0
# 1                       0               0                   0
# 2                       0               0                   0
# 3                       0               0                   0
# 4                       0               0                   0
# ..                    ...             ...                 ...
# 797                    20              16                  12
# 798                    20              13                  12
# 799                    20              18                  12
# 800                    20              14                  12
# 801                    20              11                  12
#
# [802 rows x 10 columns]

# %% [markdown]
# #Good, no null values

# %%
activity_summary_df.isnull().sum()
# Out:
# dateComponents            0
# activeEnergyBurned        0
# activeEnergyBurnedGoal    0
# activeEnergyBurnedUnit    0
# appleMoveTime             0
# appleMoveTimeGoal         0
# appleExerciseTime         0
# appleExerciseTimeGoal     0
# appleStandHours           0
# appleStandHoursGoal       0
# dtype: int64

# %%
activity_summary_df.dtypes
# Out:
# dateComponents            object
# activeEnergyBurned        object
# activeEnergyBurnedGoal    object
# activeEnergyBurnedUnit    object
# appleMoveTime             object
# appleMoveTimeGoal         object
# appleExerciseTime         object
# appleExerciseTimeGoal     object
# appleStandHours           object
# appleStandHoursGoal       object
# dtype: object

# %% [markdown]
# #Add new feature (boolean: did you meet goal)

# %%
activity_summary_df['activeEnergyBurned'] = pd.to_numeric(activity_summary_df['activeEnergyBurned'], errors='coerce')
activity_summary_df['activeEnergyBurnedGoal'] = pd.to_numeric(activity_summary_df['activeEnergyBurnedGoal'], errors='coerce')

# %%
activity_summary_df['met_energy_goal'] = activity_summary_df['activeEnergyBurned'] >= activity_summary_df['activeEnergyBurnedGoal']
activity_summary_df
# Out:
#     dateComponents  activeEnergyBurned  activeEnergyBurnedGoal  \
# 0       2022-09-20              79.454                     240
# 1       2022-09-21              92.923                     240
# 2       2022-09-22             151.574                     240
# 3       2022-09-23              61.259                     240
# 4       2022-09-24              62.416                     240
# ..             ...                 ...                     ...
# 797     2025-02-22             290.453                     270
# 798     2025-02-23             250.286                     270
# 799     2025-02-24             302.848                     270
# 800     2025-02-25             255.962                     270
# 801     2025-02-26             186.830                     270
#
#     activeEnergyBurnedUnit appleMoveTime appleMoveTimeGoal appleExerciseTime  \
# 0                      Cal             0                 0                 0
# 1                      Cal             0                 0                 0
# 2                      Cal             0                 0                 0
# 3                      Cal             0                 0                 0
# 4                      Cal             0                 0                 0
# ..                     ...           ...               ...               ...
# 797                    Cal             0                 0                 9
# 798                    Cal             0                 0                 5
# 799                    Cal             0                 0                 8
# 800                    Cal             0                 0                11
# 801                    Cal             0                 0                 4
#
#     appleExerciseTimeGoal appleStandHours appleStandHoursGoal  met_energy_goal
# 0                       0               0                   0            False
# 1                       0               0                   0            False
# 2                       0               0                   0            False
# 3                       0               0                   0            False
# 4                       0               0                   0            False
# ..                    ...             ...                 ...              ...
# 797                    20              16                  12             True
# 798                    20              13                  12            False
# 799                    20              18                  12             True
# 800                    20              14                  12            False
# 801                    20              11                  12            False
#
# [802 rows x 11 columns]

# %% [markdown]
# #Count how many times energy goals have been met and plot it in a pie chart

# %%
met_goal = activity_summary_df['met_energy_goal'].value_counts()
met_goal
# Out:
# met_energy_goal
# False    568
# True     234
# Name: count, dtype: int64

# %%
plotGoal = met_goal.plot.pie(y='count', figsize=(10, 10), autopct='%1.1f%%')
plt.ylabel('')
plt.xlabel('')
plt.title('How many times did Jannah meet her Energy goals')
plt.show()

# %% [markdown]
# #Yikes, you need to move more and meet your energy goals

# %% [markdown]
# #Analyze how much time Jojo moves

# %%
activity_summary_df.dtypes
# Out:
# dateComponents             object
# activeEnergyBurned        float64
# activeEnergyBurnedGoal      int64
# activeEnergyBurnedUnit     object
# appleMoveTime              object
# appleMoveTimeGoal          object
# appleExerciseTime          object
# appleExerciseTimeGoal      object
# appleStandHours            object
# appleStandHoursGoal        object
# met_energy_goal              bool
# dtype: object

# %%
activity_summary_df['dateComponents'] = pd.to_datetime(activity_summary_df['dateComponents']).dt.date

# %%
averageCaloriesBurned = activity_summary_df.groupby('dateComponents')['activeEnergyBurned'].mean()
averageCaloriesBurned
# Out:
# dateComponents
# 2022-09-20     79.454
# 2022-09-21     92.923
# 2022-09-22    151.574
# 2022-09-23     61.259
# 2022-09-24     62.416
#                ...
# 2025-02-22    290.453
# 2025-02-23    250.286
# 2025-02-24    302.848
# 2025-02-25    255.962
# 2025-02-26    186.830
# Name: activeEnergyBurned, Length: 802, dtype: float64

# %% [markdown]
# #Dang Jannah, what kind of drugs were you on to butn that many calories on 09/07/2024?!!!

# %%
largest_ten_caloriesBurned = averageCaloriesBurned.nlargest(10)
largest_ten_caloriesBurned
# Out:
# dateComponents
# 2024-09-07    832.134
# 2024-05-11    762.967
# 2024-07-29    724.887
# 2024-06-24    701.456
# 2024-05-07    698.361
# 2024-08-02    669.910
# 2024-05-18    640.900
# 2024-04-12    639.028
# 2024-08-25    626.231
# 2024-04-14    606.944
# Name: activeEnergyBurned, dtype: float64

# %%
largest_ten_caloriesBurned = largest_ten_caloriesBurned.to_frame()

# %%
sns.barplot(data = largest_ten_caloriesBurned, x = 'dateComponents', y = 'activeEnergyBurned', hue = 'dateComponents', legend = False, palette= "viridis")
plt.title('Average Calories Burned Per Day (Largest 10)')
plt.xlabel('Date')
plt.ylabel('Average Calories Burned Per Day')
plt.xticks(rotation = 90)
plt.figure(figsize=(12, 8))
plt.close()

# %% [markdown]
# #See what unique values exist to see if further analysis is needed here

# %%
activity_summary_df.dtypes
# Out:
# dateComponents             object
# activeEnergyBurned        float64
# activeEnergyBurnedGoal      int64
# activeEnergyBurnedUnit     object
# appleMoveTime              object
# appleMoveTimeGoal          object
# appleExerciseTime          object
# appleExerciseTimeGoal      object
# appleStandHours            object
# appleStandHoursGoal        object
# met_energy_goal              bool
# dtype: object

# %%
activity_summary_df['appleMoveTime'].unique()
# Out:
# array(['0'], dtype=object)

# %%
activity_summary_df['activeEnergyBurnedUnit'].unique()
# Out:
# array(['Cal'], dtype=object)

# %%
activity_summary_df['appleMoveTime'].unique()
# Out:
# array(['0'], dtype=object)

# %%
activity_summary_df['appleMoveTimeGoal'].unique()
# Out:
# array(['0'], dtype=object)

# %%
activity_summary_df['appleExerciseTime'].unique()
# Out:
# array(['0', '32', '31', '24', '30', '12', '3', '1', '20', '45', '60', '4',
#        '22', '38', '26', '16', '7', '51', '46', '23', '14', '33', '9',
#        '18', '15', '40', '37', '41', '62', '10', '5', '2', '8', '13',
#        '11', '6', '21', '17', '66', '36', '19', '44', '43', '35', '63',
#        '42', '34', '28', '78', '109', '57', '47', '50', '65', '29', '117',
#        '64', '164', '120', '68', '67', '39', '48', '59', '53', '49', '27',
#        '105', '93', '56', '61', '79', '58', '25'], dtype=object)

# %%
activity_summary_df['appleExerciseTimeGoal'].unique()
# Out:
# array(['0', '15', '20'], dtype=object)

# %%
activity_summary_df['appleStandHours'].unique()
# Out:
# array(['0', '9', '17', '22', '18', '15', '13', '12', '16', '14', '19',
#        '8', '4', '20', '11', '5', '6', '3', '1', '10', '7', '2'],
#       dtype=object)

# %%
activity_summary_df['appleStandHoursGoal'].unique()
# Out:
# array(['0', '12', '14', '16', '15'], dtype=object)

# %% [markdown]
# #Add more Boolean Variables Rows

# %% [markdown]
# **Convert columns to numeric values**

# %%
activity_summary_df['appleExerciseTime'] = pd.to_numeric(activity_summary_df['appleExerciseTime'], errors='coerce')
activity_summary_df['appleExerciseTimeGoal'] = pd.to_numeric(activity_summary_df['appleExerciseTimeGoal'], errors='coerce')
activity_summary_df['appleStandHours'] = pd.to_numeric(activity_summary_df['appleStandHours'], errors='coerce')
activity_summary_df['appleStandHoursGoal'] = pd.to_numeric(activity_summary_df['appleStandHoursGoal'], errors='coerce')

# %%
activity_summary_df['met_Apple_Exercise_Time'] = activity_summary_df['appleExerciseTime'] >= activity_summary_df['appleExerciseTimeGoal']
activity_summary_df['met_Apple_Stand_Hours'] = activity_summary_df['appleStandHours'] >= activity_summary_df['appleStandHoursGoal']
activity_summary_df
# Out:
#     dateComponents  activeEnergyBurned  activeEnergyBurnedGoal  \
# 0       2022-09-20              79.454                     240
# 1       2022-09-21              92.923                     240
# 2       2022-09-22             151.574                     240
# 3       2022-09-23              61.259                     240
# 4       2022-09-24              62.416                     240
# ..             ...                 ...                     ...
# 797     2025-02-22             290.453                     270
# 798     2025-02-23             250.286                     270
# 799     2025-02-24             302.848                     270
# 800     2025-02-25             255.962                     270
# 801     2025-02-26             186.830                     270
#
#     activeEnergyBurnedUnit appleMoveTime appleMoveTimeGoal  appleExerciseTime  \
# 0                      Cal             0                 0                  0
# 1                      Cal             0                 0                  0
# 2                      Cal             0                 0                  0
# 3                      Cal             0                 0                  0
# 4                      Cal             0                 0                  0
# ..                     ...           ...               ...                ...
# 797                    Cal             0                 0                  9
# 798                    Cal             0                 0                  5
# 799                    Cal             0                 0                  8
# 800                    Cal             0                 0                 11
# 801                    Cal             0                 0                  4
#
#      appleExerciseTimeGoal  appleStandHours  appleStandHoursGoal  \
# 0                        0                0                    0
# 1                        0                0                    0
# 2                        0                0                    0
# 3                        0                0                    0
# 4                        0                0                    0
# ..                     ...              ...                  ...
# 797                     20               16                   12
# 798                     20               13                   12
# 799                     20               18                   12
# 800                     20               14                   12
# 801                     20               11                   12
#
#      met_energy_goal  met_Apple_Exercise_Time  met_Apple_Stand_Hours
# 0              False                     True                   True
# 1              False                     True                   True
# 2              False                     True                   True
# 3              False                     True                   True
# 4              False                     True                   True
# ..               ...                      ...                    ...
# 797             True                    False                   True
# 798            False                    False                   True
# 799             True                    False                   True
# 800            False                    False                   True
# 801            False                    False                  False
#
# [802 rows x 13 columns]

# %%
met_Apple_Exercise_Time = activity_summary_df['met_Apple_Exercise_Time'].value_counts()
met_Apple_Exercise_Time
# Out:
# met_Apple_Exercise_Time
# True     558
# False    244
# Name: count, dtype: int64

# %%
plotGoal = met_Apple_Exercise_Time.plot.pie(y='count', figsize=(10, 10), autopct='%1.1f%%')
plt.ylabel('')
plt.xlabel('')
plt.title('How many times did Jannah meet her Apple Exercise Time')
plt.show()

# %% [markdown]
# #Good Job Jannah, there has been some improvements!!!

# %%
met_Apple_Stand_Hours = activity_summary_df['met_Apple_Stand_Hours'].value_counts()
met_Apple_Stand_Hours
# Out:
# met_Apple_Stand_Hours
# True     628
# False    174
# Name: count, dtype: int64

# %%
plotGoal = met_Apple_Stand_Hours.plot.pie(y='count', figsize=(10, 10), autopct='%1.1f%%')
plt.ylabel('')
plt.xlabel('')
plt.title('How many times did Jannah meet her Apple Stand Hours')
plt.show()

# %% [markdown]
# #Good job JOJO!!! At least you standing up right!

# %%
activity_summary_df
# Out:
#     dateComponents  activeEnergyBurned  activeEnergyBurnedGoal  \
# 0       2022-09-20              79.454                     240
# 1       2022-09-21              92.923                     240
# 2       2022-09-22             151.574                     240
# 3       2022-09-23              61.259                     240
# 4       2022-09-24              62.416                     240
# ..             ...                 ...                     ...
# 797     2025-02-22             290.453                     270
# 798     2025-02-23             250.286                     270
# 799     2025-02-24             302.848                     270
# 800     2025-02-25             255.962                     270
# 801     2025-02-26             186.830                     270
#
#     activeEnergyBurnedUnit appleMoveTime appleMoveTimeGoal  appleExerciseTime  \
# 0                      Cal             0                 0                  0
# 1                      Cal             0                 0                  0
# 2                      Cal             0                 0                  0
# 3                      Cal             0                 0                  0
# 4                      Cal             0                 0                  0
# ..                     ...           ...               ...                ...
# 797                    Cal             0                 0                  9
# 798                    Cal             0                 0                  5
# 799                    Cal             0                 0                  8
# 800                    Cal             0                 0                 11
# 801                    Cal             0                 0                  4
#
#      appleExerciseTimeGoal  appleStandHours  appleStandHoursGoal  \
# 0                        0                0                    0
# 1                        0                0                    0
# 2                        0                0                    0
# 3                        0                0                    0
# 4                        0                0                    0
# ..                     ...              ...                  ...
# 797                     20               16                   12
# 798                     20               13                   12
# 799                     20               18                   12
# 800                     20               14                   12
# 801                     20               11                   12
#
#      met_energy_goal  met_Apple_Exercise_Time  met_Apple_Stand_Hours
# 0              False                     True                   True
# 1              False                     True                   True
# 2              False                     True                   True
# 3              False                     True                   True
# 4              False                     True                   True
# ..               ...                      ...                    ...
# 797             True                    False                   True
# 798            False                    False                   True
# 799             True                    False                   True
# 800            False                    False                   True
# 801            False                    False                  False
#
# [802 rows x 13 columns]

# %%
activity_summary_df.dtypes
# Out:
# dateComponents              object
# activeEnergyBurned         float64
# activeEnergyBurnedGoal       int64
# activeEnergyBurnedUnit      object
# appleMoveTime               object
# appleMoveTimeGoal           object
# appleExerciseTime            int64
# appleExerciseTimeGoal        int64
# appleStandHours              int64
# appleStandHoursGoal          int64
# met_energy_goal               bool
# met_Apple_Exercise_Time       bool
# met_Apple_Stand_Hours         bool
# dtype: object

# %%
activity_summary_df['appleMoveTimeGoal'] = pd.to_numeric(activity_summary_df['appleMoveTimeGoal'], errors='coerce')
activity_summary_df['appleMoveTime'] = pd.to_numeric(activity_summary_df['appleMoveTime'], errors='coerce')
activity_summary_df
# Out:
#     dateComponents  activeEnergyBurned  activeEnergyBurnedGoal  \
# 0       2022-09-20              79.454                     240
# 1       2022-09-21              92.923                     240
# 2       2022-09-22             151.574                     240
# 3       2022-09-23              61.259                     240
# 4       2022-09-24              62.416                     240
# ..             ...                 ...                     ...
# 797     2025-02-22             290.453                     270
# 798     2025-02-23             250.286                     270
# 799     2025-02-24             302.848                     270
# 800     2025-02-25             255.962                     270
# 801     2025-02-26             186.830                     270
#
#     activeEnergyBurnedUnit  appleMoveTime  appleMoveTimeGoal  \
# 0                      Cal              0                  0
# 1                      Cal              0                  0
# 2                      Cal              0                  0
# 3                      Cal              0                  0
# 4                      Cal              0                  0
# ..                     ...            ...                ...
# 797                    Cal              0                  0
# 798                    Cal              0                  0
# 799                    Cal              0                  0
# 800                    Cal              0                  0
# 801                    Cal              0                  0
#
#      appleExerciseTime  appleExerciseTimeGoal  appleStandHours  \
# 0                    0                      0                0
# 1                    0                      0                0
# 2                    0                      0                0
# 3                    0                      0                0
# 4                    0                      0                0
# ..                 ...                    ...              ...
# 797                  9                     20               16
# 798                  5                     20               13
# 799                  8                     20               18
# 800                 11                     20               14
# 801                  4                     20               11
#
#      appleStandHoursGoal  met_energy_goal  met_Apple_Exercise_Time  \
# 0                      0            False                     True
# 1                      0            False                     True
# 2                      0            False                     True
# 3                      0            False                     True
# 4                      0            False                     True
# ..                   ...              ...                      ...
# 797                   12             True                    False
# 798                   12            False                    False
# 799                   12             True                    False
# 800                   12            False                    False
# 801                   12            False                    False
#
#      met_Apple_Stand_Hours
# 0                     True
# 1                     True
# 2                     True
# 3                     True
# 4                     True
# ..                     ...
# 797                   True
# 798                   True
# 799                   True
# 800                   True
# 801                  False
#
# [802 rows x 13 columns]

# %%
activity_summary_df['appleMoveTimeGoal'].unique()
# Out:
# array([0])

# %%
activity_summary_df['appleMoveTime'].unique()
# Out:
# array([0])

# %%
activity_summary_df.drop(columns=['appleMoveTimeGoal', 'appleMoveTime'], inplace=True)
activity_summary_df
# Out:
#     dateComponents  activeEnergyBurned  activeEnergyBurnedGoal  \
# 0       2022-09-20              79.454                     240
# 1       2022-09-21              92.923                     240
# 2       2022-09-22             151.574                     240
# 3       2022-09-23              61.259                     240
# 4       2022-09-24              62.416                     240
# ..             ...                 ...                     ...
# 797     2025-02-22             290.453                     270
# 798     2025-02-23             250.286                     270
# 799     2025-02-24             302.848                     270
# 800     2025-02-25             255.962                     270
# 801     2025-02-26             186.830                     270
#
#     activeEnergyBurnedUnit  appleExerciseTime  appleExerciseTimeGoal  \
# 0                      Cal                  0                      0
# 1                      Cal                  0                      0
# 2                      Cal                  0                      0
# 3                      Cal                  0                      0
# 4                      Cal                  0                      0
# ..                     ...                ...                    ...
# 797                    Cal                  9                     20
# 798                    Cal                  5                     20
# 799                    Cal                  8                     20
# 800                    Cal                 11                     20
# 801                    Cal                  4                     20
#
#      appleStandHours  appleStandHoursGoal  met_energy_goal  \
# 0                  0                    0            False
# 1                  0                    0            False
# 2                  0                    0            False
# 3                  0                    0            False
# 4                  0                    0            False
# ..               ...                  ...              ...
# 797               16                   12             True
# 798               13                   12            False
# 799               18                   12             True
# 800               14                   12            False
# 801               11                   12            False
#
#      met_Apple_Exercise_Time  met_Apple_Stand_Hours
# 0                       True                   True
# 1                       True                   True
# 2                       True                   True
# 3                       True                   True
# 4                       True                   True
# ..                       ...                    ...
# 797                    False                   True
# 798                    False                   True
# 799                    False                   True
# 800                    False                   True
# 801                    False                  False
#
# [802 rows x 11 columns]

# %%
activity_summary_df['dateComponents'] = pd.to_datetime(activity_summary_df['dateComponents']).dt.tz_localize(None)
activity_summary_df.dtypes
# Out:
# dateComponents             datetime64[ns]
# activeEnergyBurned                float64
# activeEnergyBurnedGoal              int64
# activeEnergyBurnedUnit             object
# appleExerciseTime                   int64
# appleExerciseTimeGoal               int64
# appleStandHours                     int64
# appleStandHoursGoal                 int64
# met_energy_goal                      bool
# met_Apple_Exercise_Time              bool
# met_Apple_Stand_Hours                bool
# dtype: object

# %%
activity_summary_df
# Out:
#     dateComponents  activeEnergyBurned  activeEnergyBurnedGoal  \
# 0       2022-09-20              79.454                     240
# 1       2022-09-21              92.923                     240
# 2       2022-09-22             151.574                     240
# 3       2022-09-23              61.259                     240
# 4       2022-09-24              62.416                     240
# ..             ...                 ...                     ...
# 797     2025-02-22             290.453                     270
# 798     2025-02-23             250.286                     270
# 799     2025-02-24             302.848                     270
# 800     2025-02-25             255.962                     270
# 801     2025-02-26             186.830                     270
#
#     activeEnergyBurnedUnit  appleExerciseTime  appleExerciseTimeGoal  \
# 0                      Cal                  0                      0
# 1                      Cal                  0                      0
# 2                      Cal                  0                      0
# 3                      Cal                  0                      0
# 4                      Cal                  0                      0
# ..                     ...                ...                    ...
# 797                    Cal                  9                     20
# 798                    Cal                  5                     20
# 799                    Cal                  8                     20
# 800                    Cal                 11                     20
# 801                    Cal                  4                     20
#
#      appleStandHours  appleStandHoursGoal  met_energy_goal  \
# 0                  0                    0            False
# 1                  0                    0            False
# 2                  0                    0            False
# 3                  0                    0            False
# 4                  0                    0            False
# ..               ...                  ...              ...
# 797               16                   12             True
# 798               13                   12            False
# 799               18                   12             True
# 800               14                   12            False
# 801               11                   12            False
#
#      met_Apple_Exercise_Time  met_Apple_Stand_Hours
# 0                       True                   True
# 1                       True                   True
# 2                       True                   True
# 3                       True                   True
# 4                       True                   True
# ..                       ...                    ...
# 797                    False                   True
# 798                    False                   True
# 799                    False                   True
# 800                    False                   True
# 801                    False                  False
#
# [802 rows x 11 columns]

# %%
#activity_summary_df.to_excel("activities.xlsx", index=False)

# %% [markdown]
# #Look into later. Build a model

# %% [markdown]
# #Explore Workout Table

# %%
workouts_df
# Out:
#                workoutActivityType           duration durationUnit  \
# 0       HKWorkoutActivityTypeOther                  0          min
# 1     HKWorkoutActivityTypeWalking  34.62768211166064          min
# 2     HKWorkoutActivityTypeRunning  17.38285479942958          min
# 3     HKWorkoutActivityTypeRunning  11.51686753034592          min
# 4    HKWorkoutActivityTypeSwimming   6.07142174243927          min
# ..                             ...                ...          ...
# 241   HKWorkoutActivityTypeRunning   9.06705576578776          min
# 242  HKWorkoutActivityTypeCooldown  28.62752670049667          min
# 243  HKWorkoutActivityTypeSwimming  77.92724243203799          min
# 244  HKWorkoutActivityTypeSwimming    62.294687606891          min
# 245  HKWorkoutActivityTypeSwimming  63.09930336872737          min
#
#                sourceName sourceVersion               creationDate  \
# 0                  Health        11.3.1  2018-06-29 14:38:15 -0500
# 1    Jannah’s Apple Watch           9.3  2023-09-17 17:26:39 -0500
# 2    Jannah’s Apple Watch           9.3  2023-09-18 18:24:44 -0500
# 3    Jannah’s Apple Watch           9.3  2023-09-21 15:01:49 -0500
# 4    Jannah’s Apple Watch           9.3  2023-09-26 15:56:23 -0500
# ..                    ...           ...                        ...
# 241  Jannah’s Apple Watch        10.6.1  2024-10-29 19:13:03 -0500
# 242  Jannah’s Apple Watch        10.6.1  2024-10-29 19:41:48 -0500
# 243  Jannah’s Apple Watch          11.0  2025-01-31 16:35:38 -0500
# 244  Jannah’s Apple Watch          11.0  2025-02-03 16:31:21 -0500
# 245  Jannah’s Apple Watch          11.0  2025-02-07 16:24:12 -0500
#
#                      startDate                    endDate  \
# 0    2018-06-29 14:37:00 -0500  2018-06-29 14:37:00 -0500
# 1    2023-09-17 16:51:58 -0500  2023-09-17 17:26:35 -0500
# 2    2023-09-18 18:07:19 -0500  2023-09-18 18:24:42 -0500
# 3    2023-09-21 14:50:17 -0500  2023-09-21 15:01:48 -0500
# 4    2023-09-26 15:50:18 -0500  2023-09-26 15:56:22 -0500
# ..                         ...                        ...
# 241  2024-10-29 19:03:58 -0500  2024-10-29 19:13:02 -0500
# 242  2024-10-29 19:13:09 -0500  2024-10-29 19:41:47 -0500
# 243  2025-01-31 15:17:39 -0500  2025-01-31 16:35:35 -0500
# 244  2025-02-03 15:29:01 -0500  2025-02-03 16:31:19 -0500
# 245  2025-02-07 15:21:04 -0500  2025-02-07 16:24:10 -0500
#
#                                                 device
# 0                                                  NaN
# 1    <<HKDevice: 0x30186e5d0>, name:Apple Watch, ma...
# 2    <<HKDevice: 0x30186e5d0>, name:Apple Watch, ma...
# 3    <<HKDevice: 0x30186e5d0>, name:Apple Watch, ma...
# 4    <<HKDevice: 0x30186e5d0>, name:Apple Watch, ma...
# ..                                                 ...
# 241  <<HKDevice: 0x301810280>, name:Apple Watch, ma...
# 242  <<HKDevice: 0x301810280>, name:Apple Watch, ma...
# 243  <<HKDevice: 0x301800e10>, name:Apple Watch, ma...
# 244  <<HKDevice: 0x301800e10>, name:Apple Watch, ma...
# 245  <<HKDevice: 0x301800e10>, name:Apple Watch, ma...
#
# [246 rows x 9 columns]

# %% [markdown]
# #Do the same reg ex manipulation as above for device

# %%
workouts_expanded = workouts_df['device'].str.extract(r'hardware:([\w\d,]+)')
workouts_expanded = workouts_expanded[0].str.rstrip(',')
workouts_expanded
# Out:
# 0            NaN
# 1      Watch6,14
# 2      Watch6,14
# 3      Watch6,14
# 4      Watch6,14
#          ...
# 241    Watch6,14
# 242    Watch6,14
# 243    Watch6,10
# 244    Watch6,10
# 245    Watch6,10
# Name: 0, Length: 246, dtype: object

# %%
workouts_expanded = workouts_expanded.to_frame()
workouts_expanded.rename(columns={0: 'deviceType'}, inplace=True)
workouts_expanded
# Out:
#     deviceType
# 0          NaN
# 1    Watch6,14
# 2    Watch6,14
# 3    Watch6,14
# 4    Watch6,14
# ..         ...
# 241  Watch6,14
# 242  Watch6,14
# 243  Watch6,10
# 244  Watch6,10
# 245  Watch6,10
#
# [246 rows x 1 columns]

# %%
workouts_df = pd.concat([workouts_df, workouts_expanded], axis=1)
workouts_df
# Out:
#                workoutActivityType           duration durationUnit  \
# 0       HKWorkoutActivityTypeOther                  0          min
# 1     HKWorkoutActivityTypeWalking  34.62768211166064          min
# 2     HKWorkoutActivityTypeRunning  17.38285479942958          min
# 3     HKWorkoutActivityTypeRunning  11.51686753034592          min
# 4    HKWorkoutActivityTypeSwimming   6.07142174243927          min
# ..                             ...                ...          ...
# 241   HKWorkoutActivityTypeRunning   9.06705576578776          min
# 242  HKWorkoutActivityTypeCooldown  28.62752670049667          min
# 243  HKWorkoutActivityTypeSwimming  77.92724243203799          min
# 244  HKWorkoutActivityTypeSwimming    62.294687606891          min
# 245  HKWorkoutActivityTypeSwimming  63.09930336872737          min
#
#                sourceName sourceVersion               creationDate  \
# 0                  Health        11.3.1  2018-06-29 14:38:15 -0500
# 1    Jannah’s Apple Watch           9.3  2023-09-17 17:26:39 -0500
# 2    Jannah’s Apple Watch           9.3  2023-09-18 18:24:44 -0500
# 3    Jannah’s Apple Watch           9.3  2023-09-21 15:01:49 -0500
# 4    Jannah’s Apple Watch           9.3  2023-09-26 15:56:23 -0500
# ..                    ...           ...                        ...
# 241  Jannah’s Apple Watch        10.6.1  2024-10-29 19:13:03 -0500
# 242  Jannah’s Apple Watch        10.6.1  2024-10-29 19:41:48 -0500
# 243  Jannah’s Apple Watch          11.0  2025-01-31 16:35:38 -0500
# 244  Jannah’s Apple Watch          11.0  2025-02-03 16:31:21 -0500
# 245  Jannah’s Apple Watch          11.0  2025-02-07 16:24:12 -0500
#
#                      startDate                    endDate  \
# 0    2018-06-29 14:37:00 -0500  2018-06-29 14:37:00 -0500
# 1    2023-09-17 16:51:58 -0500  2023-09-17 17:26:35 -0500
# 2    2023-09-18 18:07:19 -0500  2023-09-18 18:24:42 -0500
# 3    2023-09-21 14:50:17 -0500  2023-09-21 15:01:48 -0500
# 4    2023-09-26 15:50:18 -0500  2023-09-26 15:56:22 -0500
# ..                         ...                        ...
# 241  2024-10-29 19:03:58 -0500  2024-10-29 19:13:02 -0500
# 242  2024-10-29 19:13:09 -0500  2024-10-29 19:41:47 -0500
# 243  2025-01-31 15:17:39 -0500  2025-01-31 16:35:35 -0500
# 244  2025-02-03 15:29:01 -0500  2025-02-03 16:31:19 -0500
# 245  2025-02-07 15:21:04 -0500  2025-02-07 16:24:10 -0500
#
#                                                 device deviceType
# 0                                                  NaN        NaN
# 1    <<HKDevice: 0x30186e5d0>, name:Apple Watch, ma...  Watch6,14
# 2    <<HKDevice: 0x30186e5d0>, name:Apple Watch, ma...  Watch6,14
# 3    <<HKDevice: 0x30186e5d0>, name:Apple Watch, ma...  Watch6,14
# 4    <<HKDevice: 0x30186e5d0>, name:Apple Watch, ma...  Watch6,14
# ..                                                 ...        ...
# 241  <<HKDevice: 0x301810280>, name:Apple Watch, ma...  Watch6,14
# 242  <<HKDevice: 0x301810280>, name:Apple Watch, ma...  Watch6,14
# 243  <<HKDevice: 0x301800e10>, name:Apple Watch, ma...  Watch6,10
# 244  <<HKDevice: 0x301800e10>, name:Apple Watch, ma...  Watch6,10
# 245  <<HKDevice: 0x301800e10>, name:Apple Watch, ma...  Watch6,10
#
# [246 rows x 10 columns]

# %%
workouts_df.drop(columns=['sourceName','device'], inplace=True)
workouts_df
# Out:
#                workoutActivityType           duration durationUnit  \
# 0       HKWorkoutActivityTypeOther                  0          min
# 1     HKWorkoutActivityTypeWalking  34.62768211166064          min
# 2     HKWorkoutActivityTypeRunning  17.38285479942958          min
# 3     HKWorkoutActivityTypeRunning  11.51686753034592          min
# 4    HKWorkoutActivityTypeSwimming   6.07142174243927          min
# ..                             ...                ...          ...
# 241   HKWorkoutActivityTypeRunning   9.06705576578776          min
# 242  HKWorkoutActivityTypeCooldown  28.62752670049667          min
# 243  HKWorkoutActivityTypeSwimming  77.92724243203799          min
# 244  HKWorkoutActivityTypeSwimming    62.294687606891          min
# 245  HKWorkoutActivityTypeSwimming  63.09930336872737          min
#
#     sourceVersion               creationDate                  startDate  \
# 0          11.3.1  2018-06-29 14:38:15 -0500  2018-06-29 14:37:00 -0500
# 1             9.3  2023-09-17 17:26:39 -0500  2023-09-17 16:51:58 -0500
# 2             9.3  2023-09-18 18:24:44 -0500  2023-09-18 18:07:19 -0500
# 3             9.3  2023-09-21 15:01:49 -0500  2023-09-21 14:50:17 -0500
# 4             9.3  2023-09-26 15:56:23 -0500  2023-09-26 15:50:18 -0500
# ..            ...                        ...                        ...
# 241        10.6.1  2024-10-29 19:13:03 -0500  2024-10-29 19:03:58 -0500
# 242        10.6.1  2024-10-29 19:41:48 -0500  2024-10-29 19:13:09 -0500
# 243          11.0  2025-01-31 16:35:38 -0500  2025-01-31 15:17:39 -0500
# 244          11.0  2025-02-03 16:31:21 -0500  2025-02-03 15:29:01 -0500
# 245          11.0  2025-02-07 16:24:12 -0500  2025-02-07 15:21:04 -0500
#
#                        endDate deviceType
# 0    2018-06-29 14:37:00 -0500        NaN
# 1    2023-09-17 17:26:35 -0500  Watch6,14
# 2    2023-09-18 18:24:42 -0500  Watch6,14
# 3    2023-09-21 15:01:48 -0500  Watch6,14
# 4    2023-09-26 15:56:22 -0500  Watch6,14
# ..                         ...        ...
# 241  2024-10-29 19:13:02 -0500  Watch6,14
# 242  2024-10-29 19:41:47 -0500  Watch6,14
# 243  2025-01-31 16:35:35 -0500  Watch6,10
# 244  2025-02-03 16:31:19 -0500  Watch6,10
# 245  2025-02-07 16:24:10 -0500  Watch6,10
#
# [246 rows x 8 columns]

# %%
workouts_df.drop(columns=['sourceVersion'], inplace=True)
workouts_df
# Out:
#                workoutActivityType           duration durationUnit  \
# 0       HKWorkoutActivityTypeOther                  0          min
# 1     HKWorkoutActivityTypeWalking  34.62768211166064          min
# 2     HKWorkoutActivityTypeRunning  17.38285479942958          min
# 3     HKWorkoutActivityTypeRunning  11.51686753034592          min
# 4    HKWorkoutActivityTypeSwimming   6.07142174243927          min
# ..                             ...                ...          ...
# 241   HKWorkoutActivityTypeRunning   9.06705576578776          min
# 242  HKWorkoutActivityTypeCooldown  28.62752670049667          min
# 243  HKWorkoutActivityTypeSwimming  77.92724243203799          min
# 244  HKWorkoutActivityTypeSwimming    62.294687606891          min
# 245  HKWorkoutActivityTypeSwimming  63.09930336872737          min
#
#                   creationDate                  startDate  \
# 0    2018-06-29 14:38:15 -0500  2018-06-29 14:37:00 -0500
# 1    2023-09-17 17:26:39 -0500  2023-09-17 16:51:58 -0500
# 2    2023-09-18 18:24:44 -0500  2023-09-18 18:07:19 -0500
# 3    2023-09-21 15:01:49 -0500  2023-09-21 14:50:17 -0500
# 4    2023-09-26 15:56:23 -0500  2023-09-26 15:50:18 -0500
# ..                         ...                        ...
# 241  2024-10-29 19:13:03 -0500  2024-10-29 19:03:58 -0500
# 242  2024-10-29 19:41:48 -0500  2024-10-29 19:13:09 -0500
# 243  2025-01-31 16:35:38 -0500  2025-01-31 15:17:39 -0500
# 244  2025-02-03 16:31:21 -0500  2025-02-03 15:29:01 -0500
# 245  2025-02-07 16:24:12 -0500  2025-02-07 15:21:04 -0500
#
#                        endDate deviceType
# 0    2018-06-29 14:37:00 -0500        NaN
# 1    2023-09-17 17:26:35 -0500  Watch6,14
# 2    2023-09-18 18:24:42 -0500  Watch6,14
# 3    2023-09-21 15:01:48 -0500  Watch6,14
# 4    2023-09-26 15:56:22 -0500  Watch6,14
# ..                         ...        ...
# 241  2024-10-29 19:13:02 -0500  Watch6,14
# 242  2024-10-29 19:41:47 -0500  Watch6,14
# 243  2025-01-31 16:35:35 -0500  Watch6,10
# 244  2025-02-03 16:31:19 -0500  Watch6,10
# 245  2025-02-07 16:24:10 -0500  Watch6,10
#
# [246 rows x 7 columns]

# %%
workouts_df.isnull().sum()
# Out:
# workoutActivityType    0
# duration               0
# durationUnit           0
# creationDate           0
# startDate              0
# endDate                0
# deviceType             6
# dtype: int64

# %%
workouts_df.dropna(subset = ['deviceType'], inplace=True, axis = 0)
workouts_df
# Out:
#                workoutActivityType           duration durationUnit  \
# 1     HKWorkoutActivityTypeWalking  34.62768211166064          min
# 2     HKWorkoutActivityTypeRunning  17.38285479942958          min
# 3     HKWorkoutActivityTypeRunning  11.51686753034592          min
# 4    HKWorkoutActivityTypeSwimming   6.07142174243927          min
# 5    HKWorkoutActivityTypeSwimming  34.46688185135523          min
# ..                             ...                ...          ...
# 241   HKWorkoutActivityTypeRunning   9.06705576578776          min
# 242  HKWorkoutActivityTypeCooldown  28.62752670049667          min
# 243  HKWorkoutActivityTypeSwimming  77.92724243203799          min
# 244  HKWorkoutActivityTypeSwimming    62.294687606891          min
# 245  HKWorkoutActivityTypeSwimming  63.09930336872737          min
#
#                   creationDate                  startDate  \
# 1    2023-09-17 17:26:39 -0500  2023-09-17 16:51:58 -0500
# 2    2023-09-18 18:24:44 -0500  2023-09-18 18:07:19 -0500
# 3    2023-09-21 15:01:49 -0500  2023-09-21 14:50:17 -0500
# 4    2023-09-26 15:56:23 -0500  2023-09-26 15:50:18 -0500
# 5    2023-09-28 15:53:09 -0500  2023-09-28 15:18:40 -0500
# ..                         ...                        ...
# 241  2024-10-29 19:13:03 -0500  2024-10-29 19:03:58 -0500
# 242  2024-10-29 19:41:48 -0500  2024-10-29 19:13:09 -0500
# 243  2025-01-31 16:35:38 -0500  2025-01-31 15:17:39 -0500
# 244  2025-02-03 16:31:21 -0500  2025-02-03 15:29:01 -0500
# 245  2025-02-07 16:24:12 -0500  2025-02-07 15:21:04 -0500
#
#                        endDate deviceType
# 1    2023-09-17 17:26:35 -0500  Watch6,14
# 2    2023-09-18 18:24:42 -0500  Watch6,14
# 3    2023-09-21 15:01:48 -0500  Watch6,14
# 4    2023-09-26 15:56:22 -0500  Watch6,14
# 5    2023-09-28 15:53:08 -0500  Watch6,14
# ..                         ...        ...
# 241  2024-10-29 19:13:02 -0500  Watch6,14
# 242  2024-10-29 19:41:47 -0500  Watch6,14
# 243  2025-01-31 16:35:35 -0500  Watch6,10
# 244  2025-02-03 16:31:19 -0500  Watch6,10
# 245  2025-02-07 16:24:10 -0500  Watch6,10
#
# [240 rows x 7 columns]

# %% [markdown]
# #See what Device Jannah works out on the most

# %%
greatestWorkout = workouts_df['deviceType'].value_counts()
greatestWorkout
# Out:
# deviceType
# Watch6,14    237
# Watch6,10      3
# Name: count, dtype: int64

# %%
greatestWorkout.plot.pie(y='count', figsize=(10, 10), autopct='%1.1f%%')
plt.ylabel('')
plt.xlabel('')
plt.title('What Device Jannah works out on the most')
plt.show()

# %%
workouts_df.dtypes
# Out:
# workoutActivityType    object
# duration               object
# durationUnit           object
# creationDate           object
# startDate              object
# endDate                object
# deviceType             object
# dtype: object

# %%
workouts_df['duration'] = pd.to_numeric(workouts_df['duration'], errors='coerce')
workouts_df
# Out:
#                workoutActivityType   duration durationUnit  \
# 1     HKWorkoutActivityTypeWalking  34.627682          min
# 2     HKWorkoutActivityTypeRunning  17.382855          min
# 3     HKWorkoutActivityTypeRunning  11.516868          min
# 4    HKWorkoutActivityTypeSwimming   6.071422          min
# 5    HKWorkoutActivityTypeSwimming  34.466882          min
# ..                             ...        ...          ...
# 241   HKWorkoutActivityTypeRunning   9.067056          min
# 242  HKWorkoutActivityTypeCooldown  28.627527          min
# 243  HKWorkoutActivityTypeSwimming  77.927242          min
# 244  HKWorkoutActivityTypeSwimming  62.294688          min
# 245  HKWorkoutActivityTypeSwimming  63.099303          min
#
#                   creationDate                  startDate  \
# 1    2023-09-17 17:26:39 -0500  2023-09-17 16:51:58 -0500
# 2    2023-09-18 18:24:44 -0500  2023-09-18 18:07:19 -0500
# 3    2023-09-21 15:01:49 -0500  2023-09-21 14:50:17 -0500
# 4    2023-09-26 15:56:23 -0500  2023-09-26 15:50:18 -0500
# 5    2023-09-28 15:53:09 -0500  2023-09-28 15:18:40 -0500
# ..                         ...                        ...
# 241  2024-10-29 19:13:03 -0500  2024-10-29 19:03:58 -0500
# 242  2024-10-29 19:41:48 -0500  2024-10-29 19:13:09 -0500
# 243  2025-01-31 16:35:38 -0500  2025-01-31 15:17:39 -0500
# 244  2025-02-03 16:31:21 -0500  2025-02-03 15:29:01 -0500
# 245  2025-02-07 16:24:12 -0500  2025-02-07 15:21:04 -0500
#
#                        endDate deviceType
# 1    2023-09-17 17:26:35 -0500  Watch6,14
# 2    2023-09-18 18:24:42 -0500  Watch6,14
# 3    2023-09-21 15:01:48 -0500  Watch6,14
# 4    2023-09-26 15:56:22 -0500  Watch6,14
# 5    2023-09-28 15:53:08 -0500  Watch6,14
# ..                         ...        ...
# 241  2024-10-29 19:13:02 -0500  Watch6,14
# 242  2024-10-29 19:41:47 -0500  Watch6,14
# 243  2025-01-31 16:35:35 -0500  Watch6,10
# 244  2025-02-03 16:31:19 -0500  Watch6,10
# 245  2025-02-07 16:24:10 -0500  Watch6,10
#
# [240 rows x 7 columns]

# %% [markdown]
# #Jannah works out an average 22 minutes since like 2023

# %%
np.mean(workouts_df['duration'])
# Out:
# np.float64(21.59183992044793)

# %%
workouts_df['workoutActivityType'].unique()
# Out:
# array(['HKWorkoutActivityTypeWalking', 'HKWorkoutActivityTypeRunning',
#        'HKWorkoutActivityTypeSwimming',
#        'HKWorkoutActivityTypeCoreTraining',
#        'HKWorkoutActivityTypeFunctionalStrengthTraining',
#        'HKWorkoutActivityTypeCooldown',
#        'HKWorkoutActivityTypeHighIntensityIntervalTraining',
#        'HKWorkoutActivityTypeCycling', 'HKWorkoutActivityTypeClimbing',
#        'HKWorkoutActivityTypeYoga', 'HKWorkoutActivityTypeSkatingSports',
#        'HKWorkoutActivityTypePilates'], dtype=object)

# %% [markdown]
# #Jannah walks around 35 mins on average based on the minimally collected data

# %%
walkingWorkout = workouts_df[workouts_df['workoutActivityType'] == 'HKWorkoutActivityTypeWalking']
walkingWorkout
# Out:
#               workoutActivityType    duration durationUnit  \
# 1    HKWorkoutActivityTypeWalking   34.627682          min
# 6    HKWorkoutActivityTypeWalking   26.509701          min
# 10   HKWorkoutActivityTypeWalking   34.127199          min
# 12   HKWorkoutActivityTypeWalking   41.368659          min
# 21   HKWorkoutActivityTypeWalking   10.178703          min
# 22   HKWorkoutActivityTypeWalking   24.149839          min
# 26   HKWorkoutActivityTypeWalking   28.912038          min
# 57   HKWorkoutActivityTypeWalking   12.331436          min
# 71   HKWorkoutActivityTypeWalking  108.443797          min
# 72   HKWorkoutActivityTypeWalking   23.535873          min
# 79   HKWorkoutActivityTypeWalking   31.857262          min
# 93   HKWorkoutActivityTypeWalking   15.291181          min
# 109  HKWorkoutActivityTypeWalking   22.495893          min
# 116  HKWorkoutActivityTypeWalking   21.969866          min
# 166  HKWorkoutActivityTypeWalking   47.129366          min
# 210  HKWorkoutActivityTypeWalking   77.075301          min
#
#                   creationDate                  startDate  \
# 1    2023-09-17 17:26:39 -0500  2023-09-17 16:51:58 -0500
# 6    2023-09-29 18:41:19 -0500  2023-09-29 18:14:48 -0500
# 10   2023-10-05 20:25:32 -0500  2023-10-05 19:51:23 -0500
# 12   2023-10-10 15:09:22 -0500  2023-10-10 14:27:58 -0500
# 21   2023-10-30 10:54:09 -0500  2023-10-30 10:43:58 -0500
# 22   2023-10-30 14:36:57 -0500  2023-10-30 14:12:48 -0500
# 26   2023-11-14 19:09:35 -0500  2023-11-14 18:40:39 -0500
# 57   2024-04-03 12:25:50 -0500  2024-04-03 12:13:29 -0500
# 71   2024-04-29 19:03:44 -0500  2024-04-29 17:15:07 -0500
# 72   2024-04-30 14:40:52 -0500  2024-04-30 14:17:19 -0500
# 79   2024-05-05 14:24:03 -0500  2024-05-05 13:52:09 -0500
# 93   2024-06-04 19:10:54 -0500  2024-06-04 18:55:35 -0500
# 109  2024-06-22 19:00:43 -0500  2024-06-22 18:38:11 -0500
# 116  2024-06-27 18:20:33 -0500  2024-06-27 17:58:31 -0500
# 166  2024-08-02 14:25:26 -0500  2024-08-02 13:38:16 -0500
# 210  2024-09-14 18:02:34 -0500  2024-09-14 16:45:25 -0500
#
#                        endDate deviceType
# 1    2023-09-17 17:26:35 -0500  Watch6,14
# 6    2023-09-29 18:41:19 -0500  Watch6,14
# 10   2023-10-05 20:25:30 -0500  Watch6,14
# 12   2023-10-10 15:09:20 -0500  Watch6,14
# 21   2023-10-30 10:54:09 -0500  Watch6,14
# 22   2023-10-30 14:36:57 -0500  Watch6,14
# 26   2023-11-14 19:09:34 -0500  Watch6,14
# 57   2024-04-03 12:25:49 -0500  Watch6,14
# 71   2024-04-29 19:03:34 -0500  Watch6,14
# 72   2024-04-30 14:40:51 -0500  Watch6,14
# 79   2024-05-05 14:24:01 -0500  Watch6,14
# 93   2024-06-04 19:10:52 -0500  Watch6,14
# 109  2024-06-22 19:00:40 -0500  Watch6,14
# 116  2024-06-27 18:20:29 -0500  Watch6,14
# 166  2024-08-02 14:25:24 -0500  Watch6,14
# 210  2024-09-14 18:02:29 -0500  Watch6,14

# %%
np.mean(walkingWorkout['duration'])
# Out:
# np.float64(35.000237208480634)

# %% [markdown]
# #Average run time is 11.31 minutes

# %%
runningWorkout = workouts_df[workouts_df['workoutActivityType'] == 'HKWorkoutActivityTypeRunning']
runningWorkout
# Out:
#               workoutActivityType   duration durationUnit  \
# 2    HKWorkoutActivityTypeRunning  17.382855          min
# 3    HKWorkoutActivityTypeRunning  11.516868          min
# 7    HKWorkoutActivityTypeRunning   9.226493          min
# 9    HKWorkoutActivityTypeRunning  12.225145          min
# 11   HKWorkoutActivityTypeRunning   9.205468          min
# ..                            ...        ...          ...
# 231  HKWorkoutActivityTypeRunning   8.632216          min
# 234  HKWorkoutActivityTypeRunning   9.130434          min
# 236  HKWorkoutActivityTypeRunning   9.119307          min
# 238  HKWorkoutActivityTypeRunning   9.230285          min
# 241  HKWorkoutActivityTypeRunning   9.067056          min
#
#                   creationDate                  startDate  \
# 2    2023-09-18 18:24:44 -0500  2023-09-18 18:07:19 -0500
# 3    2023-09-21 15:01:49 -0500  2023-09-21 14:50:17 -0500
# 7    2023-10-02 14:52:39 -0500  2023-10-02 14:43:25 -0500
# 9    2023-10-04 15:27:56 -0500  2023-10-04 15:15:42 -0500
# 11   2023-10-09 17:30:27 -0500  2023-10-09 17:21:15 -0500
# ..                         ...                        ...
# 231  2024-10-10 16:17:09 -0500  2024-10-10 16:08:30 -0500
# 234  2024-10-17 18:07:04 -0500  2024-10-17 17:57:55 -0500
# 236  2024-10-23 17:28:35 -0500  2024-10-23 17:19:27 -0500
# 238  2024-10-25 15:52:39 -0500  2024-10-25 15:43:24 -0500
# 241  2024-10-29 19:13:03 -0500  2024-10-29 19:03:58 -0500
#
#                        endDate deviceType
# 2    2023-09-18 18:24:42 -0500  Watch6,14
# 3    2023-09-21 15:01:48 -0500  Watch6,14
# 7    2023-10-02 14:52:39 -0500  Watch6,14
# 9    2023-10-04 15:27:56 -0500  Watch6,14
# 11   2023-10-09 17:30:27 -0500  Watch6,14
# ..                         ...        ...
# 231  2024-10-10 16:17:08 -0500  Watch6,14
# 234  2024-10-17 18:07:03 -0500  Watch6,14
# 236  2024-10-23 17:28:34 -0500  Watch6,14
# 238  2024-10-25 15:52:38 -0500  Watch6,14
# 241  2024-10-29 19:13:02 -0500  Watch6,14
#
# [92 rows x 7 columns]

# %%
np.mean(runningWorkout['duration'])
# Out:
# np.float64(11.313312614871107)

# %% [markdown]
# #Swim Workout is on average 35 minutes

# %%
swmmingWorkout = workouts_df[workouts_df['workoutActivityType'] == 'HKWorkoutActivityTypeSwimming']
swmmingWorkout
# Out:
#                workoutActivityType   duration durationUnit  \
# 4    HKWorkoutActivityTypeSwimming   6.071422          min
# 5    HKWorkoutActivityTypeSwimming  34.466882          min
# 8    HKWorkoutActivityTypeSwimming  21.070266          min
# 20   HKWorkoutActivityTypeSwimming  26.705626          min
# 23   HKWorkoutActivityTypeSwimming  23.835609          min
# 62   HKWorkoutActivityTypeSwimming  19.925014          min
# 65   HKWorkoutActivityTypeSwimming  33.260991          min
# 66   HKWorkoutActivityTypeSwimming  31.146238          min
# 70   HKWorkoutActivityTypeSwimming  35.201801          min
# 96   HKWorkoutActivityTypeSwimming  32.349075          min
# 130  HKWorkoutActivityTypeSwimming  25.619784          min
# 133  HKWorkoutActivityTypeSwimming  35.962627          min
# 138  HKWorkoutActivityTypeSwimming  31.291474          min
# 146  HKWorkoutActivityTypeSwimming  40.379604          min
# 147  HKWorkoutActivityTypeSwimming  39.241329          min
# 243  HKWorkoutActivityTypeSwimming  77.927242          min
# 244  HKWorkoutActivityTypeSwimming  62.294688          min
# 245  HKWorkoutActivityTypeSwimming  63.099303          min
#
#                   creationDate                  startDate  \
# 4    2023-09-26 15:56:23 -0500  2023-09-26 15:50:18 -0500
# 5    2023-09-28 15:53:09 -0500  2023-09-28 15:18:40 -0500
# 8    2023-10-03 15:51:59 -0500  2023-10-03 15:30:54 -0500
# 20   2023-10-28 09:41:57 -0500  2023-10-28 09:15:13 -0500
# 23   2023-10-31 15:45:44 -0500  2023-10-31 15:21:53 -0500
# 62   2024-04-15 15:34:57 -0500  2024-04-15 15:15:00 -0500
# 65   2024-04-18 17:15:32 -0500  2024-04-18 16:42:15 -0500
# 66   2024-04-22 15:45:53 -0500  2024-04-22 15:14:42 -0500
# 70   2024-04-25 15:38:59 -0500  2024-04-25 15:03:43 -0500
# 96   2024-06-08 09:50:01 -0500  2024-06-08 09:17:38 -0500
# 130  2024-07-06 09:49:08 -0500  2024-07-06 09:23:29 -0500
# 133  2024-07-09 07:07:25 -0500  2024-07-09 06:31:25 -0500
# 138  2024-07-13 09:46:06 -0500  2024-07-13 09:14:47 -0500
# 146  2024-07-18 07:11:09 -0500  2024-07-18 06:30:36 -0500
# 147  2024-07-20 09:55:10 -0500  2024-07-20 09:15:51 -0500
# 243  2025-01-31 16:35:38 -0500  2025-01-31 15:17:39 -0500
# 244  2025-02-03 16:31:21 -0500  2025-02-03 15:29:01 -0500
# 245  2025-02-07 16:24:12 -0500  2025-02-07 15:21:04 -0500
#
#                        endDate deviceType
# 4    2023-09-26 15:56:22 -0500  Watch6,14
# 5    2023-09-28 15:53:08 -0500  Watch6,14
# 8    2023-10-03 15:51:58 -0500  Watch6,14
# 20   2023-10-28 09:41:55 -0500  Watch6,14
# 23   2023-10-31 15:45:43 -0500  Watch6,14
# 62   2024-04-15 15:34:56 -0500  Watch6,14
# 65   2024-04-18 17:15:30 -0500  Watch6,14
# 66   2024-04-22 15:45:51 -0500  Watch6,14
# 70   2024-04-25 15:38:55 -0500  Watch6,14
# 96   2024-06-08 09:49:59 -0500  Watch6,14
# 130  2024-07-06 09:49:06 -0500  Watch6,14
# 133  2024-07-09 07:07:23 -0500  Watch6,14
# 138  2024-07-13 09:46:04 -0500  Watch6,14
# 146  2024-07-18 07:10:59 -0500  Watch6,14
# 147  2024-07-20 09:55:06 -0500  Watch6,14
# 243  2025-01-31 16:35:35 -0500  Watch6,10
# 244  2025-02-03 16:31:19 -0500  Watch6,10
# 245  2025-02-07 16:24:10 -0500  Watch6,10

# %%
np.mean(swmmingWorkout['duration'])
# Out:
# np.float64(35.54716531777823)

# %% [markdown]
# #Even though you don't core train a lot, it was an average of 40 minutes for those handful of times

# %%
coreTraining = workouts_df[workouts_df['workoutActivityType'] == 'HKWorkoutActivityTypeCoreTraining']
coreTraining
# Out:
#                   workoutActivityType   duration durationUnit  \
# 14  HKWorkoutActivityTypeCoreTraining  30.020404          min
# 27  HKWorkoutActivityTypeCoreTraining  30.029833          min
# 47  HKWorkoutActivityTypeCoreTraining  36.729181          min
# 48  HKWorkoutActivityTypeCoreTraining  46.910850          min
# 92  HKWorkoutActivityTypeCoreTraining  51.954452          min
#
#                  creationDate                  startDate  \
# 14  2023-10-12 19:43:33 -0500  2023-10-12 19:13:30 -0500
# 27  2024-01-01 13:23:52 -0500  2024-01-01 12:53:49 -0500
# 47  2024-02-26 19:51:22 -0500  2024-02-26 19:14:36 -0500
# 48  2024-02-29 18:24:20 -0500  2024-02-29 17:37:23 -0500
# 92  2024-05-21 18:17:43 -0500  2024-05-21 17:25:43 -0500
#
#                       endDate deviceType
# 14  2023-10-12 19:43:31 -0500  Watch6,14
# 27  2024-01-01 13:23:51 -0500  Watch6,14
# 47  2024-02-26 19:51:20 -0500  Watch6,14
# 48  2024-02-29 18:24:18 -0500  Watch6,14
# 92  2024-05-21 18:17:40 -0500  Watch6,14

# %%
np.mean(coreTraining['duration'])
# Out:
# np.float64(39.12894384344419)

# %% [markdown]
# #Not a lot of functonal strength training and it was around 26 mins on average

# %%
functionalStrength = workouts_df[workouts_df['workoutActivityType'] == 'HKWorkoutActivityTypeFunctionalStrengthTraining']
functionalStrength
# Out:
#                                  workoutActivityType   duration durationUnit  \
# 24   HKWorkoutActivityTypeFunctionalStrengthTraining  46.194822          min
# 25   HKWorkoutActivityTypeFunctionalStrengthTraining  11.081109          min
# 46   HKWorkoutActivityTypeFunctionalStrengthTraining  38.557832          min
# 73   HKWorkoutActivityTypeFunctionalStrengthTraining   6.395834          min
# 74   HKWorkoutActivityTypeFunctionalStrengthTraining  25.818375          min
# 101  HKWorkoutActivityTypeFunctionalStrengthTraining  30.009443          min
# 123  HKWorkoutActivityTypeFunctionalStrengthTraining  31.660907          min
# 157  HKWorkoutActivityTypeFunctionalStrengthTraining  29.078320          min
# 173  HKWorkoutActivityTypeFunctionalStrengthTraining   5.856759          min
# 198  HKWorkoutActivityTypeFunctionalStrengthTraining  11.995317          min
# 233  HKWorkoutActivityTypeFunctionalStrengthTraining  29.361840          min
# 240  HKWorkoutActivityTypeFunctionalStrengthTraining  47.382309          min
#
#                   creationDate                  startDate  \
# 24   2023-11-01 19:28:52 -0500  2023-11-01 18:42:38 -0500
# 25   2023-11-11 21:51:52 -0500  2023-11-11 21:40:46 -0500
# 46   2024-02-22 19:11:04 -0500  2024-02-22 18:32:28 -0500
# 73   2024-05-01 18:54:02 -0500  2024-05-01 18:47:36 -0500
# 74   2024-05-01 21:05:48 -0500  2024-05-01 20:39:56 -0500
# 101  2024-06-13 11:00:04 -0500  2024-06-13 10:30:01 -0500
# 123  2024-07-02 20:15:27 -0500  2024-07-02 19:43:45 -0500
# 157  2024-07-28 11:09:42 -0500  2024-07-28 10:40:36 -0500
# 173  2024-08-13 17:53:07 -0500  2024-08-13 17:29:58 -0500
# 198  2024-09-05 18:53:22 -0500  2024-09-05 18:41:20 -0500
# 233  2024-10-16 15:31:26 -0500  2024-10-16 15:02:01 -0500
# 240  2024-10-26 10:30:14 -0500  2024-10-26 09:42:48 -0500
#
#                        endDate deviceType
# 24   2023-11-01 19:28:50 -0500  Watch6,14
# 25   2023-11-11 21:51:51 -0500  Watch6,14
# 46   2024-02-22 19:11:02 -0500  Watch6,14
# 73   2024-05-01 18:54:00 -0500  Watch6,14
# 74   2024-05-01 21:05:45 -0500  Watch6,14
# 101  2024-06-13 11:00:02 -0500  Watch6,14
# 123  2024-07-02 20:15:25 -0500  Watch6,14
# 157  2024-07-28 11:09:41 -0500  Watch6,14
# 173  2024-08-13 17:53:06 -0500  Watch6,14
# 198  2024-09-05 18:53:20 -0500  Watch6,14
# 233  2024-10-16 15:31:23 -0500  Watch6,14
# 240  2024-10-26 10:30:11 -0500  Watch6,14

# %%
np.mean(functionalStrength['duration'])
# Out:
# np.float64(26.116072400079833)

# %% [markdown]
# #Only one piece of data for high intensity interval training

# %%
highIntensity = workouts_df[workouts_df['workoutActivityType'] == 'HKWorkoutActivityTypeHighIntensityIntervalTraining']
highIntensity
# Out:
#                                   workoutActivityType   duration durationUnit  \
# 36  HKWorkoutActivityTypeHighIntensityIntervalTrai...  15.856438          min
#
#                  creationDate                  startDate  \
# 36  2024-02-07 16:44:28 -0500  2024-02-07 16:28:35 -0500
#
#                       endDate deviceType
# 36  2024-02-07 16:44:27 -0500  Watch6,14

# %% [markdown]
# #Average cycling duration is 38 minutes

# %%
cycling = workouts_df[workouts_df['workoutActivityType'] == 'HKWorkoutActivityTypeCycling']
cycling
# Out:
#               workoutActivityType   duration durationUnit  \
# 37   HKWorkoutActivityTypeCycling  26.807146          min
# 49   HKWorkoutActivityTypeCycling  60.173535          min
# 52   HKWorkoutActivityTypeCycling  31.697613          min
# 55   HKWorkoutActivityTypeCycling  22.707993          min
# 56   HKWorkoutActivityTypeCycling  33.549031          min
# 58   HKWorkoutActivityTypeCycling  51.729171          min
# 60   HKWorkoutActivityTypeCycling  10.411583          min
# 61   HKWorkoutActivityTypeCycling  73.727653          min
# 67   HKWorkoutActivityTypeCycling  57.037372          min
# 89   HKWorkoutActivityTypeCycling  66.590806          min
# 169  HKWorkoutActivityTypeCycling  16.477513          min
# 170  HKWorkoutActivityTypeCycling  19.478065          min
# 182  HKWorkoutActivityTypeCycling  34.273126          min
# 183  HKWorkoutActivityTypeCycling  30.810758          min
#
#                   creationDate                  startDate  \
# 37   2024-02-11 17:00:12 -0500  2024-02-11 16:24:08 -0500
# 49   2024-03-03 17:50:52 -0500  2024-03-03 16:29:53 -0500
# 52   2024-03-07 17:58:04 -0500  2024-03-07 17:26:19 -0500
# 55   2024-03-10 15:38:47 -0500  2024-03-10 15:16:03 -0500
# 56   2024-03-12 16:24:39 -0500  2024-03-12 15:51:01 -0500
# 58   2024-04-07 14:47:27 -0500  2024-04-07 13:47:32 -0500
# 60   2024-04-14 13:44:48 -0500  2024-04-14 12:24:51 -0500
# 61   2024-04-14 17:32:33 -0500  2024-04-14 14:05:21 -0500
# 67   2024-04-23 17:05:14 -0500  2024-04-23 16:08:07 -0500
# 89   2024-05-16 18:29:38 -0500  2024-05-16 17:18:29 -0500
# 169  2024-08-11 09:09:47 -0500  2024-08-11 08:53:15 -0500
# 170  2024-08-11 10:14:16 -0500  2024-08-11 09:54:42 -0500
# 182  2024-08-21 13:14:28 -0500  2024-08-21 12:40:08 -0500
# 183  2024-08-21 14:55:40 -0500  2024-08-21 14:23:45 -0500
#
#                        endDate deviceType
# 37   2024-02-11 17:00:09 -0500  Watch6,14
# 49   2024-03-03 17:50:47 -0500  Watch6,14
# 52   2024-03-07 17:58:01 -0500  Watch6,14
# 55   2024-03-10 15:38:45 -0500  Watch6,14
# 56   2024-03-12 16:24:34 -0500  Watch6,14
# 58   2024-04-07 14:47:22 -0500  Watch6,14
# 60   2024-04-14 12:36:38 -0500  Watch6,14
# 61   2024-04-14 17:19:55 -0500  Watch6,14
# 67   2024-04-23 17:05:10 -0500  Watch6,14
# 89   2024-05-16 18:29:32 -0500  Watch6,14
# 169  2024-08-11 09:09:44 -0500  Watch6,14
# 170  2024-08-11 10:14:10 -0500  Watch6,14
# 182  2024-08-21 13:14:25 -0500  Watch6,14
# 183  2024-08-21 14:55:37 -0500  Watch6,14

# %%
np.mean(cycling['duration'])
# Out:
# np.float64(38.247954767800515)

# %% [markdown]
# #Only one piece of data for climbing

# %%
climbing = workouts_df[workouts_df['workoutActivityType'] == 'HKWorkoutActivityTypeClimbing']
climbing
# Out:
#               workoutActivityType    duration durationUnit  \
# 84  HKWorkoutActivityTypeClimbing  111.264952          min
#
#                  creationDate                  startDate  \
# 84  2024-05-11 18:11:06 -0500  2024-05-11 16:11:58 -0500
#
#                       endDate deviceType
# 84  2024-05-11 18:10:54 -0500  Watch6,14

# %% [markdown]
# #Only one piece of data for yoga

# %%
yoga = workouts_df[workouts_df['workoutActivityType'] == 'HKWorkoutActivityTypeYoga']
yoga
# Out:
#            workoutActivityType   duration durationUnit  \
# 108  HKWorkoutActivityTypeYoga  24.187645          min
#
#                   creationDate                  startDate  \
# 108  2024-06-21 05:53:06 -0500  2024-06-21 05:28:52 -0500
#
#                        endDate deviceType
# 108  2024-06-21 05:53:03 -0500  Watch6,14

# %% [markdown]
# #Only one piece of data for pilates

# %%
pilates = workouts_df[workouts_df['workoutActivityType'] == 'HKWorkoutActivityTypePilates']
pilates
# Out:
#               workoutActivityType   duration durationUnit  \
# 209  HKWorkoutActivityTypePilates  31.273333          min
#
#                   creationDate                  startDate  \
# 209  2024-09-13 16:12:53 -0500  2024-09-13 15:41:35 -0500
#
#                        endDate deviceType
# 209  2024-09-13 16:12:51 -0500  Watch6,14

# %%
workouts_df
# Out:
#                workoutActivityType   duration durationUnit  \
# 1     HKWorkoutActivityTypeWalking  34.627682          min
# 2     HKWorkoutActivityTypeRunning  17.382855          min
# 3     HKWorkoutActivityTypeRunning  11.516868          min
# 4    HKWorkoutActivityTypeSwimming   6.071422          min
# 5    HKWorkoutActivityTypeSwimming  34.466882          min
# ..                             ...        ...          ...
# 241   HKWorkoutActivityTypeRunning   9.067056          min
# 242  HKWorkoutActivityTypeCooldown  28.627527          min
# 243  HKWorkoutActivityTypeSwimming  77.927242          min
# 244  HKWorkoutActivityTypeSwimming  62.294688          min
# 245  HKWorkoutActivityTypeSwimming  63.099303          min
#
#                   creationDate                  startDate  \
# 1    2023-09-17 17:26:39 -0500  2023-09-17 16:51:58 -0500
# 2    2023-09-18 18:24:44 -0500  2023-09-18 18:07:19 -0500
# 3    2023-09-21 15:01:49 -0500  2023-09-21 14:50:17 -0500
# 4    2023-09-26 15:56:23 -0500  2023-09-26 15:50:18 -0500
# 5    2023-09-28 15:53:09 -0500  2023-09-28 15:18:40 -0500
# ..                         ...                        ...
# 241  2024-10-29 19:13:03 -0500  2024-10-29 19:03:58 -0500
# 242  2024-10-29 19:41:48 -0500  2024-10-29 19:13:09 -0500
# 243  2025-01-31 16:35:38 -0500  2025-01-31 15:17:39 -0500
# 244  2025-02-03 16:31:21 -0500  2025-02-03 15:29:01 -0500
# 245  2025-02-07 16:24:12 -0500  2025-02-07 15:21:04 -0500
#
#                        endDate deviceType
# 1    2023-09-17 17:26:35 -0500  Watch6,14
# 2    2023-09-18 18:24:42 -0500  Watch6,14
# 3    2023-09-21 15:01:48 -0500  Watch6,14
# 4    2023-09-26 15:56:22 -0500  Watch6,14
# 5    2023-09-28 15:53:08 -0500  Watch6,14
# ..                         ...        ...
# 241  2024-10-29 19:13:02 -0500  Watch6,14
# 242  2024-10-29 19:41:47 -0500  Watch6,14
# 243  2025-01-31 16:35:35 -0500  Watch6,10
# 244  2025-02-03 16:31:19 -0500  Watch6,10
# 245  2025-02-07 16:24:10 -0500  Watch6,10
#
# [240 rows x 7 columns]

# %%
workouts_df.dtypes
# Out:
# workoutActivityType     object
# duration               float64
# durationUnit            object
# creationDate            object
# startDate               object
# endDate                 object
# deviceType              object
# dtype: object

# %%
workouts_df['creationYear'] = pd.to_datetime(workouts_df['creationDate']).dt.year
workouts_df['creationMonth'] = pd.to_datetime(workouts_df['creationDate']).dt.month
workouts_df['creationDay'] = pd.to_datetime(workouts_df['creationDate']).dt.day

workouts_df
# Out:
#                workoutActivityType   duration durationUnit  \
# 1     HKWorkoutActivityTypeWalking  34.627682          min
# 2     HKWorkoutActivityTypeRunning  17.382855          min
# 3     HKWorkoutActivityTypeRunning  11.516868          min
# 4    HKWorkoutActivityTypeSwimming   6.071422          min
# 5    HKWorkoutActivityTypeSwimming  34.466882          min
# ..                             ...        ...          ...
# 241   HKWorkoutActivityTypeRunning   9.067056          min
# 242  HKWorkoutActivityTypeCooldown  28.627527          min
# 243  HKWorkoutActivityTypeSwimming  77.927242          min
# 244  HKWorkoutActivityTypeSwimming  62.294688          min
# 245  HKWorkoutActivityTypeSwimming  63.099303          min
#
#                   creationDate                  startDate  \
# 1    2023-09-17 17:26:39 -0500  2023-09-17 16:51:58 -0500
# 2    2023-09-18 18:24:44 -0500  2023-09-18 18:07:19 -0500
# 3    2023-09-21 15:01:49 -0500  2023-09-21 14:50:17 -0500
# 4    2023-09-26 15:56:23 -0500  2023-09-26 15:50:18 -0500
# 5    2023-09-28 15:53:09 -0500  2023-09-28 15:18:40 -0500
# ..                         ...                        ...
# 241  2024-10-29 19:13:03 -0500  2024-10-29 19:03:58 -0500
# 242  2024-10-29 19:41:48 -0500  2024-10-29 19:13:09 -0500
# 243  2025-01-31 16:35:38 -0500  2025-01-31 15:17:39 -0500
# 244  2025-02-03 16:31:21 -0500  2025-02-03 15:29:01 -0500
# 245  2025-02-07 16:24:12 -0500  2025-02-07 15:21:04 -0500
#
#                        endDate deviceType  creationYear  creationMonth  \
# 1    2023-09-17 17:26:35 -0500  Watch6,14          2023              9
# 2    2023-09-18 18:24:42 -0500  Watch6,14          2023              9
# 3    2023-09-21 15:01:48 -0500  Watch6,14          2023              9
# 4    2023-09-26 15:56:22 -0500  Watch6,14          2023              9
# 5    2023-09-28 15:53:08 -0500  Watch6,14          2023              9
# ..                         ...        ...           ...            ...
# 241  2024-10-29 19:13:02 -0500  Watch6,14          2024             10
# 242  2024-10-29 19:41:47 -0500  Watch6,14          2024             10
# 243  2025-01-31 16:35:35 -0500  Watch6,10          2025              1
# 244  2025-02-03 16:31:19 -0500  Watch6,10          2025              2
# 245  2025-02-07 16:24:10 -0500  Watch6,10          2025              2
#
#      creationDay
# 1             17
# 2             18
# 3             21
# 4             26
# 5             28
# ..           ...
# 241           29
# 242           29
# 243           31
# 244            3
# 245            7
#
# [240 rows x 10 columns]

# %%
workouts_df['startYear'] = pd.to_datetime(workouts_df['startDate']).dt.year
workouts_df['startMonth'] = pd.to_datetime(workouts_df['startDate']).dt.month
workouts_df['startDay'] = pd.to_datetime(workouts_df['startDate']).dt.day

workouts_df['endYear'] = pd.to_datetime(workouts_df['endDate']).dt.year
workouts_df['endMonth'] = pd.to_datetime(workouts_df['endDate']).dt.month
workouts_df['endDay'] = pd.to_datetime(workouts_df['endDate']).dt.day

workouts_df
# Out:
#                workoutActivityType   duration durationUnit  \
# 1     HKWorkoutActivityTypeWalking  34.627682          min
# 2     HKWorkoutActivityTypeRunning  17.382855          min
# 3     HKWorkoutActivityTypeRunning  11.516868          min
# 4    HKWorkoutActivityTypeSwimming   6.071422          min
# 5    HKWorkoutActivityTypeSwimming  34.466882          min
# ..                             ...        ...          ...
# 241   HKWorkoutActivityTypeRunning   9.067056          min
# 242  HKWorkoutActivityTypeCooldown  28.627527          min
# 243  HKWorkoutActivityTypeSwimming  77.927242          min
# 244  HKWorkoutActivityTypeSwimming  62.294688          min
# 245  HKWorkoutActivityTypeSwimming  63.099303          min
#
#                   creationDate                  startDate  \
# 1    2023-09-17 17:26:39 -0500  2023-09-17 16:51:58 -0500
# 2    2023-09-18 18:24:44 -0500  2023-09-18 18:07:19 -0500
# 3    2023-09-21 15:01:49 -0500  2023-09-21 14:50:17 -0500
# 4    2023-09-26 15:56:23 -0500  2023-09-26 15:50:18 -0500
# 5    2023-09-28 15:53:09 -0500  2023-09-28 15:18:40 -0500
# ..                         ...                        ...
# 241  2024-10-29 19:13:03 -0500  2024-10-29 19:03:58 -0500
# 242  2024-10-29 19:41:48 -0500  2024-10-29 19:13:09 -0500
# 243  2025-01-31 16:35:38 -0500  2025-01-31 15:17:39 -0500
# 244  2025-02-03 16:31:21 -0500  2025-02-03 15:29:01 -0500
# 245  2025-02-07 16:24:12 -0500  2025-02-07 15:21:04 -0500
#
#                        endDate deviceType  creationYear  creationMonth  \
# 1    2023-09-17 17:26:35 -0500  Watch6,14          2023              9
# 2    2023-09-18 18:24:42 -0500  Watch6,14          2023              9
# 3    2023-09-21 15:01:48 -0500  Watch6,14          2023              9
# 4    2023-09-26 15:56:22 -0500  Watch6,14          2023              9
# 5    2023-09-28 15:53:08 -0500  Watch6,14          2023              9
# ..                         ...        ...           ...            ...
# 241  2024-10-29 19:13:02 -0500  Watch6,14          2024             10
# 242  2024-10-29 19:41:47 -0500  Watch6,14          2024             10
# 243  2025-01-31 16:35:35 -0500  Watch6,10          2025              1
# 244  2025-02-03 16:31:19 -0500  Watch6,10          2025              2
# 245  2025-02-07 16:24:10 -0500  Watch6,10          2025              2
#
#      creationDay  startYear  startMonth  startDay  endYear  endMonth  endDay
# 1             17       2023           9        17     2023         9      17
# 2             18       2023           9        18     2023         9      18
# 3             21       2023           9        21     2023         9      21
# 4             26       2023           9        26     2023         9      26
# 5             28       2023           9        28     2023         9      28
# ..           ...        ...         ...       ...      ...       ...     ...
# 241           29       2024          10        29     2024        10      29
# 242           29       2024          10        29     2024        10      29
# 243           31       2025           1        31     2025         1      31
# 244            3       2025           2         3     2025         2       3
# 245            7       2025           2         7     2025         2       7
#
# [240 rows x 16 columns]

# %%
workouts_df['creationDate'] = pd.to_datetime(workouts_df['creationDate']).dt.tz_localize(None)
workouts_df['startDate'] = pd.to_datetime(workouts_df['startDate']).dt.tz_localize(None)
workouts_df['endDate'] = pd.to_datetime(workouts_df['endDate']).dt.tz_localize(None)

workouts_df
# Out:
#                workoutActivityType   duration durationUnit  \
# 1     HKWorkoutActivityTypeWalking  34.627682          min
# 2     HKWorkoutActivityTypeRunning  17.382855          min
# 3     HKWorkoutActivityTypeRunning  11.516868          min
# 4    HKWorkoutActivityTypeSwimming   6.071422          min
# 5    HKWorkoutActivityTypeSwimming  34.466882          min
# ..                             ...        ...          ...
# 241   HKWorkoutActivityTypeRunning   9.067056          min
# 242  HKWorkoutActivityTypeCooldown  28.627527          min
# 243  HKWorkoutActivityTypeSwimming  77.927242          min
# 244  HKWorkoutActivityTypeSwimming  62.294688          min
# 245  HKWorkoutActivityTypeSwimming  63.099303          min
#
#            creationDate           startDate             endDate deviceType  \
# 1   2023-09-17 17:26:39 2023-09-17 16:51:58 2023-09-17 17:26:35  Watch6,14
# 2   2023-09-18 18:24:44 2023-09-18 18:07:19 2023-09-18 18:24:42  Watch6,14
# 3   2023-09-21 15:01:49 2023-09-21 14:50:17 2023-09-21 15:01:48  Watch6,14
# 4   2023-09-26 15:56:23 2023-09-26 15:50:18 2023-09-26 15:56:22  Watch6,14
# 5   2023-09-28 15:53:09 2023-09-28 15:18:40 2023-09-28 15:53:08  Watch6,14
# ..                  ...                 ...                 ...        ...
# 241 2024-10-29 19:13:03 2024-10-29 19:03:58 2024-10-29 19:13:02  Watch6,14
# 242 2024-10-29 19:41:48 2024-10-29 19:13:09 2024-10-29 19:41:47  Watch6,14
# 243 2025-01-31 16:35:38 2025-01-31 15:17:39 2025-01-31 16:35:35  Watch6,10
# 244 2025-02-03 16:31:21 2025-02-03 15:29:01 2025-02-03 16:31:19  Watch6,10
# 245 2025-02-07 16:24:12 2025-02-07 15:21:04 2025-02-07 16:24:10  Watch6,10
#
#      creationYear  creationMonth  creationDay  startYear  startMonth  \
# 1            2023              9           17       2023           9
# 2            2023              9           18       2023           9
# 3            2023              9           21       2023           9
# 4            2023              9           26       2023           9
# 5            2023              9           28       2023           9
# ..            ...            ...          ...        ...         ...
# 241          2024             10           29       2024          10
# 242          2024             10           29       2024          10
# 243          2025              1           31       2025           1
# 244          2025              2            3       2025           2
# 245          2025              2            7       2025           2
#
#      startDay  endYear  endMonth  endDay
# 1          17     2023         9      17
# 2          18     2023         9      18
# 3          21     2023         9      21
# 4          26     2023         9      26
# 5          28     2023         9      28
# ..        ...      ...       ...     ...
# 241        29     2024        10      29
# 242        29     2024        10      29
# 243        31     2025         1      31
# 244         3     2025         2       3
# 245         7     2025         2       7
#
# [240 rows x 16 columns]

# %% [markdown]
# #Correlation Matrix

# %%
numeric_df = workouts_df.select_dtypes(include=['number'])
matrix = numeric_df.corr()

# plotting correlation matrix
plt.imshow(matrix, cmap='Blues')

# adding colorbar
plt.colorbar()

# extracting variable names
variables = []
for i in matrix.columns:
    variables.append(i)

# Adding labels to the matrix
plt.xticks(range(len(matrix)), variables, rotation=45, ha='right')
plt.yticks(range(len(matrix)), variables)

# Display the plot
plt.show()

# %%
#workouts_df.to_excel("workouts.xlsx", index=False)

# %% [markdown]
# #Make an ML model later

# %%
records_df['type'].unique()
# Out:
# array(['HKQuantityTypeIdentifierHeartRate',
#        'HKQuantityTypeIdentifierRespiratoryRate',
#        'HKQuantityTypeIdentifierStepCount',
#        'HKQuantityTypeIdentifierDistanceWalkingRunning',
#        'HKQuantityTypeIdentifierBasalEnergyBurned',
#        'HKQuantityTypeIdentifierActiveEnergyBurned',
#        'HKQuantityTypeIdentifierFlightsClimbed',
#        'HKQuantityTypeIdentifierAppleExerciseTime',
#        'HKQuantityTypeIdentifierDistanceCycling',
#        'HKQuantityTypeIdentifierDistanceSwimming',
#        'HKQuantityTypeIdentifierSwimmingStrokeCount',
#        'HKQuantityTypeIdentifierEnvironmentalAudioExposure',
#        'HKQuantityTypeIdentifierWalkingDoubleSupportPercentage',
#        'HKQuantityTypeIdentifierWalkingSpeed',
#        'HKQuantityTypeIdentifierWalkingStepLength',
#        'HKQuantityTypeIdentifierWalkingAsymmetryPercentage',
#        'HKQuantityTypeIdentifierAppleWalkingSteadiness',
#        'HKQuantityTypeIdentifierTimeInDaylight',
#        'HKQuantityTypeIdentifierHeartRateVariabilitySDNN'], dtype=object)

# %%
workouts_df['workoutActivityType'].unique()
# Out:
# array(['HKWorkoutActivityTypeWalking', 'HKWorkoutActivityTypeRunning',
#        'HKWorkoutActivityTypeSwimming',
#        'HKWorkoutActivityTypeCoreTraining',
#        'HKWorkoutActivityTypeFunctionalStrengthTraining',
#        'HKWorkoutActivityTypeCooldown',
#        'HKWorkoutActivityTypeHighIntensityIntervalTraining',
#        'HKWorkoutActivityTypeCycling', 'HKWorkoutActivityTypeClimbing',
#        'HKWorkoutActivityTypeYoga', 'HKWorkoutActivityTypeSkatingSports',
#        'HKWorkoutActivityTypePilates'], dtype=object)
